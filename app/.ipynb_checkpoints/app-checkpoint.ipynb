# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
gtes = "gtes04ene.xls"
goi = "goi04ene.xls"
gom = "gom04ene.xls"
gef = "gef04ene.xls"
cuentas=[7,10,11,12,16,17]
bdgtes = pd.read_excel('../data/'+gtes)
bdgoi = pd.read_excel('../data/'+goi)
bdgom = pd.read_excel('../data/'+gom)
bdgef = pd.read_excel('../data/'+gef)

bdBruto= pd.concat([bdgtes,bdgoi,bdgom,bdgef],ignore_index=True)
#bd.describe()

# %%
bdBruto.columns
# Out:
# Index(['cod_unidad', 'glosa_reng', 'cve_debe_haber', 'monto_mo',
#        'factor_conv_mo_mn', 'nro_centro', 'cod_moneda', 'cod_movimiento',
#        'fecha_dia', 'nom_movimiento', 'nom_moneda', 'nom_persona',
#        'exponente_escala', 'monto_mn', 'compute_0015', 'compute_0016',
#        'nro_afectable', 'glosa_comprob', 'cve_tipo_comprob', 'nro_comprob',
#        'nro_aprobacion', 'nro_reng', 'nom_centro', 'fecha_hora', 'cod_mayor',
#        'nom_mayor', 'cod_tipo_cuenta', 'desc_tipo_cuenta', 'cod_persona',
#        'cod_moneda.1'],
#       dtype='object')

# %%
bdReducida=bdBruto.loc[:,('cve_tipo_comprob','glosa_reng','cve_debe_haber','monto_mo',
           'cod_moneda', 'cod_movimiento', 'nom_movimiento',
           'monto_mn','glosa_comprob','nro_comprob','cod_mayor')]
#bdReducida

# %%
dict = {'cve_tipo_comprob':'tipo','glosa_reng':'glosaRenglon','cve_debe_haber':'dh','monto_mo':'mo',
           'cod_moneda':'moneda', 'cod_movimiento':'codMov', 'nom_movimiento':'nomMov',
           'monto_mn':'mn','glosa_comprob':'glosa','nro_comprob':'comprobante','cod_mayor':'mayor'}
bdReducida.rename(columns=dict,
          inplace=True)
bdReducida.shape
# Out:
# (4815, 11)

# %%
#bd['mayor'].unique()

#bdFiltro1=bdReducida[bdReducida['mayor'].isin([7,10,11,16,17])]
bdFiltro1=bdReducida[bdReducida['mayor'].isin(cuentas)]

# %%
#bdFiltro1.loc[:,("comprobante","mayor")]
bdFiltro1["comprobante"].unique()
#bdFiltro1.sort_values(by="comprobante", ascending=True)
# Out:
# array([1988999, 1989052, 1989068, 1023079, 1023080, 1023086, 1023090,
#        1023081,   28350,   21762, 1747929,   28354, 1747939, 1023099,
#        1023082, 1747823, 1023083, 1747923, 1747924, 1747926, 1023106,
#        1023110, 1747931, 1747933, 1747935, 1747937, 1023104, 1023117,
#        1023120, 1023089], dtype=int64)

# %%
#bd[bd['comprobante'].isin(bdFiltro1["comprobante"])].sort_values(by="comprobante", ascending=True).tail(60)
bd=bdReducida[bdReducida["comprobante"].isin(bdFiltro1["comprobante"])].sort_values(by=["comprobante","dh"], ascending=True)
bd = bd.reset_index(drop=True)
bd.head(60)
# Out:
#    tipo                                       glosaRenglon dh            mo  \
# 0     D  Saldo ME = -972249.54 ;Bs/Mo: 6.86000000000 ;S...  D  0.000000e+00
# 1     D  Saldo ME = 2029398.45 ;Bs/Mo: 6.86000000000 ;S...  D  0.000000e+00
# 2     D  Saldo ME = 96961.47 ;Bs/Mo: 6.86000000000 ;Sal...  D  0.000000e+00
# 3     D  Saldo ME = 1386.09 ;Bs/Mo: 6.86000000000 ;Sald...  D  0.000000e+00
# 4     D  Saldo ME = 19.70 ;Bs/Mo: 6.86000000000 ;Saldo ...  D  0.000000e+00
# 5     D  Saldo MO = -6741712.77 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 6     D  Saldo MO = -39486890.83 ;Bs/Mo: 6.86000000000 ...  D  0.000000e+00
# 7     D  Saldo MO = -87657056.04 ;Bs/Mo: 6.86000000000 ...  D  0.000000e+00
# 8     D  Saldo MO = -3443775.78 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 9     D  Saldo MO = -6741712.77 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 10    D  Saldo MO = -2241995.43 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 11    D  Saldo ME = -678093.46 ;Bs/Mo: 6.86000000000 ;S...  H  0.000000e+00
# 12    D  Saldo ME = 2151.91 ;Bs/Mo: 6.86000000000 ;Sald...  H  0.000000e+00
# 13    D  Saldo ME = 676646003.62 ;Bs/Mo: 6.86000000000 ...  H  0.000000e+00
# 14    D  Saldo ME = -1.17 ;Bs/Mo: 6.86000000000 ;Saldo ...  H  0.000000e+00
# 15    D  Saldo MO = 0.00 ;Bs/Mo: 6.86000000000 ;Saldo B...  H  0.000000e+00
# 16    D  Saldo MO = -5086038.82 ;Bs/Mo: 6.86000000000 ;...  H  0.000000e+00
# 17    D  Saldo MO = -52067773.42 ;Bs/Mo: 6.86000000000 ...  H  0.000000e+00
# 18    D  Saldo MO = 0.00 ;Bs/Mo: 6.86000000000 ;Saldo B...  H  0.000000e+00
# 19    V  Saldo Ant.= 36491.00 ;Bs: 9.61072280000 = $us ...  D  0.000000e+00
# 20    V  Saldo Ant.= -1374.83 ;Bs: 7.74835000000 = $us ...  D  0.000000e+00
# 21    V  Saldo Ant.= -600349.90 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 22    V  Saldo Ant.= -860780.92 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 23    V  Saldo Ant.= 1536.00 ;Bs: 9.61072280000 = $us 2...  D  0.000000e+00
# 24    V  Saldo Ant.= -162857.00 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 25    V  Saldo Ant.= 398905287.00 ;Bs: 9.61072280000 = ...  D  0.000000e+00
# 26    V  Saldo Ant.= 26025000.00 ;Bs: 9.61072280000 = $...  D  0.000000e+00
# 27    V  Saldo Ant.= -1.04 ;Bs: 7.74835000000 = $us -1....  D  0.000000e+00
# 28    V  Saldo Ant.= -217524.50 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 29    V  Saldo Ant.= -36070.00 ;Bs: 9.61072280000 = $us...  H  0.000000e+00
# 30    V  Saldo Ant.= 1791431.77 ;Bs: 7.74835000000 = $u...  H  0.000000e+00
# 31    V  Saldo Ant.= 85136.57 ;Bs: 7.74835000000 = $us ...  H  0.000000e+00
# 32    V  Saldo Ant.= 303.10 ;Bs: 7.46789000000 = $us 32...  H  0.000000e+00
# 33    V  Saldo Ant.= 1028.41 ;Bs: 9.24591000000 = $us 1...  H  0.000000e+00
# 34    V  Saldo Ant.= -394256208.00 ;Bs: 9.61072280000 =...  H  0.000000e+00
# 35    V  Saldo Ant.= 17.46 ;Bs: 7.74835000000 = $us 19....  H  0.000000e+00
# 36    V  Saldo Ant.= 599218898.54 ;Bs: 7.74835000000 = ...  H  0.000000e+00
# 37    V  Saldo Ant.= 451473.00 ;Bs: 0.05951000000 = $us...  H  0.000000e+00
# 38    V  Saldo Ant.= 451473.00 ;Bs: 0.05951000000 = $us...  H  0.000000e+00
# 39    V  Saldo Ant.= 85844.82 ;Bs: 7.74835000000 = $us ...  H  0.000000e+00
# 40    S                                                NaN  D  2.150045e+08
# 41    S                                                NaN  H  4.479170e+03
# 42    S                                                NaN  H  2.150000e+08
# 43    S                                                NaN  D  3.583340e+03
# 44    S                                                NaN  H  2.458171e+04
# 45    S                                                NaN  D  2.000000e-02
# 46    S                                                NaN  H  2.000000e-02
# 47    S                                                NaN  D  5.295710e+03
# 48    S                                                NaN  H  4.103301e+04
# 49    S                                                NaN  D  1.620900e+06
# 50    S                                                NaN  D  3.000000e+00
# 51    S                                                NaN  H  3.504100e+04
# 52    S                                                NaN  H  1.585862e+06
# 53    S                                                NaN  D  1.504731e+05
# 54    S                                                NaN  H  1.504731e+05
# 55    S    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.  D  4.293000e+04
# 56    S  POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...  H  4.293000e+04
# 57    S                                                NaN  D  3.107020e+03
# 58    S                                                NaN  H  2.131416e+04
# 59    S                                                NaN  D  1.168000e+02
#
#     moneda  codMov                                             nomMov  \
# 0       53    5708  RECUPERACIONES CREDITO ESPAÑOL - FAD IV C.N.S....
# 1       53    6296  INTERESES DEVENGADOS                          ...
# 2       53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 3       33      39  LONDRES - CTA. 40433331                       ...
# 4       53    6535  CTA. P03394 - 57603 PORTAFOLIO EURO           ...
# 5       34     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 6       34    3914  BISA-CUENTA CORRIENTE Y DE ENCAJE             ...
# 7       34    3906  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...
# 8       34    7191  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...
# 9       34     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 10      34    6354  COOPERATIVA JESUS NAZARENO LTDA. - CUENTA ENCA...
# 11      53    5713  RECUPERACIONES CREDITO ESPAÑOL FAD V C.N.S.   ...
# 12      50    7810  INTERESES DEVENGADOS S/TRAMO DE RESERVA FMI   ...
# 13      53    6758  TITULOS - PORTAFOLIO GLOBAL                   ...
# 14      53    8080  GAMLP - AECID ACUERDO COMPLEMENTARIO NRO. 8   ...
# 15      34    5247  ACCL-CTA.LIQUIDADORA CAMARA DE CHEQUES        ...
# 16      34    7178  BCO. PYME ECOFUTURO S.A. CTA.CORRIENTE Y DE EN...
# 17      34    3910  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...
# 18      34    7768  LINKSER EMP.ADM.TAR.ELECTRONICAS - CTA.LIQUIDA...
# 19      50     113  INTERESES DEVENGADOS S/TENENCIAS DEG          ...
# 20      53    1470  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...
# 21      53    5713  RECUPERACIONES CREDITO ESPAÑOL FAD V C.N.S.   ...
# 22      53    5708  RECUPERACIONES CREDITO ESPAÑOL - FAD IV C.N.S....
# 23      50    7810  INTERESES DEVENGADOS S/TRAMO DE RESERVA FMI   ...
# 24      53    7329  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...
# 25      50     112  TENENCIAS DE DEGS                             ...
# 26      50     114  TRAMO DE RESERVA                              ...
# 27      53    8080  GAMLP - AECID ACUERDO COMPLEMENTARIO NRO. 8   ...
# 28      53    8500  UMSFX - PROYECTO INNOVA                       ...
# 29      50    6177  INTERESES DEVENGADOS S/ASIGNACIONES DEG'S     ...
# 30      53    6296  INTERESES DEVENGADOS                          ...
# 31      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 32      31    6853  1 D CHF BCB - BASILEA, SUIZA                  ...
# 33      33      39  LONDRES - CTA. 40433331                       ...
# 34      50     647  ASIGNACIONES DEG-FMI                          ...
# 35      53    6535  CTA. P03394 - 57603 PORTAFOLIO EURO           ...
# 36      53    6758  TITULOS - PORTAFOLIO GLOBAL                   ...
# 37      20      35  TOKIO - 653-0402206                           ...
# 38      20      35  TOKIO - 653-0402206                           ...
# 39      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 40      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 41      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 42      34    6294  DEPOSITOS OVERNIGHT PACTADOS                  ...
# 43      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 44      69    1535  INTERESES OVERNIGHT CAPITAL TRABAJO           ...
# 45      34    5906  PROVISION  COMISIONES Y GASTOS BANCARIOS EXTER...
# 46      53    6535  CTA. P03394 - 57603 PORTAFOLIO EURO           ...
# 47      53    6296  INTERESES DEVENGADOS                          ...
# 48      69    6538  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...
# 49      34    5397  ENCAJE LEGAL EN TITULOS-SISTEMA FINANCIERO    ...
# 50      34    5552  ENCAJE LEGAL EN TITULOS MVDOL-SISTEMA FINANCIE...
# 51      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 52      34    5397  ENCAJE LEGAL EN TITULOS-SISTEMA FINANCIERO    ...
# 53      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 54      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 55      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 56      34    7954  YPFB - EXPORTACION DE UREA Y OTROS            ...
# 57      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 58      69    1535  INTERESES OVERNIGHT CAPITAL TRABAJO           ...
# 59      34    6286  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...
#
#               mn                                              glosa  \
# 0   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 2   2.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 3   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 4   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 5   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 6   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 7   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 8   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 9   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 10  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 11  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 12  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 13  3.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 14  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 15  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 16  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 17  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 18  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 19  3.504800e+02  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 20  6.983000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 21  3.051582e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 22  4.375349e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 23  1.482000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 24  8.278030e+03  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 25  3.831086e+06  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 26  2.499441e+05  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 27  7.000000e-02  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 28  1.105674e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 29  3.464300e+02  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 30  9.105847e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 31  4.327490e+03  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 32  1.838000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 33  4.233000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 34  3.786437e+06  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 35  8.900000e-01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 36  3.045830e+07  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 37  3.608000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 38  3.608000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 39  7.000000e-02  AJUSTE COMPLEMENTARIO POR ARBITRAJE DE SALDOS ...
# 40  1.474931e+09  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...
# 41  3.072711e+04  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...
# 42  1.474900e+09  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...
# 43  2.458171e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||COMPLE...
# 44  2.458171e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||COMPLE...
# 45  1.400000e-01  ||PAGO DE COMISIONES Y GASTOS BANCARIOS EXTERI...
# 46  1.500000e-01  ||PAGO DE COMISIONES Y GASTOS BANCARIOS EXTERI...
# 47  4.103301e+04  ||INTERESES DEVENGADOS DEL PORTAFOLIO GLOBAL E...
# 48  4.103301e+04  ||INTERESES DEVENGADOS DEL PORTAFOLIO GLOBAL E...
# 49  1.111937e+07  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 50  2.058000e+01  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 51  2.403813e+05  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 52  1.087901e+07  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 53  1.032245e+06  'INTERESES GANADOS'||POR OVERNIGHT AUTOMATICOS...
# 54  1.032245e+06  'INTERESES GANADOS'||POR OVERNIGHT AUTOMATICOS...
# 55  2.944998e+05  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 56  2.944998e+05  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 57  2.131416e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 58  2.131416e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 59  8.012500e+02  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
#
#     comprobante  mayor
# 0         21762    410
# 1         21762     17
# 2         21762     10
# 3         21762     10
# 4         21762     10
# 5         21762    412
# 6         21762    403
# 7         21762    403
# 8         21762    403
# 9         21762    412
# 10        21762    403
# 11        21762    410
# 12        21762     24
# 13        21762     16
# 14        21762    406
# 15        21762    414
# 16        21762    403
# 17        21762    403
# 18        21762    414
# 19        28350     22
# 20        28350    498
# 21        28350    410
# 22        28350    410
# 23        28350     24
# 24        28350    405
# 25        28350     21
# 26        28350     23
# 27        28350    406
# 28        28350    406
# 29        28350    306
# 30        28350     17
# 31        28350     10
# 32        28350     10
# 33        28350     10
# 34        28350    385
# 35        28350     10
# 36        28350     16
# 37        28350     10
# 38        28350     10
# 39        28354     10
# 40      1023079     10
# 41      1023079     11
# 42      1023079     12
# 43      1023080     11
# 44      1023080    606
# 45      1023081    485
# 46      1023081     10
# 47      1023082     17
# 48      1023082    606
# 49      1023083    403
# 50      1023083    403
# 51      1023083     10
# 52      1023083    403
# 53      1023086     10
# 54      1023086     11
# 55      1023089     10
# 56      1023089    404
# 57      1023090     11
# 58      1023090    606
# 59      1023099     16

# %%
#list(bd.loc[55,["glosa"]])

# %%
#bd.to_excel("ux.xlsx")

# %%
bd=bd.drop_duplicates()
bd = bd.reset_index(drop=True)
bd.head(60)
# Out:
#    tipo                                       glosaRenglon dh            mo  \
# 0     D  Saldo ME = -972249.54 ;Bs/Mo: 6.86000000000 ;S...  D  0.000000e+00
# 1     D  Saldo ME = 2029398.45 ;Bs/Mo: 6.86000000000 ;S...  D  0.000000e+00
# 2     D  Saldo ME = 96961.47 ;Bs/Mo: 6.86000000000 ;Sal...  D  0.000000e+00
# 3     D  Saldo ME = 1386.09 ;Bs/Mo: 6.86000000000 ;Sald...  D  0.000000e+00
# 4     D  Saldo ME = 19.70 ;Bs/Mo: 6.86000000000 ;Saldo ...  D  0.000000e+00
# 5     D  Saldo MO = -6741712.77 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 6     D  Saldo MO = -39486890.83 ;Bs/Mo: 6.86000000000 ...  D  0.000000e+00
# 7     D  Saldo MO = -87657056.04 ;Bs/Mo: 6.86000000000 ...  D  0.000000e+00
# 8     D  Saldo MO = -3443775.78 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 9     D  Saldo MO = -2241995.43 ;Bs/Mo: 6.86000000000 ;...  D  0.000000e+00
# 10    D  Saldo ME = -678093.46 ;Bs/Mo: 6.86000000000 ;S...  H  0.000000e+00
# 11    D  Saldo ME = 2151.91 ;Bs/Mo: 6.86000000000 ;Sald...  H  0.000000e+00
# 12    D  Saldo ME = 676646003.62 ;Bs/Mo: 6.86000000000 ...  H  0.000000e+00
# 13    D  Saldo ME = -1.17 ;Bs/Mo: 6.86000000000 ;Saldo ...  H  0.000000e+00
# 14    D  Saldo MO = 0.00 ;Bs/Mo: 6.86000000000 ;Saldo B...  H  0.000000e+00
# 15    D  Saldo MO = -5086038.82 ;Bs/Mo: 6.86000000000 ;...  H  0.000000e+00
# 16    D  Saldo MO = -52067773.42 ;Bs/Mo: 6.86000000000 ...  H  0.000000e+00
# 17    D  Saldo MO = 0.00 ;Bs/Mo: 6.86000000000 ;Saldo B...  H  0.000000e+00
# 18    V  Saldo Ant.= 36491.00 ;Bs: 9.61072280000 = $us ...  D  0.000000e+00
# 19    V  Saldo Ant.= -1374.83 ;Bs: 7.74835000000 = $us ...  D  0.000000e+00
# 20    V  Saldo Ant.= -600349.90 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 21    V  Saldo Ant.= -860780.92 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 22    V  Saldo Ant.= 1536.00 ;Bs: 9.61072280000 = $us 2...  D  0.000000e+00
# 23    V  Saldo Ant.= -162857.00 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 24    V  Saldo Ant.= 398905287.00 ;Bs: 9.61072280000 = ...  D  0.000000e+00
# 25    V  Saldo Ant.= 26025000.00 ;Bs: 9.61072280000 = $...  D  0.000000e+00
# 26    V  Saldo Ant.= -1.04 ;Bs: 7.74835000000 = $us -1....  D  0.000000e+00
# 27    V  Saldo Ant.= -217524.50 ;Bs: 7.74835000000 = $u...  D  0.000000e+00
# 28    V  Saldo Ant.= -36070.00 ;Bs: 9.61072280000 = $us...  H  0.000000e+00
# 29    V  Saldo Ant.= 1791431.77 ;Bs: 7.74835000000 = $u...  H  0.000000e+00
# 30    V  Saldo Ant.= 85136.57 ;Bs: 7.74835000000 = $us ...  H  0.000000e+00
# 31    V  Saldo Ant.= 303.10 ;Bs: 7.46789000000 = $us 32...  H  0.000000e+00
# 32    V  Saldo Ant.= 1028.41 ;Bs: 9.24591000000 = $us 1...  H  0.000000e+00
# 33    V  Saldo Ant.= -394256208.00 ;Bs: 9.61072280000 =...  H  0.000000e+00
# 34    V  Saldo Ant.= 17.46 ;Bs: 7.74835000000 = $us 19....  H  0.000000e+00
# 35    V  Saldo Ant.= 599218898.54 ;Bs: 7.74835000000 = ...  H  0.000000e+00
# 36    V  Saldo Ant.= 451473.00 ;Bs: 0.05951000000 = $us...  H  0.000000e+00
# 37    V  Saldo Ant.= 85844.82 ;Bs: 7.74835000000 = $us ...  H  0.000000e+00
# 38    S                                                NaN  D  2.150045e+08
# 39    S                                                NaN  H  4.479170e+03
# 40    S                                                NaN  H  2.150000e+08
# 41    S                                                NaN  D  3.583340e+03
# 42    S                                                NaN  H  2.458171e+04
# 43    S                                                NaN  D  2.000000e-02
# 44    S                                                NaN  H  2.000000e-02
# 45    S                                                NaN  D  5.295710e+03
# 46    S                                                NaN  H  4.103301e+04
# 47    S                                                NaN  D  1.620900e+06
# 48    S                                                NaN  D  3.000000e+00
# 49    S                                                NaN  H  3.504100e+04
# 50    S                                                NaN  H  1.585862e+06
# 51    S                                                NaN  D  1.504731e+05
# 52    S                                                NaN  H  1.504731e+05
# 53    S    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.  D  4.293000e+04
# 54    S  POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...  H  4.293000e+04
# 55    S                                                NaN  D  3.107020e+03
# 56    S                                                NaN  H  2.131416e+04
# 57    S                                                NaN  D  1.168000e+02
# 58    S                                                NaN  H  8.012500e+02
# 59    S  (CC:H-0044417-2021) I-2021-10 VTA. DIVISAS S/G...  D  8.080368e+05
#
#     moneda  codMov                                             nomMov  \
# 0       53    5708  RECUPERACIONES CREDITO ESPAÑOL - FAD IV C.N.S....
# 1       53    6296  INTERESES DEVENGADOS                          ...
# 2       53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 3       33      39  LONDRES - CTA. 40433331                       ...
# 4       53    6535  CTA. P03394 - 57603 PORTAFOLIO EURO           ...
# 5       34     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 6       34    3914  BISA-CUENTA CORRIENTE Y DE ENCAJE             ...
# 7       34    3906  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...
# 8       34    7191  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...
# 9       34    6354  COOPERATIVA JESUS NAZARENO LTDA. - CUENTA ENCA...
# 10      53    5713  RECUPERACIONES CREDITO ESPAÑOL FAD V C.N.S.   ...
# 11      50    7810  INTERESES DEVENGADOS S/TRAMO DE RESERVA FMI   ...
# 12      53    6758  TITULOS - PORTAFOLIO GLOBAL                   ...
# 13      53    8080  GAMLP - AECID ACUERDO COMPLEMENTARIO NRO. 8   ...
# 14      34    5247  ACCL-CTA.LIQUIDADORA CAMARA DE CHEQUES        ...
# 15      34    7178  BCO. PYME ECOFUTURO S.A. CTA.CORRIENTE Y DE EN...
# 16      34    3910  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...
# 17      34    7768  LINKSER EMP.ADM.TAR.ELECTRONICAS - CTA.LIQUIDA...
# 18      50     113  INTERESES DEVENGADOS S/TENENCIAS DEG          ...
# 19      53    1470  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...
# 20      53    5713  RECUPERACIONES CREDITO ESPAÑOL FAD V C.N.S.   ...
# 21      53    5708  RECUPERACIONES CREDITO ESPAÑOL - FAD IV C.N.S....
# 22      50    7810  INTERESES DEVENGADOS S/TRAMO DE RESERVA FMI   ...
# 23      53    7329  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...
# 24      50     112  TENENCIAS DE DEGS                             ...
# 25      50     114  TRAMO DE RESERVA                              ...
# 26      53    8080  GAMLP - AECID ACUERDO COMPLEMENTARIO NRO. 8   ...
# 27      53    8500  UMSFX - PROYECTO INNOVA                       ...
# 28      50    6177  INTERESES DEVENGADOS S/ASIGNACIONES DEG'S     ...
# 29      53    6296  INTERESES DEVENGADOS                          ...
# 30      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 31      31    6853  1 D CHF BCB - BASILEA, SUIZA                  ...
# 32      33      39  LONDRES - CTA. 40433331                       ...
# 33      50     647  ASIGNACIONES DEG-FMI                          ...
# 34      53    6535  CTA. P03394 - 57603 PORTAFOLIO EURO           ...
# 35      53    6758  TITULOS - PORTAFOLIO GLOBAL                   ...
# 36      20      35  TOKIO - 653-0402206                           ...
# 37      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 38      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 39      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 40      34    6294  DEPOSITOS OVERNIGHT PACTADOS                  ...
# 41      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 42      69    1535  INTERESES OVERNIGHT CAPITAL TRABAJO           ...
# 43      34    5906  PROVISION  COMISIONES Y GASTOS BANCARIOS EXTER...
# 44      53    6535  CTA. P03394 - 57603 PORTAFOLIO EURO           ...
# 45      53    6296  INTERESES DEVENGADOS                          ...
# 46      69    6538  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...
# 47      34    5397  ENCAJE LEGAL EN TITULOS-SISTEMA FINANCIERO    ...
# 48      34    5552  ENCAJE LEGAL EN TITULOS MVDOL-SISTEMA FINANCIE...
# 49      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 50      34    5397  ENCAJE LEGAL EN TITULOS-SISTEMA FINANCIERO    ...
# 51      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 52      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 53      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 54      34    7954  YPFB - EXPORTACION DE UREA Y OTROS            ...
# 55      34    2902  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...
# 56      69    1535  INTERESES OVERNIGHT CAPITAL TRABAJO           ...
# 57      34    6286  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...
# 58      69    7355  VALORACION TITULOS DE LAS RESERVAS INTERNACION...
# 59      34    3071  GARANTIA POR ACREDITIVOS - INST. DESC.        ...
#
#               mn                                              glosa  \
# 0   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 2   2.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 3   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 4   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 5   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 6   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 7   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 8   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 9   1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 10  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 11  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 12  3.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 13  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 14  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 15  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 16  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 17  1.000000e-02  AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 18  3.504800e+02  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 19  6.983000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 20  3.051582e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 21  4.375349e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 22  1.482000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 23  8.278030e+03  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 24  3.831086e+06  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 25  2.499441e+05  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 26  7.000000e-02  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 27  1.105674e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 28  3.464300e+02  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 29  9.105847e+04  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 30  4.327490e+03  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 31  1.838000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 32  4.233000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 33  3.786437e+06  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 34  8.900000e-01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 35  3.045830e+07  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 36  3.608000e+01  AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 37  7.000000e-02  AJUSTE COMPLEMENTARIO POR ARBITRAJE DE SALDOS ...
# 38  1.474931e+09  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...
# 39  3.072711e+04  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...
# 40  1.474900e+09  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...
# 41  2.458171e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||COMPLE...
# 42  2.458171e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||COMPLE...
# 43  1.400000e-01  ||PAGO DE COMISIONES Y GASTOS BANCARIOS EXTERI...
# 44  1.500000e-01  ||PAGO DE COMISIONES Y GASTOS BANCARIOS EXTERI...
# 45  4.103301e+04  ||INTERESES DEVENGADOS DEL PORTAFOLIO GLOBAL E...
# 46  4.103301e+04  ||INTERESES DEVENGADOS DEL PORTAFOLIO GLOBAL E...
# 47  1.111937e+07  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 48  2.058000e+01  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 49  2.403813e+05  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 50  1.087901e+07  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...
# 51  1.032245e+06  'INTERESES GANADOS'||POR OVERNIGHT AUTOMATICOS...
# 52  1.032245e+06  'INTERESES GANADOS'||POR OVERNIGHT AUTOMATICOS...
# 53  2.944998e+05  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 54  2.944998e+05  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 55  2.131416e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 56  2.131416e+04  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 57  8.012500e+02  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 58  8.012500e+02  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 59  5.543132e+06  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
#
#     comprobante  mayor
# 0         21762    410
# 1         21762     17
# 2         21762     10
# 3         21762     10
# 4         21762     10
# 5         21762    412
# 6         21762    403
# 7         21762    403
# 8         21762    403
# 9         21762    403
# 10        21762    410
# 11        21762     24
# 12        21762     16
# 13        21762    406
# 14        21762    414
# 15        21762    403
# 16        21762    403
# 17        21762    414
# 18        28350     22
# 19        28350    498
# 20        28350    410
# 21        28350    410
# 22        28350     24
# 23        28350    405
# 24        28350     21
# 25        28350     23
# 26        28350    406
# 27        28350    406
# 28        28350    306
# 29        28350     17
# 30        28350     10
# 31        28350     10
# 32        28350     10
# 33        28350    385
# 34        28350     10
# 35        28350     16
# 36        28350     10
# 37        28354     10
# 38      1023079     10
# 39      1023079     11
# 40      1023079     12
# 41      1023080     11
# 42      1023080    606
# 43      1023081    485
# 44      1023081     10
# 45      1023082     17
# 46      1023082    606
# 47      1023083    403
# 48      1023083    403
# 49      1023083     10
# 50      1023083    403
# 51      1023086     10
# 52      1023086     11
# 53      1023089     10
# 54      1023089    404
# 55      1023090     11
# 56      1023090    606
# 57      1023099     16
# 58      1023099    499
# 59      1023104    405

# %%
#bd["comprobante"].unique()

# %%
aux1=bd["comprobante"].unique()
#len(aux1)
#print(bd["comprobante"]==aux1[5])
#print(aux1[5])

consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    ###print("---", q, "-----")
    ###print(aux2.loc[:,["comprobante","mayor"]])
    ###print("-----")
    suma=0
    for i in aux2.index:
    
        if aux2["mayor"][i] in cuentas and (aux2["tipo"][i]=='V' or aux2["tipo"][i]=='D'):
            #print (i)
            suma=suma+aux2["mn"][i]/6.86
            
        else:
            #print ("else")
            for j in aux2.index:
                if i!=j:
                    if aux2["mn"][i]==aux2["mn"][j]:  ####### AQUI VER LA FORMA DE COMPARAR CON UN MARGEN

                        data1.append({
                            "Tipo":aux2["tipo"][i],"Comprobante":aux2["comprobante"][i],"Concepto":aux2["dh"][i],
                            "Mayor":aux2["mayor"][i],"codMov":aux2["codMov"][i],"Movimiento":aux2["nomMov"][i],
                            "MN":aux2["mn"][i],"Glosa":aux2["glosa"][i],"GlosaDetalle":aux2["glosaRenglon"][i],
                                    })
                        #print(q)
                        pares=pd.DataFrame(data1,columns=columnas)
                        #print(type(pares))      
    print ("la suma es ",suma, " c ", aux2["comprobante"][i])
        #suma=0

    ########################

    # reduce a una sola linea
    
    data2=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    def llenarData(concepto,a,b):
        if concepto !="Neteo":    
            data2.append({
                     "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                    "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                    "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                    "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                    })
        else:
            data2.append({
                    "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                    "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                    "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                    "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                    })
            
    #if len(pares)>2:
    #    print("Revisar oe")

    #for i in salida.index:
    ##print("que pasa")
    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
        #print("Posible Neteo")
        llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
        unRegistro=pd.DataFrame(data2,columns=columnas)
    else:     
        if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
            llenarData("Ingreso",0,1)        
        if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
            llenarData("Egreso",0,1)                   
        if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
            llenarData("Ingreso",1,0)                    
        if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
            llenarData("Egreso",1,0) 

        unRegistro=pd.DataFrame(data2,columns=columnas)
      
    ## print(pares)
    ##print("-------------------")
    ##print("======= consolidado ============")
    ##print(consolidado) 
    #print("===================")
    consolidado=consolidado.append(unRegistro, ignore_index=True)  
    ##print ("la suma es ",suma, " c ", aux2["comprobante"][i])   
consolidado
#consolidado.to_excel("borrar.xlsx")
# Out:
# la suma es  0.011661807580174925  c  21762
# la suma es  4453903.827988339  c  28350
# la suma es  0.010204081632653062  c  28354
# la suma es  0  c  1023079
# la suma es  0  c  1023080
# la suma es  0  c  1023081
# la suma es  0  c  1023082
# la suma es  0  c  1023083
# la suma es  0  c  1023086
# la suma es  0  c  1023089
# la suma es  0  c  1023090
# la suma es  0  c  1023099
# la suma es  0  c  1023104
# la suma es  0  c  1023106
# la suma es  0  c  1023110
# la suma es  0  c  1023117
# la suma es  0  c  1023120
# la suma es  0  c  1747823
# la suma es  0  c  1747923
# la suma es  0  c  1747924
# la suma es  0  c  1747926
# la suma es  0  c  1747929
# la suma es  0  c  1747931
# la suma es  0  c  1747933
# la suma es  0  c  1747935
# la suma es  0  c  1747937
# la suma es  0  c  1747939
# la suma es  0  c  1988999
# la suma es  0  c  1989052
# la suma es  0  c  1989068
#    Tipo Comprobante Concepto Mayor1 Mayor2 codMov  \
# 0     S     1023080  Ingreso     11    606   1535
# 1     S     1023080  Ingreso     11    606   1535
# 2     S     1023082  Ingreso     17    606   6538
# 3     S     1023082  Ingreso     17    606   6538
# 4     S     1023086    Neteo     10     11   2902
# 5     S     1023089  Ingreso     10    404   7954
# 6     S     1023090  Ingreso     11    606   1535
# 7     S     1023099  Ingreso     16    499   7355
# 8     S     1023104   Egreso     10    405   3071
# 9     S     1023106  Ingreso     10    412   5832
# 10    S     1023110  Ingreso     10    403   3914
# 11    S     1023117  Ingreso     10    403   3917
# 12    S     1023120  Ingreso     10    403   3908
# 13    G     1747823   Egreso     16    499   7355
# 14    G     1747923   Egreso     10    498   6817
# 15    G     1747924  Ingreso     10    412    818
# 16    G     1747926  Ingreso     10    412   5970
# 17    G     1747926  Ingreso     10    412   5970
# 18    G     1747931  Ingreso     10    404   5968
# 19    G     1747933  Ingreso     10    404   7164
# 20    G     1747935  Ingreso     10    404   6705
# 21    G     1747937   Egreso     10    498   6817
# 22    G     1747939    Neteo     10     10   5896
# 23    O     1988999   Egreso      7    403   3908
# 24    O     1989052   Egreso      7    403   3910
# 25    O     1989068  Ingreso      7    406    898
#
#                                            Movimiento     MontoUSD  \
# 0   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3583.34
# 1   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3583.34
# 2   INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...      5981.49
# 3   INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...      5981.49
# 4   INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...         0.00
# 5   YPFB - EXPORTACION DE UREA Y OTROS            ...     42930.00
# 6   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3107.02
# 7   VALORACION TITULOS DE LAS RESERVAS INTERNACION...       116.80
# 8   GARANTIA POR ACREDITIVOS - INST. DESC.        ...    808036.80
# 9   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     16238.50
# 10  BISA-CUENTA CORRIENTE Y DE ENCAJE             ...   3000000.00
# 11  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   2000000.00
# 12  BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  16000000.00
# 13  VALORACION TITULOS DE LAS RESERVAS INTERNACION...    169995.29
# 14  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  15000000.00
# 15  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    718935.64
# 16  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...      1989.84
# 17  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...      1989.84
# 18  YPFB - HEROES DEL CHACO                       ...    293447.36
# 19  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    144050.30
# 20  YPFB OPERACIONES FINANCIERAS EXTRAORDINARIAS  ...    156883.29
# 21  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...   6000000.00
# 22  NEW YORK - CTA. 3544020682001                 ...         0.00
# 23  BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  16000000.00
# 24  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...   6500000.00
# 25  TGN CUENTA TRANSITORIA- M/E                   ...        50.00
#
#                                               Detalle  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                      (±, 150473.06)
# 5   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# 6                                                 NaN
# 7                                                 NaN
# 8   (CC:H-0044417-2021) I-2021-10 VTA. DIVISAS S/G...
# 9                      POR CUENTA DE TAMPA CARGO SAS.
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  CTA. 1-4713413 COMIBOL -  EMPRESA MINERA COROCORO
# 16  LIB. 00099021001 TGN-RECURSOS ORDINARIOS-DOLAR...
# 17  LIB. 00099021001 TGN-RECURSOS ORDINARIOS-DOLAR...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                    (±, 99200000.0)
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
#
#                                                 Glosa
# 0   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||COMPLE...
# 1   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||COMPLE...
# 2   ||INTERESES DEVENGADOS DEL PORTAFOLIO GLOBAL E...
# 3   ||INTERESES DEVENGADOS DEL PORTAFOLIO GLOBAL E...
# 4   'INTERESES GANADOS'||POR OVERNIGHT AUTOMATICOS...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 6   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 7   ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 8   'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 10  ||TRANSFERENCIA DE FONDOS DEL EXTERIOR SEGUN S...
# 11  ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN EXTRACTO...
# 12  ||TRANSF. DE FONDOS DEL EXTERIOR SEGUN EXTRACT...
# 13  REVALORACIÓN DE TÍTULOS AL 04-01-2022, PORTAFO...
# 14  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 15  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NOS.078...
# 16  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.071 ...
# 17  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.071 ...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.81 D...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.88 Y...
# 20  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.83 Y...
# 21  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 22  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 23  PAGO CHEQUE: D-06-87152     , BENEFICIARIO: EM...
# 24  PAGO CHEQUE: D-21-99278     , BENEFICIARIO: MA...
# 25  DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMA...

# %%
def llenarData(concepto,a,b):
    if concepto !="Neteo":    
        print('dentro ',pares["Comprobante"][a])
        data2.append({
                 "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                })
    else:
        data2.append({
                "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                })

def dv(concepto,suma):
    data2.append({''
                 "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                "Mayor1":"--","Mayor2":"--","codMov":"--",
                "Movimiento":"--","MontoUSD":round(suma,2),
                "Detalle":"--","Glosa":aux2["glosa"][0]
                })

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    print("q ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        sumaDebe=0
        sumaHaber=0
        for i in aux2.index:
            if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                sumaDebe=sumaDebe+aux2["mn"][i]/6.86
            elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                sumaHaber=sumaHaber+aux2["mn"][i]/6.86
        suma=sumaDebe-sumaHaber
        if suma>0:
            dv("Ingreso",suma)
            unRegistro=pd.DataFrame(data2,columns=columnas)
            consolidado=consolidado.append(unRegistro, ignore_index=True)
        else:
            dv("Egreso",-suma)
            unRegistro=pd.DataFrame(data2,columns=columnas)
            consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # este el caso normal digamos ##############################################################
        #print ("menos Tipo D o V")
        for i in aux2.index:    
            for j in aux2.index:
                if i!=j:
                    if aux2["mn"][i]==aux2["mn"][j]:
                        data1.append({
                            "Tipo":aux2["tipo"][i],"Comprobante":aux2["comprobante"][i],"Concepto":aux2["dh"][i],
                            "Mayor":aux2["mayor"][i],"codMov":aux2["codMov"][i],"Movimiento":aux2["nomMov"][i],
                            "MN":aux2["mn"][i],"Glosa":aux2["glosa"][i],"GlosaDetalle":aux2["glosaRenglon"][i],
                                    })
                        pares=pd.DataFrame(data1,columns=columnas)
                    
                    else:
                        if aux2['mayor'][i] in cuentas:
                            data1.append({
                            "Tipo":aux2["tipo"][i],"Comprobante":aux2["comprobante"][i],"Concepto":aux2["dh"][i],
                            "Mayor":aux2["mayor"][i],"codMov":aux2["codMov"][i],"Movimiento":aux2["nomMov"][i],
                            "MN":aux2["mn"][i],"Glosa":aux2["glosa"][i],"GlosaDetalle":aux2["glosaRenglon"][i],
                                    })
                            pares=pd.DataFrame(data1,columns=columnas)
                        else:
                            
                        #if aux2['mayor'][i] in cuentas:
                        print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
                    #print('pares')
                    #print(pares)
    
        print('pares ',pares["Comprobante"][0])
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes


        if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
            #print("Posible Neteo")
            llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
            unRegistro=pd.DataFrame(data2,columns=columnas)
        else:     
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                print('caso 1')
                llenarData("Ingreso",0,1)        
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                print('caso 2')
                llenarData("Egreso",0,1)                   
            if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                print('caso 3')
                llenarData("Ingreso",1,0)                    
            if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                print('caso 4')
                llenarData("Egreso",1,0) 

        unRegistro=pd.DataFrame(data2,columns=columnas)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar.xlsx")
# Out:
#   File "<ipython-input-14-1596c24ea5eb>", line 54
#     print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
#     ^
# IndentationError: expected an indented block

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        sumaDebe=0
        sumaHaber=0
        for i in aux2.index:
            if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                sumaDebe=sumaDebe+aux2["mn"][i]/6.86
            elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                sumaHaber=sumaHaber+aux2["mn"][i]/6.86
        suma=sumaDebe-sumaHaber
        if suma>0:
            dv("Ingreso",suma)
            unRegistro=pd.DataFrame(data2,columns=columnas)
            consolidado=consolidado.append(unRegistro, ignore_index=True)
        else:
            dv("Egreso",-suma)
            unRegistro=pd.DataFrame(data2,columns=columnas)
            consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # este el caso normal digamos ##############################################################
        #print ("menos Tipo D o V")
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            for x in range(len(aux4)):
                #print(aux4[x],"=== ",aux2["mn"][aux4[x]])

                data1.append({
                    "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                    "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                    "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                            })
                pares=pd.DataFrame(data1,columns=columnas)

        else:
            #if aux2['mayor'][i] in cuentas:
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux4[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas)

            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares')
            #print(pares)

            #print('pares ',pares["Comprobante"][0])
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes


        if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
            #print("Posible Neteo")
            llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
            unRegistro=pd.DataFrame(data2,columns=columnas)
        else:     
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                print('caso 1')
                llenarData("Ingreso",0,1)        
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                print('caso 2')
                llenarData("Egreso",0,1)                   
            if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                print('caso 3')
                llenarData("Ingreso",1,0)                    
            if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                print('caso 4')
                llenarData("Egreso",1,0) 

        unRegistro=pd.DataFrame(data2,columns=columnas)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar1.xlsx")
# Out:
# Comprobante  0
# 21762
# Comprobante  1
# 28350
# Comprobante  2
# 28354
# Comprobante  3
# 1023079
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh            mo  moneda  codMov  \
# 0    S          NaN  D  2.150045e+08      34    5896
# 1    S          NaN  H  4.479170e+03      34    2902
# 2    S          NaN  H  2.150000e+08      34    6294
#
#                                               nomMov            mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1.474931e+09
# 1  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  3.072711e+04
# 2  DEPOSITOS OVERNIGHT PACTADOS                  ...  1.474900e+09
#
#                                                glosa  comprobante  mayor
# 0  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...      1023079     10
# 1  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...      1023079     11
# 2  ||LIBERACION DE DEPOSITO OVERNIGHT EN LA CAF 0...      1023079     12
# Comprobante  4
# 1023080
# Hay duplicado:  True
# caso 1
# dentro  1023080
# Comprobante  5
# 1023081
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh    mo  moneda  codMov  \
# 0    S          NaN  H  0.02      53    6535
# 1    S          NaN  D  0.02      34    5906
#
#                                               nomMov    mn  \
# 0  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  0.15
# 1  PROVISION  COMISIONES Y GASTOS BANCARIOS EXTER...  0.14
#
#                                                glosa  comprobante  mayor
# 0  ||PAGO DE COMISIONES Y GASTOS BANCARIOS EXTERI...      1023081     10
# 1  ||PAGO DE COMISIONES Y GASTOS BANCARIOS EXTERI...      1023081    485
# caso 2
# dentro  1023081
# Comprobante  6
# 1023082
# Hay duplicado:  True
# caso 1
# dentro  1023082
# Comprobante  7
# 1023083
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh         mo  moneda  codMov  \
# 0    S          NaN  H    35041.0      34    5896
# 1    S          NaN  D  1620900.0      34    5397
# 2    S          NaN  D        3.0      34    5552
# 3    S          NaN  H  1585862.0      34    5397
#
#                                               nomMov           mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...    240381.26
# 1  ENCAJE LEGAL EN TITULOS-SISTEMA FINANCIERO    ...  11119374.00
# 2  ENCAJE LEGAL EN TITULOS MVDOL-SISTEMA FINANCIE...        20.58
# 3  ENCAJE LEGAL EN TITULOS-SISTEMA FINANCIERO    ...  10879013.32
#
#                                                glosa  comprobante  mayor
# 0  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...      1023083     10
# 1  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...      1023083    403
# 2  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...      1023083    403
# 3  ||MOVIMIENTO DE CAPITAL DEL FONDO RAL AL 04 DE...      1023083    403
# caso 2
# dentro  1023083
# Comprobante  8
# 1023086
# Hay duplicado:  True
# Comprobante  9
# 1023089
# Hay duplicado:  True
# caso 1
# dentro  1023089
# Comprobante  10
# 1023090
# Hay duplicado:  True
# caso 1
# dentro  1023090
# Comprobante  11
# 1023099
# Hay duplicado:  True
# caso 1
# dentro  1023099
# Comprobante  12
# 1023104
# Hay duplicado:  True
# caso 4
# dentro  1023104
# Comprobante  13
# 1023106
# Hay duplicado:  True
# caso 1
# dentro  1023106
# Comprobante  14
# 1023110
# Hay duplicado:  True
# caso 1
# dentro  1023110
# Comprobante  15
# 1023117
# Hay duplicado:  True
# caso 1
# dentro  1023117
# Comprobante  16
# 1023120
# Hay duplicado:  True
# caso 1
# dentro  1023120
# Comprobante  17
# 1747823
# Hay duplicado:  True
# caso 4
# dentro  1747823
# Comprobante  18
# 1747923
# Hay duplicado:  True
# caso 4
# dentro  1747923
# Comprobante  19
# 1747924
# Hay duplicado:  True
# caso 1
# dentro  1747924
# Comprobante  20
# 1747926
# Hay duplicado:  True
# caso 1
# dentro  1747926
# Comprobante  21
# 1747929
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh      mo  moneda  codMov  \
# 0    G          NaN  D  708.25      53    6072
# 1    G          NaN  H  799.97      34    4249
#
#                                               nomMov       mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  5487.77
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  5487.79
#
#                                                glosa  comprobante  mayor
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.80 D...      1747929     10
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.80 D...      1747929    412
# caso 1
# dentro  1747929
# Comprobante  22
# 1747931
# Hay duplicado:  True
# caso 1
# dentro  1747931
# Comprobante  23
# 1747933
# Hay duplicado:  True
# caso 1
# dentro  1747933
# Comprobante  24
# 1747935
# Hay duplicado:  True
# caso 1
# dentro  1747935
# Comprobante  25
# 1747937
# Hay duplicado:  True
# caso 4
# dentro  1747937
# Comprobante  26
# 1747939
# Hay duplicado:  True
# Comprobante  27
# 1988999
# Hay duplicado:  True
# caso 4
# dentro  1988999
# Comprobante  28
# 1989052
# Hay duplicado:  True
# caso 4
# dentro  1989052
# Comprobante  29
# 1989068
# Hay duplicado:  True
# caso 1
# dentro  1989068
