# %%
import numpy as np
import pandas as pd
import re
from pandas import Series, DataFrame
gtes = "gtes04feb.xls"
goi = "goi04feb.xls"
gom = "gom04feb.xls"
gef = "gef04feb.xls"
parametros = "parametros.xlsx"
cuentas=[7,10,11,12,16,17]
bdgtes = pd.read_excel('../data/'+gtes)
bdgoi = pd.read_excel('../data/'+goi)
bdgom = pd.read_excel('../data/'+gom)
bdgef = pd.read_excel('../data/'+gef)
movimientos =pd.read_excel('../data/'+parametros, sheet_name="movimientos")
bdBruto= pd.concat([bdgtes,bdgoi,bdgom,bdgef],ignore_index=True)
#bd.describe()
movimientos
# Out:
# WARNING *** file size (751214) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (394879) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (4014373) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (4367209) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#    Concepto  Mayor2  codMov              nomMovimiento  \
# 0   Ingreso     404    7164                   YPFB GLP
# 1   Ingreso     404    7954                  YPFB UREA
# 2   Ingreso     404    5968      YPFB Héroes del Chaco
# 3    Egreso     404    5968      YPFB Héroes del Chaco
# 4   Ingreso     404    6215  Empresa Metalúrgica Vinto
# ..      ...     ...     ...                        ...
# 63   Egreso     498    6818        Dep. Sector Público
# 64   Egreso      25     166                      Aladi
# 65  Ingreso      25    9999                      Aladi
# 66  Ingreso     828    3500                  Ver estos
# 67   Egreso      10    6535            Portafolio Euro
#
#                                codigoBC               codigoPropio
# 0                 Y.P.F.B. Otros (BCI5)                   YPFB GLP
# 1                 Y.P.F.B. Otros (BCI5)                  YPFB UREA
# 2                             Ver Glosa                  Ver Glosa
# 3                             Ver Glosa                  Ver Glosa
# 4                          VINTO (BCI6)  Empresa Metalúrgica Vinto
# ..                                  ...                        ...
# 63                            Ver Glosa                  Ver Glosa
# 64  CONVENIO CRED. RECIP.(1),(2) (BCE6)                      Aladi
# 65  CONVENIO DE CRED. RECIP (1) (BCI11)                      Aladi
# 66         CUENTA CORRIENTE (3) (BCI18)                  Ver Glosa
# 67                        OTROS (BCE12)            Portafolio Euro
#
# [68 rows x 6 columns]

# %%
#bdBruto.columns

# %%
bdReducida=bdBruto.loc[:,('cve_tipo_comprob','glosa_reng','cve_debe_haber','monto_mo',
           'cod_moneda', 'cod_movimiento', 'nom_movimiento',
           'monto_mn','glosa_comprob','nro_comprob','cod_mayor')]
#bdReducida

# %%
dict = {'cve_tipo_comprob':'tipo','glosa_reng':'glosaRenglon','cve_debe_haber':'dh','monto_mo':'mo',
           'cod_moneda':'moneda', 'cod_movimiento':'codMov', 'nom_movimiento':'nomMov',
           'monto_mn':'mn','glosa_comprob':'glosa','nro_comprob':'comprobante','cod_mayor':'mayor'}
bdReducida.rename(columns=dict,
          inplace=True)
bdReducida.shape
# Out:
# (6913, 11)

# %%
#bd['mayor'].unique()

#bdFiltro1=bdReducida[bdReducida['mayor'].isin([7,10,11,16,17])]
bdFiltro1=bdReducida[bdReducida['mayor'].isin(cuentas)]

# %%
#bdFiltro1.loc[:,("comprobante","mayor")]
bdFiltro1["comprobante"].unique()
#bdFiltro1.sort_values(by="comprobante", ascending=True)
# Out:
# array([1996851, 1996852, 1996865, 1996906, 1996980, 1025269,   28482,
#        1777767,   21859, 1025316, 1025295, 1777769, 1777343, 1777345,
#        1777347, 1777480, 1777481, 1777482, 1777483, 1025283, 1025275,
#        1025272, 1025273, 1777620, 1777623, 1777626, 1777629, 1777631,
#        1777633, 1025289, 1025312, 1025314, 1025301, 1777765, 1025315,
#        1025332, 1025334,    5545,    2178], dtype=int64)

# %%
#bd[bd['comprobante'].isin(bdFiltro1["comprobante"])].sort_values(by="comprobante", ascending=True).tail(60)
bd=bdReducida[bdReducida["comprobante"].isin(bdFiltro1["comprobante"])].sort_values(by=["comprobante","dh"], ascending=True)
bd = bd.reset_index(drop=True)
#bd.head(60)

# %%
#list(bd.loc[55,["glosa"]])

# %%
#bd.to_excel("ux.xlsx")

# %%
bd=bd.drop_duplicates()
bd = bd.reset_index(drop=True)
#bd.head(60)

# %%
#bd["comprobante"].unique()

# %%
def llenarData(concepto,a,b):
    if concepto !="Neteo":    
        print('dentro ',pares["Comprobante"][a])
        data2.append({
                 "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                })
    else:
        data2.append({
                "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                })

def dv(concepto,suma):
    print("largo cuando dentra al debehaber: ",len(aux2))
    if len(aux2)==1:
        data2.append({''
                     "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                    "Mayor1":aux2["mayor"][0],"Mayor2":"--","codMov":"--",
                    "Movimiento":"--","MontoUSD":round(suma,2),
                    "Detalle":aux2["glosaRenglon"][0],"Glosa":aux2["glosa"][0]
                    })
    else:
        data2.append({''
                     "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                    "Mayor1":aux2["mayor"][0],"Mayor2":aux2["mayor"][1],"codMov":aux2["codMov"][1],
                    "Movimiento":aux2["nomMov"][1],"MontoUSD":round(suma,2),
                    "Detalle":aux2["glosaRenglon"][0],"Glosa":aux2["glosa"][0]
                    })

def debemenoshaber(hasta):
    sumaDebe=0
    sumaHaber=0
    for i in hasta:
        if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
            sumaDebe=sumaDebe+aux2["mn"][i]/6.86
        elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
            sumaHaber=sumaHaber+aux2["mn"][i]/6.86
    suma=sumaDebe-sumaHaber
    if suma>0:
        dv("Ingreso",suma)
    else:
        dv("Egreso",-suma)

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas1=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    data2=[]
    columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        data2=[]
        columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        sumaDebe=0
        sumaHaber=0
        for i in aux2.index:
            if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                sumaDebe=sumaDebe+aux2["mn"][i]/6.86
            elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                sumaHaber=sumaHaber+aux2["mn"][i]/6.86
        suma=sumaDebe-sumaHaber
        if suma>0:
            dv("Ingreso",suma)
            #unRegistro=pd.DataFrame(data2,columns=columnas)
            #consolidado=consolidado.append(unRegistro, ignore_index=True)
        else:
            dv("Egreso",-suma)
            #unRegistro=pd.DataFrame(data2,columns=columnas)
            #consolidado=consolidado.append(unRegistro, ignore_index=True)
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        #print ("menos Tipo D o V")
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            for x in range(len(aux4)):

                data1.append({
                    "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                    "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                    "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)

        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)

            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares ',pares["Comprobante"][0])
        print(pares)
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes

        if len(aux2)==2: ### los pares. Este sería el caso normal
            print("largo de aux2: ",len(aux2))
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                #print("Posible Neteo")
                llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                unRegistro=pd.DataFrame(data2,columns=columnas2)
            else:     
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                    print('caso 1')
                    llenarData("Ingreso",0,1)        
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                    print('caso 2')
                    llenarData("Egreso",0,1)                   
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                    print('caso 3')
                    llenarData("Ingreso",1,0)                    
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                    print('caso 4')
                    llenarData("Egreso",1,0)
        else:
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                ###
                data2=[]
                columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                sumaDebe=0
                sumaHaber=0
                for i in range(len(aux2)):
                    if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                        sumaDebe=sumaDebe+aux2["mn"][i]/6.86
                    elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                        sumaHaber=sumaHaber+aux2["mn"][i]/6.86
                suma=sumaDebe-sumaHaber
                if suma>0:
                    dv("Ingreso",suma)
                    #unRegistro=pd.DataFrame(data2,columns=columnas)
                    #consolidado=consolidado.append(unRegistro, ignore_index=True)
                else:
                    dv("Egreso",-suma)
                    #unRegistro=pd.DataFrame(data2,columns=columnas)
                    #consolidado=consolidado.append(unRegistro, ignore_index=True)
                ####

        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar1.xlsx")
# Out:
# Comprobante  0
# 2178
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S         2178        D    485    5782
# 1    S         2178        H     10    7266
#
#                                           Movimiento      MN  \
# 0  PROVISIONES PARA COMISIONES AL CUSTODIO       ...  646.49
# 1  CTA. P99828-AG530 PORTAFOLIO FPA              ...  646.49
#
#                                                Glosa  GlosaDetalle
# 0  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# 1  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# largo de aux2:  2
# caso 4
# dentro  2178
# Comprobante  1
# 5545
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S         5545        D    485    5782
# 1    S         5545        H     10    7038
#
#                                           Movimiento       MN  \
# 0  PROVISIONES PARA COMISIONES AL CUSTODIO       ...  3993.89
# 1  CTA. 0728162841 PORTAFOLIO FPAH               ...  3993.89
#
#                                                Glosa  GlosaDetalle
# 0  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# 1  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# largo de aux2:  2
# caso 4
# dentro  5545
# Comprobante  2
# 21859
# largo cuando dentra al debehaber:  26
# Comprobante  3
# 28482
# largo cuando dentra al debehaber:  19
# Comprobante  4
# 1025269
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025269        D     11    2902
# 1    S      1025269        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  15385.95
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  15385.95
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# largo de aux2:  2
# caso 1
# dentro  1025269
# Comprobante  5
# 1025272
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025272        D     10    5896
# 1    S      1025272        H    412    8467
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  177218.98
# 1  DIREC.GRAL.AERONAUTICA CIVIL-RECURSOS ESPECIFI...  177218.98
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
#
#                                         GlosaDetalle
# 0  A LA CUENTA DIREC.GRAL. AERONAUTICA CIVIL-RECU...
# 1                 P. CTA. DE IATA INTERNATIONAL AIR.
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  6
# 1025273
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025273        D     10    5896
# 1    S      1025273        H    404    7954
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  20353620.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  20353620.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# largo de aux2:  2
# caso 1
# dentro  1025273
# Comprobante  7
# 1025275
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025275        D     10    5896
# 1    S      1025275        H    404    7954
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  20765220.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  20765220.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# largo de aux2:  2
# caso 1
# dentro  1025275
# Comprobante  8
# 1025283
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025283        D     10    5896
# 1    S      1025283        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1543.5
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1543.5
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046550-2022)
# largo de aux2:  2
# caso 1
# dentro  1025283
# Comprobante  9
# 1025289
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh      mo  moneda  \
# 0    S  TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...  H  105.11      34
# 1    S  CGO.LIB.00099021001 TGN RECURSOS ORDINARIOS CO...  D  270.75      69
# 2    S  LIBRETA 00099021001 TGN RECURSOS ORDINARIOS DO...  D  120.12      34
# 3    S                                                NaN  H  191.40      69
# 4    S                                                NaN  H   43.50      69
# 5    S                                                NaN  H    0.65      69
#
#    codMov                                             nomMov      mn  \
# 0    5896  NEW YORK - CTA. 3544020682001                 ...  721.05
# 1    3987  CUENTA UNICA DEL TESORO                       ...  270.75
# 2    5970  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  824.02
# 3    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...  191.40
# 4    1514  UTILES DE ESCRITORIO                          ...   43.50
# 5    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...    0.65
#
#                                                glosa  comprobante  mayor
# 0  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289     10
# 1  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    412
# 2  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    412
# 3  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    600
# 4  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    600
# 5  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    650
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025289        H     10    5896
# 1    S      1025289        D    412    3987
# 2    S      1025289        D    412    5970
# 3    S      1025289        H    600    1510
# 4    S      1025289        H    600    1514
# 5    S      1025289        H    650    1563
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  721.05
# 1  CUENTA UNICA DEL TESORO                       ...  270.75
# 2  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  824.02
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...  191.40
# 4  UTILES DE ESCRITORIO                          ...   43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...    0.65
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 1  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 2  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 3  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 4  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 5  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
#
#                                         GlosaDetalle
# 0  TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 1  CGO.LIB.00099021001 TGN RECURSOS ORDINARIOS CO...
# 2  LIBRETA 00099021001 TGN RECURSOS ORDINARIOS DO...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  6
# Comprobante  10
# 1025295
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025295        D     16    6286
# 1    S      1025295        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# largo de aux2:  2
# caso 1
# dentro  1025295
# Comprobante  11
# 1025301
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025301        D     10    5896
# 1    S      1025301        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3552519.6
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  3552519.6
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1            POR CUENTA DE HINOVE AGROCIENCIA S.A.
# largo de aux2:  2
# caso 1
# dentro  1025301
# Comprobante  12
# 1025312
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025312        D     10    5896
# 1    S      1025312        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  54880000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  54880000.0
#
#                                                Glosa  GlosaDetalle
# 0  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...           NaN
# 1  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...           NaN
# largo de aux2:  2
# caso 1
# dentro  1025312
# Comprobante  13
# 1025314
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025314        D     10    5896
# 1    S      1025314        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1715.0
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1715.0
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046552-2022)
# largo de aux2:  2
# caso 1
# dentro  1025314
# Comprobante  14
# 1025315
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025315        D    405    7329
# 1    S      1025315        H     10    5896
#
#                                           Movimiento         MN  \
# 0  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...  385861.28
# 1  NEW YORK - CTA. 3544020682001                 ...  385861.28
#
#                                                Glosa  \
# 0  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 1  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
#
#                                         GlosaDetalle
# 0  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 1  PAGO N°1 LC I-2021-28 P/C ENVIBOL A/F KONE IND...
# largo de aux2:  2
# caso 4
# dentro  1025315
# Comprobante  15
# 1025316
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh      mo  moneda  \
# 0    S                         SWIFT N° 1731 DE LA FECHA.  H   25.00      53
# 1    S  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...  D  199.02      69
# 2    S  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...  D   50.00      69
# 3    S                                                NaN  H   43.50      69
# 4    S                                                NaN  H    2.86      69
#
#    codMov                                             nomMov      mn  \
# 0    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...  196.16
# 1     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  199.02
# 2     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...   50.00
# 3    1514  UTILES DE ESCRITORIO                          ...   43.50
# 4    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.86
#
#                                                glosa  comprobante  mayor
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316     10
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    412
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    412
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    600
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025316        H     10    6072
# 1    S      1025316        D    412     818
# 2    S      1025316        D    412     818
# 3    S      1025316        H    600    1514
# 4    S      1025316        H    680    6890
#
#                                           Movimiento      MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  196.16
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  199.02
# 2  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...   50.00
# 3  UTILES DE ESCRITORIO                          ...   43.50
# 4  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.86
#
#                                                Glosa  \
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
#
#                                         GlosaDetalle
# 0                         SWIFT N° 1731 DE LA FECHA.
# 1  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...
# 2  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  16
# 1025332
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh     mo  moneda  codMov  \
# 0    S          NaN  D  11.78      34    5896
#
#                                               nomMov     mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  80.81
#
#                                                glosa  comprobante  mayor
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...      1025332     10
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025332        D     10    5896
#
#                                           Movimiento     MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  80.81
#
#                                                Glosa  GlosaDetalle
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...           NaN
# entramos con 1
# caso 5
# dentro  1025332
# Comprobante  17
# 1025334
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh     mo  moneda  codMov  \
# 0    S          NaN  D  72.78      34    5896
#
#                                               nomMov      mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  499.27
#
#                                                glosa  comprobante  mayor
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...      1025334     10
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025334        D     10    5896
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  499.27
#
#                                                Glosa  GlosaDetalle
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...           NaN
# entramos con 1
# caso 5
# dentro  1025334
# Comprobante  18
# 1777343
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777343        D     10    5896
# 1    G      1777343        H    404    7164
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1809868.17
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  1809868.17
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777343
# Comprobante  19
# 1777345
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777345        D     10    5896
# 1    G      1777345        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  390379.96
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  390379.96
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777345
# Comprobante  20
# 1777347
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777347        D     10    5896
# 1    G      1777347        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  862797.02
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  862797.02
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777347
# Comprobante  21
# 1777480
# Hay duplicado:  True
# aux4
# [0, 4]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777480        D    498    6818
# 1    G      1777480        H     10    5896
#
#                                           Movimiento      MN  \
# 0  DEPOSITOS SECTOR PUBLICO - OP. CAMBIARIAS     ...  3292.8
# 1  NEW YORK - CTA. 3544020682001                 ...  3292.8
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  HECTOR FERNANDO SIAS MONTESINOS, CTA. 68600150...
# mas de 2
# largo cuando dentra al debehaber:  6
# Comprobante  22
# 1777481
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh          mo  \
# 0    G  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...  H   152675.37
# 1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D     1317.38
# 2    G                                                NaN  D  1062620.57
# 3    G                                                NaN  H      191.40
# 4    G                                                NaN  H       43.50
# 5    G                                                NaN  H      911.22
# 6    G                                                NaN  H    15267.54
#
#    moneda  codMov                                             nomMov  \
# 0      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 3      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 4      69    1514  UTILES DE ESCRITORIO                          ...
# 5      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 6      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#            mn                                              glosa  comprobante  \
# 0  1047353.04  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 1     1317.38  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 2  1062620.57  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 3      191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 4       43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 5      911.22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 6    15267.54  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
#
#    mayor
# 0     10
# 1    412
# 2    498
# 3    600
# 4    600
# 5    650
# 6    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777481        H     10    5896
# 1    G      1777481        D    412    3987
# 2    G      1777481        D    498    4088
# 3    G      1777481        H    600    1510
# 4    G      1777481        H    600    1514
# 5    G      1777481        H    650    1563
# 6    G      1777481        H    680    6890
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1047353.04
# 1  CUENTA UNICA DEL TESORO                       ...     1317.38
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1062620.57
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      911.22
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    15267.54
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  23
# 1777482
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh        mo  \
# 0    G  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...  H   2000.00
# 1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D    283.72
# 2    G                                                NaN  D  13920.00
# 3    G                                                NaN  H    191.40
# 4    G                                                NaN  H     43.50
# 5    G                                                NaN  H     11.94
# 6    G                                                NaN  H    200.00
#
#    moneda  codMov                                             nomMov  \
# 0      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 3      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 4      69    1514  UTILES DE ESCRITORIO                          ...
# 5      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 6      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#          mn                                              glosa  comprobante  \
# 0  13720.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 1    283.72  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 2  13920.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 3    191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 4     43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 5     11.94  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 6    200.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
#
#    mayor
# 0     10
# 1    412
# 2    498
# 3    600
# 4    600
# 5    650
# 6    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777482        H     10    5896
# 1    G      1777482        D    412    3987
# 2    G      1777482        D    498    4088
# 3    G      1777482        H    600    1510
# 4    G      1777482        H    600    1514
# 5    G      1777482        H    650    1563
# 6    G      1777482        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  13720.00
# 1  CUENTA UNICA DEL TESORO                       ...    283.72
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  13920.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     11.94
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    200.00
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  24
# 1777483
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777483        D     10    5896
# 1    G      1777483        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  6860000.0
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  6860000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 1  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIBRETA N° 00287104321 FPS-U$-MIAGUA V - CAF  ...
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  25
# 1777620
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777620        D     10    5896
# 1    G      1777620        H    404    6215
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  5229980.58
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  5229980.58
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777620
# Comprobante  26
# 1777623
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777623        D     10    5896
# 1    G      1777623        H    404    6215
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  8912366.64
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  8912366.64
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777623
# Comprobante  27
# 1777626
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777626        D     10    5896
# 1    G      1777626        H    404    6215
#
#                                           Movimiento           MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10623426.53
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  10623426.53
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777626
# Comprobante  28
# 1777629
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777629        D     10    5896
# 1    G      1777629        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  2144436.0
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  2144436.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
#
#                                 GlosaDetalle
# 0                                        NaN
# 1  LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# largo de aux2:  2
# caso 1
# dentro  1777629
# Comprobante  29
# 1777631
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777631        D     10    5896
# 1    G      1777631        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  434630.94
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  434630.94
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777631
# Comprobante  30
# 1777633
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777633        D     10    5896
# 1    G      1777633        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  150597.58
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  150597.58
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# largo de aux2:  2
# caso 1
# dentro  1777633
# Comprobante  31
# 1777765
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777765        D     10    5896
# 1    G      1777765        H    403    3907
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  43719.26
# 1  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  43719.26
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
#
#                      GlosaDetalle
# 0                             NaN
# 1  4010612801 EMBAJADA DE ECUADOR
# largo de aux2:  2
# caso 1
# dentro  1777765
# Comprobante  32
# 1777767
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777767        D     17    6296
# 1    G      1777767        H    606    6538
#
#                                           Movimiento       MN  \
# 0  INTERESES DEVENGADOS                          ...  41552.5
# 1  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...  41552.5
#
#                                                Glosa  GlosaDetalle
# 0  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...           NaN
# 1  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...           NaN
# largo de aux2:  2
# caso 1
# dentro  1777767
# Comprobante  33
# 1777769
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777769        D    499    7355
# 1    G      1777769        H     16    6758
#
#                                           Movimiento          MN  \
# 0  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  4838139.01
# 1  TITULOS - PORTAFOLIO GLOBAL                   ...  4838139.01
#
#                                                Glosa  GlosaDetalle
# 0  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...           NaN
# 1  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...           NaN
# largo de aux2:  2
# caso 4
# dentro  1777769
# Comprobante  34
# 1996851
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996851        D    403    7191
# 1    O      1996851        H      7    3491
#
#                                           Movimiento        MN  \
# 0  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...  686000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  686000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...           NaN
# largo de aux2:  2
# caso 4
# dentro  1996851
# Comprobante  35
# 1996852
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996852        D    403    3907
# 1    O      1996852        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...           NaN
# largo de aux2:  2
# caso 4
# dentro  1996852
# Comprobante  36
# 1996865
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996865        D    403    3906
# 1    O      1996865        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  48020000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  48020000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...           NaN
# largo de aux2:  2
# caso 4
# dentro  1996865
# Comprobante  37
# 1996906
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996906        D    403    6893
# 1    O      1996906        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...           NaN
# largo de aux2:  2
# caso 4
# dentro  1996906
# Comprobante  38
# 1996980
# Hay duplicado:  True
# aux4
# [1, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    H      1996980        H    828    3559
# 1    H      1996980        H      7    8085
#
#                                           Movimiento        MN  \
# 0  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...  137200.0
# 1  DOLARES ESTADOUNIDENSES - MANDATO BUSA        ...  137200.0
#
#                                                Glosa  GlosaDetalle
# 0  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# 1  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# mas de 2
# largo cuando dentra al debehaber:  4
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     S         2178   Egreso      10     485    5782
# 1     S         5545   Egreso      10     485    5782
# 2     D        21859  Ingreso      22     498    1470
# 3     V        28482  Ingreso     306      17    6296
# 4     S      1025269  Ingreso      11     606    1535
# 5     S      1025272  Ingreso      10     412    3987
# 6     S      1025273  Ingreso      10     404    7954
# 7     S      1025275  Ingreso      10     404    7954
# 8     S      1025283  Ingreso      10     498    8304
# 9     S      1025289   Egreso      10     412    3987
# 10    S      1025295  Ingreso      16     499    7355
# 11    S      1025301  Ingreso      10     404    7954
# 12    S      1025312  Ingreso      10     414    7866
# 13    S      1025314  Ingreso      10     498    8304
# 14    S      1025315   Egreso      10     405    7329
# 15    S      1025316   Egreso      10     412     818
# 16    S      1025332  Ingreso      10      10    5896
# 17    S      1025334  Ingreso      10      10    5896
# 18    G      1777343  Ingreso      10     404    7164
# 19    G      1777345  Ingreso      10     404    7164
# 20    G      1777347  Ingreso      10     404    7164
# 21    G      1777480   Egreso     498     404    6498
# 22    G      1777481   Egreso      10     412    3987
# 23    G      1777482   Egreso      10     412    3987
# 24    G      1777483  Ingreso      10     412    3987
# 25    G      1777620  Ingreso      10     404    6215
# 26    G      1777623  Ingreso      10     404    6215
# 27    G      1777626  Ingreso      10     404    6215
# 28    G      1777629  Ingreso      10     412    5970
# 29    G      1777631  Ingreso      10     404    7164
# 30    G      1777633  Ingreso      10     412    5970
# 31    G      1777765  Ingreso      10     403    3907
# 32    G      1777767  Ingreso      17     606    6538
# 33    G      1777769   Egreso      16     499    7355
# 34    O      1996851   Egreso       7     403    7191
# 35    O      1996852   Egreso       7     403    3907
# 36    O      1996865   Egreso       7     403    3906
# 37    O      1996906   Egreso       7     403    6893
# 38    H      1996980   Egreso     198     828    3559
#
#                                            Movimiento    MontoUSD  \
# 0   PROVISIONES PARA COMISIONES AL CUSTODIO       ...       94.24
# 1   PROVISIONES PARA COMISIONES AL CUSTODIO       ...      582.20
# 2   ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...        0.01
# 3   INTERESES DEVENGADOS                          ...  7749695.03
# 4   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     2242.85
# 5   CUENTA UNICA DEL TESORO                       ...    25833.67
# 6   YPFB - EXPORTACION DE UREA Y OTROS            ...  2967000.00
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...  3027000.00
# 8   ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 9   CUENTA UNICA DEL TESORO                       ...      105.11
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  YPFB - EXPORTACION DE UREA Y OTROS            ...   517860.00
# 12  EFECTIVO GARANTIA FONDO CPVIS                 ...  8000000.00
# 13  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      250.00
# 14  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...    56248.00
# 15  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...       28.59
# 16  NEW YORK - CTA. 3544020682001                 ...       11.78
# 17  NEW YORK - CTA. 3544020682001                 ...       72.78
# 18  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   263829.18
# 19  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    56906.70
# 20  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   125772.16
# 21  TAB TRANSPORTES AEREOS BOLIVIANOS             ...      480.00
# 22  CUENTA UNICA DEL TESORO                       ...   152675.37
# 23  CUENTA UNICA DEL TESORO                       ...     2000.00
# 24  CUENTA UNICA DEL TESORO                       ...  1000000.00
# 25  EMPRESA METALURGICA VINTO (EMV)               ...   762387.84
# 26  EMPRESA METALURGICA VINTO (EMV)               ...  1299178.81
# 27  EMPRESA METALURGICA VINTO (EMV)               ...  1548604.45
# 28  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   312600.00
# 29  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    63357.28
# 30  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    21953.00
# 31  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...     6373.07
# 32  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...     6057.22
# 33  VALORACION TITULOS DE LAS RESERVAS INTERNACION...   705268.08
# 34  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...   100000.00
# 35  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  5000000.00
# 36  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  7000000.00
# 37  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 38  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
#
#                                               Detalle  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Saldo ME = 93567.36 ;Bs/Mo: 6.86000000000 ;Sal...
# 3   Saldo Ant.= -66098.00 ;Bs: 9.59837480000 = $us...
# 4                                                 NaN
# 5   A LA CUENTA DIREC.GRAL. AERONAUTICA CIVIL-RECU...
# 6   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 7   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 8                                (CC:H-0046550-2022)
# 9   TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 10                                                NaN
# 11              POR CUENTA DE HINOVE AGROCIENCIA S.A.
# 12                                                NaN
# 13                               (CC:H-0046552-2022)
# 14  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 15                         SWIFT N° 1731 DE LA FECHA.
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 23  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28          LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# 29                                                NaN
# 30  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 31                     4010612801 EMBAJADA DE ECUADOR
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                                 Glosa
# 0   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 1   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 2   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 3   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 4   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 9   ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 12  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...
# 13  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 14  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 15  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 16  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...
# 17  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...
# 20  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...
# 21  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 23  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 24  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...
# 27  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...
# 28  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 29  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...
# 30  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 31  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 32  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...
# 33  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...
# 34  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...
# 35  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...
# 36  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...
# 37  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...
# 38  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas1=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    data2=[]
    columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        #data2=[]
        #columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        ########## RRRRRRRRRRRR
        debemenoshaber(aux2.index)
        ########## RRRRRRRRRRRR   
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            if len(aux4)==2:
                for x in range(len(aux4)):

                    data1.append({
                        "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                        "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                        "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                                })
                    pares=pd.DataFrame(data1,columns=columnas1)
                #################### 1
                print("largo de aux2: ",len(aux2))
                print(pares)
                ###########
                #data2=[]
                #columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                ##########
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                    #print("Posible Neteo")
                    llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                    unRegistro=pd.DataFrame(data2,columns=columnas2)
                else:     
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                        print('caso 1')
                        llenarData("Ingreso",0,1)        
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                        print('caso 2')
                        llenarData("Egreso",0,1)                   
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                        print('caso 3')
                        llenarData("Ingreso",1,0)                    
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                        print('caso 4')
                        llenarData("Egreso",1,0)
            else:
                
                #@#@#@#@#@#@#
                #data2=[]
                #columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
               
                ####BBBBBBBBBBBBBBBBBBB
                debemenoshaber(range(len(aux2)))
                ####BBBBBBBBBBBBBBBBBBB
                #@#@#@#@#@#@#
            #################### 1

        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)
            ################### 2
            print(pares)
            #data2=[]
            #columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
            
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                
                
                #data2=[]
                #columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                ######### HHHHHHH
               # if len(aux2)==3 and aux2["mayor"][0] in cuentas and aux2["mayor"][1] in cuentas and aux2["mayor"][2]==680:
               #     llenarData("Neteo",0,1)
               # else:
                debemenoshaber(range(len(aux2)))
               
                ######### HHHHHHH 
            ################### 2
            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares ',pares["Comprobante"][0])
            
        ###$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
        ##### $$$$$$$$$$$$$$$
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado

#consolidado.to_excel("borrar10ene.xlsx")
# Out:
# Comprobante  0
# 2178
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S         2178        D    485    5782
# 1    S         2178        H     10    7266
#
#                                           Movimiento      MN  \
# 0  PROVISIONES PARA COMISIONES AL CUSTODIO       ...  646.49
# 1  CTA. P99828-AG530 PORTAFOLIO FPA              ...  646.49
#
#                                                Glosa  GlosaDetalle
# 0  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# 1  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# caso 4
# dentro  2178
# Comprobante  1
# 5545
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S         5545        D    485    5782
# 1    S         5545        H     10    7038
#
#                                           Movimiento       MN  \
# 0  PROVISIONES PARA COMISIONES AL CUSTODIO       ...  3993.89
# 1  CTA. 0728162841 PORTAFOLIO FPAH               ...  3993.89
#
#                                                Glosa  GlosaDetalle
# 0  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# 1  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# caso 4
# dentro  5545
# Comprobante  2
# 21859
# largo cuando dentra al debehaber:  26
# Comprobante  3
# 28482
# largo cuando dentra al debehaber:  19
# Comprobante  4
# 1025269
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025269        D     11    2902
# 1    S      1025269        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  15385.95
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  15385.95
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# caso 1
# dentro  1025269
# Comprobante  5
# 1025272
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025272        D     10    5896
# 1    S      1025272        H    412    8467
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  177218.98
# 1  DIREC.GRAL.AERONAUTICA CIVIL-RECURSOS ESPECIFI...  177218.98
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
#
#                                         GlosaDetalle
# 0  A LA CUENTA DIREC.GRAL. AERONAUTICA CIVIL-RECU...
# 1                 P. CTA. DE IATA INTERNATIONAL AIR.
# caso 1
# dentro  1025272
# Comprobante  6
# 1025273
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025273        D     10    5896
# 1    S      1025273        H    404    7954
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  20353620.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  20353620.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# caso 1
# dentro  1025273
# Comprobante  7
# 1025275
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025275        D     10    5896
# 1    S      1025275        H    404    7954
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  20765220.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  20765220.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# caso 1
# dentro  1025275
# Comprobante  8
# 1025283
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025283        D     10    5896
# 1    S      1025283        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1543.5
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1543.5
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046550-2022)
# caso 1
# dentro  1025283
# Comprobante  9
# 1025289
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh      mo  moneda  \
# 0    S  TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...  H  105.11      34
# 1    S  CGO.LIB.00099021001 TGN RECURSOS ORDINARIOS CO...  D  270.75      69
# 2    S  LIBRETA 00099021001 TGN RECURSOS ORDINARIOS DO...  D  120.12      34
# 3    S                                                NaN  H  191.40      69
# 4    S                                                NaN  H   43.50      69
# 5    S                                                NaN  H    0.65      69
#
#    codMov                                             nomMov      mn  \
# 0    5896  NEW YORK - CTA. 3544020682001                 ...  721.05
# 1    3987  CUENTA UNICA DEL TESORO                       ...  270.75
# 2    5970  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  824.02
# 3    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...  191.40
# 4    1514  UTILES DE ESCRITORIO                          ...   43.50
# 5    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...    0.65
#
#                                                glosa  comprobante  mayor
# 0  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289     10
# 1  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    412
# 2  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    412
# 3  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    600
# 4  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    600
# 5  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    650
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025289        H     10    5896
# 1    S      1025289        D    412    3987
# 2    S      1025289        D    412    5970
# 3    S      1025289        H    600    1510
# 4    S      1025289        H    600    1514
# 5    S      1025289        H    650    1563
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  721.05
# 1  CUENTA UNICA DEL TESORO                       ...  270.75
# 2  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  824.02
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...  191.40
# 4  UTILES DE ESCRITORIO                          ...   43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...    0.65
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 1  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 2  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 3  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 4  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 5  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
#
#                                         GlosaDetalle
# 0  TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 1  CGO.LIB.00099021001 TGN RECURSOS ORDINARIOS CO...
# 2  LIBRETA 00099021001 TGN RECURSOS ORDINARIOS DO...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  6
# Comprobante  10
# 1025295
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025295        D     16    6286
# 1    S      1025295        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# caso 1
# dentro  1025295
# Comprobante  11
# 1025301
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025301        D     10    5896
# 1    S      1025301        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3552519.6
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  3552519.6
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1            POR CUENTA DE HINOVE AGROCIENCIA S.A.
# caso 1
# dentro  1025301
# Comprobante  12
# 1025312
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025312        D     10    5896
# 1    S      1025312        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  54880000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  54880000.0
#
#                                                Glosa  GlosaDetalle
# 0  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...           NaN
# 1  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...           NaN
# caso 1
# dentro  1025312
# Comprobante  13
# 1025314
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025314        D     10    5896
# 1    S      1025314        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1715.0
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1715.0
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046552-2022)
# caso 1
# dentro  1025314
# Comprobante  14
# 1025315
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025315        D    405    7329
# 1    S      1025315        H     10    5896
#
#                                           Movimiento         MN  \
# 0  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...  385861.28
# 1  NEW YORK - CTA. 3544020682001                 ...  385861.28
#
#                                                Glosa  \
# 0  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 1  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
#
#                                         GlosaDetalle
# 0  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 1  PAGO N°1 LC I-2021-28 P/C ENVIBOL A/F KONE IND...
# caso 4
# dentro  1025315
# Comprobante  15
# 1025316
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh      mo  moneda  \
# 0    S                         SWIFT N° 1731 DE LA FECHA.  H   25.00      53
# 1    S  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...  D  199.02      69
# 2    S  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...  D   50.00      69
# 3    S                                                NaN  H   43.50      69
# 4    S                                                NaN  H    2.86      69
#
#    codMov                                             nomMov      mn  \
# 0    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...  196.16
# 1     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  199.02
# 2     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...   50.00
# 3    1514  UTILES DE ESCRITORIO                          ...   43.50
# 4    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.86
#
#                                                glosa  comprobante  mayor
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316     10
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    412
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    412
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    600
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025316        H     10    6072
# 1    S      1025316        D    412     818
# 2    S      1025316        D    412     818
# 3    S      1025316        H    600    1514
# 4    S      1025316        H    680    6890
#
#                                           Movimiento      MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  196.16
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  199.02
# 2  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...   50.00
# 3  UTILES DE ESCRITORIO                          ...   43.50
# 4  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.86
#
#                                                Glosa  \
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
#
#                                         GlosaDetalle
# 0                         SWIFT N° 1731 DE LA FECHA.
# 1  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...
# 2  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  16
# 1025332
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh     mo  moneda  codMov  \
# 0    S          NaN  D  11.78      34    5896
#
#                                               nomMov     mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  80.81
#
#                                                glosa  comprobante  mayor
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...      1025332     10
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025332        D     10    5896
#
#                                           Movimiento     MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  80.81
#
#                                                Glosa  GlosaDetalle
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...           NaN
# entramos con 1
# caso 5
# dentro  1025332
# Comprobante  17
# 1025334
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh     mo  moneda  codMov  \
# 0    S          NaN  D  72.78      34    5896
#
#                                               nomMov      mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  499.27
#
#                                                glosa  comprobante  mayor
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...      1025334     10
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025334        D     10    5896
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  499.27
#
#                                                Glosa  GlosaDetalle
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...           NaN
# entramos con 1
# caso 5
# dentro  1025334
# Comprobante  18
# 1777343
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777343        D     10    5896
# 1    G      1777343        H    404    7164
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1809868.17
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  1809868.17
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...           NaN
# caso 1
# dentro  1777343
# Comprobante  19
# 1777345
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777345        D     10    5896
# 1    G      1777345        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  390379.96
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  390379.96
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...           NaN
# caso 1
# dentro  1777345
# Comprobante  20
# 1777347
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777347        D     10    5896
# 1    G      1777347        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  862797.02
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  862797.02
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...           NaN
# caso 1
# dentro  1777347
# Comprobante  21
# 1777480
# Hay duplicado:  True
# aux4
# [0, 4]
# largo de aux2:  6
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777480        D    498    6818
# 1    G      1777480        H     10    5896
#
#                                           Movimiento      MN  \
# 0  DEPOSITOS SECTOR PUBLICO - OP. CAMBIARIAS     ...  3292.8
# 1  NEW YORK - CTA. 3544020682001                 ...  3292.8
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  HECTOR FERNANDO SIAS MONTESINOS, CTA. 68600150...
# caso 4
# dentro  1777480
# Comprobante  22
# 1777481
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh          mo  \
# 0    G  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...  H   152675.37
# 1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D     1317.38
# 2    G                                                NaN  D  1062620.57
# 3    G                                                NaN  H      191.40
# 4    G                                                NaN  H       43.50
# 5    G                                                NaN  H      911.22
# 6    G                                                NaN  H    15267.54
#
#    moneda  codMov                                             nomMov  \
# 0      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 3      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 4      69    1514  UTILES DE ESCRITORIO                          ...
# 5      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 6      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#            mn                                              glosa  comprobante  \
# 0  1047353.04  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 1     1317.38  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 2  1062620.57  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 3      191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 4       43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 5      911.22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 6    15267.54  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
#
#    mayor
# 0     10
# 1    412
# 2    498
# 3    600
# 4    600
# 5    650
# 6    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777481        H     10    5896
# 1    G      1777481        D    412    3987
# 2    G      1777481        D    498    4088
# 3    G      1777481        H    600    1510
# 4    G      1777481        H    600    1514
# 5    G      1777481        H    650    1563
# 6    G      1777481        H    680    6890
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1047353.04
# 1  CUENTA UNICA DEL TESORO                       ...     1317.38
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1062620.57
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      911.22
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    15267.54
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  23
# 1777482
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh        mo  \
# 0    G  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...  H   2000.00
# 1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D    283.72
# 2    G                                                NaN  D  13920.00
# 3    G                                                NaN  H    191.40
# 4    G                                                NaN  H     43.50
# 5    G                                                NaN  H     11.94
# 6    G                                                NaN  H    200.00
#
#    moneda  codMov                                             nomMov  \
# 0      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 3      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 4      69    1514  UTILES DE ESCRITORIO                          ...
# 5      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 6      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#          mn                                              glosa  comprobante  \
# 0  13720.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 1    283.72  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 2  13920.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 3    191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 4     43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 5     11.94  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 6    200.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
#
#    mayor
# 0     10
# 1    412
# 2    498
# 3    600
# 4    600
# 5    650
# 6    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777482        H     10    5896
# 1    G      1777482        D    412    3987
# 2    G      1777482        D    498    4088
# 3    G      1777482        H    600    1510
# 4    G      1777482        H    600    1514
# 5    G      1777482        H    650    1563
# 6    G      1777482        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  13720.00
# 1  CUENTA UNICA DEL TESORO                       ...    283.72
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  13920.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     11.94
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    200.00
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  24
# 1777483
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777483        D     10    5896
# 1    G      1777483        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  6860000.0
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  6860000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 1  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIBRETA N° 00287104321 FPS-U$-MIAGUA V - CAF  ...
# caso 1
# dentro  1777483
# Comprobante  25
# 1777620
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777620        D     10    5896
# 1    G      1777620        H    404    6215
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  5229980.58
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  5229980.58
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...           NaN
# caso 1
# dentro  1777620
# Comprobante  26
# 1777623
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777623        D     10    5896
# 1    G      1777623        H    404    6215
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  8912366.64
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  8912366.64
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...           NaN
# caso 1
# dentro  1777623
# Comprobante  27
# 1777626
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777626        D     10    5896
# 1    G      1777626        H    404    6215
#
#                                           Movimiento           MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10623426.53
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  10623426.53
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...           NaN
# caso 1
# dentro  1777626
# Comprobante  28
# 1777629
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777629        D     10    5896
# 1    G      1777629        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  2144436.0
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  2144436.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
#
#                                 GlosaDetalle
# 0                                        NaN
# 1  LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# caso 1
# dentro  1777629
# Comprobante  29
# 1777631
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777631        D     10    5896
# 1    G      1777631        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  434630.94
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  434630.94
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...           NaN
# caso 1
# dentro  1777631
# Comprobante  30
# 1777633
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777633        D     10    5896
# 1    G      1777633        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  150597.58
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  150597.58
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# caso 1
# dentro  1777633
# Comprobante  31
# 1777765
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777765        D     10    5896
# 1    G      1777765        H    403    3907
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  43719.26
# 1  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  43719.26
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
#
#                      GlosaDetalle
# 0                             NaN
# 1  4010612801 EMBAJADA DE ECUADOR
# caso 1
# dentro  1777765
# Comprobante  32
# 1777767
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777767        D     17    6296
# 1    G      1777767        H    606    6538
#
#                                           Movimiento       MN  \
# 0  INTERESES DEVENGADOS                          ...  41552.5
# 1  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...  41552.5
#
#                                                Glosa  GlosaDetalle
# 0  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...           NaN
# 1  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...           NaN
# caso 1
# dentro  1777767
# Comprobante  33
# 1777769
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777769        D    499    7355
# 1    G      1777769        H     16    6758
#
#                                           Movimiento          MN  \
# 0  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  4838139.01
# 1  TITULOS - PORTAFOLIO GLOBAL                   ...  4838139.01
#
#                                                Glosa  GlosaDetalle
# 0  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...           NaN
# 1  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...           NaN
# caso 4
# dentro  1777769
# Comprobante  34
# 1996851
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996851        D    403    7191
# 1    O      1996851        H      7    3491
#
#                                           Movimiento        MN  \
# 0  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...  686000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  686000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1996851
# Comprobante  35
# 1996852
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996852        D    403    3907
# 1    O      1996852        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1996852
# Comprobante  36
# 1996865
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996865        D    403    3906
# 1    O      1996865        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  48020000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  48020000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1996865
# Comprobante  37
# 1996906
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996906        D    403    6893
# 1    O      1996906        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...           NaN
# caso 4
# dentro  1996906
# Comprobante  38
# 1996980
# Hay duplicado:  True
# aux4
# [1, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    H      1996980        H    828    3559
# 1    H      1996980        H      7    8085
#
#                                           Movimiento        MN  \
# 0  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...  137200.0
# 1  DOLARES ESTADOUNIDENSES - MANDATO BUSA        ...  137200.0
#
#                                                Glosa  GlosaDetalle
# 0  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# 1  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# caso 4
# dentro  1996980
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     S         2178   Egreso      10     485    5782
# 1     S         5545   Egreso      10     485    5782
# 2     D        21859  Ingreso      22     498    1470
# 3     V        28482  Ingreso     306      17    6296
# 4     S      1025269  Ingreso      11     606    1535
# 5     S      1025272  Ingreso      10     412    8467
# 6     S      1025273  Ingreso      10     404    7954
# 7     S      1025275  Ingreso      10     404    7954
# 8     S      1025283  Ingreso      10     498    8304
# 9     S      1025289   Egreso      10     412    3987
# 10    S      1025295  Ingreso      16     499    7355
# 11    S      1025301  Ingreso      10     404    7954
# 12    S      1025312  Ingreso      10     414    7866
# 13    S      1025314  Ingreso      10     498    8304
# 14    S      1025315   Egreso      10     405    7329
# 15    S      1025316   Egreso      10     412     818
# 16    S      1025332  Ingreso      10      10    5896
# 17    S      1025334  Ingreso      10      10    5896
# 18    G      1777343  Ingreso      10     404    7164
# 19    G      1777345  Ingreso      10     404    7164
# 20    G      1777347  Ingreso      10     404    7164
# 21    G      1777480   Egreso      10     498    6818
# 22    G      1777481   Egreso      10     412    3987
# 23    G      1777482   Egreso      10     412    3987
# 24    G      1777483  Ingreso      10     412    5970
# 25    G      1777620  Ingreso      10     404    6215
# 26    G      1777623  Ingreso      10     404    6215
# 27    G      1777626  Ingreso      10     404    6215
# 28    G      1777629  Ingreso      10     412    5970
# 29    G      1777631  Ingreso      10     404    7164
# 30    G      1777633  Ingreso      10     412    5970
# 31    G      1777765  Ingreso      10     403    3907
# 32    G      1777767  Ingreso      17     606    6538
# 33    G      1777769   Egreso      16     499    7355
# 34    O      1996851   Egreso       7     403    7191
# 35    O      1996852   Egreso       7     403    3907
# 36    O      1996865   Egreso       7     403    3906
# 37    O      1996906   Egreso       7     403    6893
# 38    H      1996980   Egreso       7     828    3559
#
#                                            Movimiento    MontoUSD  \
# 0   PROVISIONES PARA COMISIONES AL CUSTODIO       ...       94.24
# 1   PROVISIONES PARA COMISIONES AL CUSTODIO       ...      582.20
# 2   ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...        0.01
# 3   INTERESES DEVENGADOS                          ...  7749695.03
# 4   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     2242.85
# 5   DIREC.GRAL.AERONAUTICA CIVIL-RECURSOS ESPECIFI...    25833.67
# 6   YPFB - EXPORTACION DE UREA Y OTROS            ...  2967000.00
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...  3027000.00
# 8   ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 9   CUENTA UNICA DEL TESORO                       ...      105.11
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  YPFB - EXPORTACION DE UREA Y OTROS            ...   517860.00
# 12  EFECTIVO GARANTIA FONDO CPVIS                 ...  8000000.00
# 13  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      250.00
# 14  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...    56248.00
# 15  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...       28.59
# 16  NEW YORK - CTA. 3544020682001                 ...       11.78
# 17  NEW YORK - CTA. 3544020682001                 ...       72.78
# 18  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   263829.18
# 19  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    56906.70
# 20  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   125772.16
# 21  DEPOSITOS SECTOR PUBLICO - OP. CAMBIARIAS     ...      480.00
# 22  CUENTA UNICA DEL TESORO                       ...   152675.37
# 23  CUENTA UNICA DEL TESORO                       ...     2000.00
# 24  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  1000000.00
# 25  EMPRESA METALURGICA VINTO (EMV)               ...   762387.84
# 26  EMPRESA METALURGICA VINTO (EMV)               ...  1299178.81
# 27  EMPRESA METALURGICA VINTO (EMV)               ...  1548604.45
# 28  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   312600.00
# 29  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    63357.28
# 30  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    21953.00
# 31  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...     6373.07
# 32  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...     6057.22
# 33  VALORACION TITULOS DE LAS RESERVAS INTERNACION...   705268.08
# 34  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...   100000.00
# 35  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  5000000.00
# 36  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  7000000.00
# 37  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 38  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
#
#                                               Detalle  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Saldo ME = 93567.36 ;Bs/Mo: 6.86000000000 ;Sal...
# 3   Saldo Ant.= -66098.00 ;Bs: 9.59837480000 = $us...
# 4                                                 NaN
# 5                  P. CTA. DE IATA INTERNATIONAL AIR.
# 6   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 7   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 8                                (CC:H-0046550-2022)
# 9   TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 10                                                NaN
# 11              POR CUENTA DE HINOVE AGROCIENCIA S.A.
# 12                                                NaN
# 13                               (CC:H-0046552-2022)
# 14  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 15                         SWIFT N° 1731 DE LA FECHA.
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 23  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 24  LIBRETA N° 00287104321 FPS-U$-MIAGUA V - CAF  ...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28          LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# 29                                                NaN
# 30  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 31                     4010612801 EMBAJADA DE ECUADOR
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                                 Glosa
# 0   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 1   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 2   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 3   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 4   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 9   ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 12  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...
# 13  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 14  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 15  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 16  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...
# 17  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...
# 20  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...
# 21  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 23  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 24  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...
# 27  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...
# 28  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 29  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...
# 30  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 31  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 32  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...
# 33  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...
# 34  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...
# 35  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...
# 36  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...
# 37  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...
# 38  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...

# %%
texto1 = "PAGO A EXIMBANK CHINA POPUL PRÉSTAMO PBC 2015 (08) 350 VCTO. 21-01-2022 POR CUENTA DE TGN , NTI. 015626 VALOR 21-01-2022 CAPITAL USD 27.355.555,56 COMISIONES USD 260.358,75"
texto2= "PAGO A AFD PRÉSTAMO CBO-1009-01-J VCTO. 21-01-2022 POR CUENTA DE ENDE , VALOR 21-01-2022  INTERESES EUR 168.666,67"

#capital = re.findall(" CAPITAL (.*)(?= [IC])" , texto1)
capital = re.findall(" CAPITAL (.*)(?= [INTERESES][COMISIONES])" , texto1)
intereses = re.findall(" INTERESES (.*)(?=[C\s])" , texto1)
comisiones = re.findall(" COMISIONES (.*)" , texto1)

#t= pd.DataFrame(search)
#t
print(capital, intereses, comisiones)
# Out:
# [] [] ['USD 260.358,75']

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas1=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    data2=[]
    columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        debemenoshaber(aux2.index)
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            if len(aux4)==2:
                for x in range(len(aux4)):
                    data1.append({
                        "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                        "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                        "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                                })
                    pares=pd.DataFrame(data1,columns=columnas1)
                print("largo de aux2: ",len(aux2))
                print(pares)
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                    #print("Posible Neteo")
                    llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                    unRegistro=pd.DataFrame(data2,columns=columnas2)
                else:     
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                        print('caso 1')
                        llenarData("Ingreso",0,1)        
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                        print('caso 2')
                        llenarData("Egreso",0,1)                   
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                        print('caso 3')
                        llenarData("Ingreso",1,0)                    
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                        print('caso 4')
                        llenarData("Egreso",1,0)
            else:
                debemenoshaber(range(len(aux2)))
        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            for x in range(len(aux2)):
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)
            print(pares)
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                debemenoshaber(range(len(aux2)))
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar10ene.xlsx")
# Out:
# Comprobante  0
# 2178
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S         2178        D    485    5782
# 1    S         2178        H     10    7266
#
#                                           Movimiento      MN  \
# 0  PROVISIONES PARA COMISIONES AL CUSTODIO       ...  646.49
# 1  CTA. P99828-AG530 PORTAFOLIO FPA              ...  646.49
#
#                                                Glosa  GlosaDetalle
# 0  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# 1  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# caso 4
# dentro  2178
# Comprobante  1
# 5545
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S         5545        D    485    5782
# 1    S         5545        H     10    7038
#
#                                           Movimiento       MN  \
# 0  PROVISIONES PARA COMISIONES AL CUSTODIO       ...  3993.89
# 1  CTA. 0728162841 PORTAFOLIO FPAH               ...  3993.89
#
#                                                Glosa  GlosaDetalle
# 0  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# 1  ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...           NaN
# caso 4
# dentro  5545
# Comprobante  2
# 21859
# largo cuando dentra al debehaber:  26
# Comprobante  3
# 28482
# largo cuando dentra al debehaber:  19
# Comprobante  4
# 1025269
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025269        D     11    2902
# 1    S      1025269        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  15385.95
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  15385.95
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# caso 1
# dentro  1025269
# Comprobante  5
# 1025272
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025272        D     10    5896
# 1    S      1025272        H    412    8467
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  177218.98
# 1  DIREC.GRAL.AERONAUTICA CIVIL-RECURSOS ESPECIFI...  177218.98
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
#
#                                         GlosaDetalle
# 0  A LA CUENTA DIREC.GRAL. AERONAUTICA CIVIL-RECU...
# 1                 P. CTA. DE IATA INTERNATIONAL AIR.
# caso 1
# dentro  1025272
# Comprobante  6
# 1025273
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025273        D     10    5896
# 1    S      1025273        H    404    7954
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  20353620.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  20353620.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# caso 1
# dentro  1025273
# Comprobante  7
# 1025275
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025275        D     10    5896
# 1    S      1025275        H    404    7954
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  20765220.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  20765220.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# caso 1
# dentro  1025275
# Comprobante  8
# 1025283
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025283        D     10    5896
# 1    S      1025283        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1543.5
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1543.5
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046550-2022)
# caso 1
# dentro  1025283
# Comprobante  9
# 1025289
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh      mo  moneda  \
# 0    S  TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...  H  105.11      34
# 1    S  CGO.LIB.00099021001 TGN RECURSOS ORDINARIOS CO...  D  270.75      69
# 2    S  LIBRETA 00099021001 TGN RECURSOS ORDINARIOS DO...  D  120.12      34
# 3    S                                                NaN  H  191.40      69
# 4    S                                                NaN  H   43.50      69
# 5    S                                                NaN  H    0.65      69
#
#    codMov                                             nomMov      mn  \
# 0    5896  NEW YORK - CTA. 3544020682001                 ...  721.05
# 1    3987  CUENTA UNICA DEL TESORO                       ...  270.75
# 2    5970  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  824.02
# 3    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...  191.40
# 4    1514  UTILES DE ESCRITORIO                          ...   43.50
# 5    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...    0.65
#
#                                                glosa  comprobante  mayor
# 0  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289     10
# 1  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    412
# 2  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    412
# 3  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    600
# 4  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    600
# 5  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...      1025289    650
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025289        H     10    5896
# 1    S      1025289        D    412    3987
# 2    S      1025289        D    412    5970
# 3    S      1025289        H    600    1510
# 4    S      1025289        H    600    1514
# 5    S      1025289        H    650    1563
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  721.05
# 1  CUENTA UNICA DEL TESORO                       ...  270.75
# 2  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  824.02
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...  191.40
# 4  UTILES DE ESCRITORIO                          ...   43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...    0.65
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 1  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 2  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 3  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 4  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 5  ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
#
#                                         GlosaDetalle
# 0  TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 1  CGO.LIB.00099021001 TGN RECURSOS ORDINARIOS CO...
# 2  LIBRETA 00099021001 TGN RECURSOS ORDINARIOS DO...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  6
# Comprobante  10
# 1025295
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025295        D     16    6286
# 1    S      1025295        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# caso 1
# dentro  1025295
# Comprobante  11
# 1025301
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025301        D     10    5896
# 1    S      1025301        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3552519.6
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  3552519.6
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1            POR CUENTA DE HINOVE AGROCIENCIA S.A.
# caso 1
# dentro  1025301
# Comprobante  12
# 1025312
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025312        D     10    5896
# 1    S      1025312        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  54880000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  54880000.0
#
#                                                Glosa  GlosaDetalle
# 0  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...           NaN
# 1  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...           NaN
# caso 1
# dentro  1025312
# Comprobante  13
# 1025314
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025314        D     10    5896
# 1    S      1025314        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1715.0
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1715.0
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046552-2022)
# caso 1
# dentro  1025314
# Comprobante  14
# 1025315
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025315        D    405    7329
# 1    S      1025315        H     10    5896
#
#                                           Movimiento         MN  \
# 0  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...  385861.28
# 1  NEW YORK - CTA. 3544020682001                 ...  385861.28
#
#                                                Glosa  \
# 0  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 1  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
#
#                                         GlosaDetalle
# 0  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 1  PAGO N°1 LC I-2021-28 P/C ENVIBOL A/F KONE IND...
# caso 4
# dentro  1025315
# Comprobante  15
# 1025316
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh      mo  moneda  \
# 0    S                         SWIFT N° 1731 DE LA FECHA.  H   25.00      53
# 1    S  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...  D  199.02      69
# 2    S  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...  D   50.00      69
# 3    S                                                NaN  H   43.50      69
# 4    S                                                NaN  H    2.86      69
#
#    codMov                                             nomMov      mn  \
# 0    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...  196.16
# 1     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  199.02
# 2     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...   50.00
# 3    1514  UTILES DE ESCRITORIO                          ...   43.50
# 4    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.86
#
#                                                glosa  comprobante  mayor
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316     10
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    412
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    412
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    600
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025316    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025316        H     10    6072
# 1    S      1025316        D    412     818
# 2    S      1025316        D    412     818
# 3    S      1025316        H    600    1514
# 4    S      1025316        H    680    6890
#
#                                           Movimiento      MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  196.16
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  199.02
# 2  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...   50.00
# 3  UTILES DE ESCRITORIO                          ...   43.50
# 4  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.86
#
#                                                Glosa  \
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
#
#                                         GlosaDetalle
# 0                         SWIFT N° 1731 DE LA FECHA.
# 1  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...
# 2  CTA. 10000004713413 COMIBOL-EMPRESA MINERA COR...
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  16
# 1025332
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh     mo  moneda  codMov  \
# 0    S          NaN  D  11.78      34    5896
#
#                                               nomMov     mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  80.81
#
#                                                glosa  comprobante  mayor
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...      1025332     10
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025332        D     10    5896
#
#                                           Movimiento     MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  80.81
#
#                                                Glosa  GlosaDetalle
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...           NaN
# entramos con 1
# caso 5
# dentro  1025332
# Comprobante  17
# 1025334
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh     mo  moneda  codMov  \
# 0    S          NaN  D  72.78      34    5896
#
#                                               nomMov      mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  499.27
#
#                                                glosa  comprobante  mayor
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...      1025334     10
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025334        D     10    5896
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  499.27
#
#                                                Glosa  GlosaDetalle
# 0  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...           NaN
# entramos con 1
# caso 5
# dentro  1025334
# Comprobante  18
# 1777343
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777343        D     10    5896
# 1    G      1777343        H    404    7164
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1809868.17
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  1809868.17
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...           NaN
# caso 1
# dentro  1777343
# Comprobante  19
# 1777345
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777345        D     10    5896
# 1    G      1777345        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  390379.96
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  390379.96
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...           NaN
# caso 1
# dentro  1777345
# Comprobante  20
# 1777347
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777347        D     10    5896
# 1    G      1777347        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  862797.02
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  862797.02
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...           NaN
# caso 1
# dentro  1777347
# Comprobante  21
# 1777480
# Hay duplicado:  True
# aux4
# [0, 4]
# largo de aux2:  6
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777480        D    498    6818
# 1    G      1777480        H     10    5896
#
#                                           Movimiento      MN  \
# 0  DEPOSITOS SECTOR PUBLICO - OP. CAMBIARIAS     ...  3292.8
# 1  NEW YORK - CTA. 3544020682001                 ...  3292.8
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  HECTOR FERNANDO SIAS MONTESINOS, CTA. 68600150...
# caso 4
# dentro  1777480
# Comprobante  22
# 1777481
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh          mo  \
# 0    G  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...  H   152675.37
# 1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D     1317.38
# 2    G                                                NaN  D  1062620.57
# 3    G                                                NaN  H      191.40
# 4    G                                                NaN  H       43.50
# 5    G                                                NaN  H      911.22
# 6    G                                                NaN  H    15267.54
#
#    moneda  codMov                                             nomMov  \
# 0      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 3      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 4      69    1514  UTILES DE ESCRITORIO                          ...
# 5      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 6      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#            mn                                              glosa  comprobante  \
# 0  1047353.04  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 1     1317.38  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 2  1062620.57  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 3      191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 4       43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 5      911.22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
# 6    15267.54  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777481
#
#    mayor
# 0     10
# 1    412
# 2    498
# 3    600
# 4    600
# 5    650
# 6    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777481        H     10    5896
# 1    G      1777481        D    412    3987
# 2    G      1777481        D    498    4088
# 3    G      1777481        H    600    1510
# 4    G      1777481        H    600    1514
# 5    G      1777481        H    650    1563
# 6    G      1777481        H    680    6890
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1047353.04
# 1  CUENTA UNICA DEL TESORO                       ...     1317.38
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1062620.57
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      911.22
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    15267.54
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  23
# 1777482
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh        mo  \
# 0    G  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...  H   2000.00
# 1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D    283.72
# 2    G                                                NaN  D  13920.00
# 3    G                                                NaN  H    191.40
# 4    G                                                NaN  H     43.50
# 5    G                                                NaN  H     11.94
# 6    G                                                NaN  H    200.00
#
#    moneda  codMov                                             nomMov  \
# 0      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 3      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 4      69    1514  UTILES DE ESCRITORIO                          ...
# 5      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 6      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#          mn                                              glosa  comprobante  \
# 0  13720.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 1    283.72  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 2  13920.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 3    191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 4     43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 5     11.94  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
# 6    200.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1777482
#
#    mayor
# 0     10
# 1    412
# 2    498
# 3    600
# 4    600
# 5    650
# 6    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777482        H     10    5896
# 1    G      1777482        D    412    3987
# 2    G      1777482        D    498    4088
# 3    G      1777482        H    600    1510
# 4    G      1777482        H    600    1514
# 5    G      1777482        H    650    1563
# 6    G      1777482        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  13720.00
# 1  CUENTA UNICA DEL TESORO                       ...    283.72
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  13920.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     11.94
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    200.00
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  24
# 1777483
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777483        D     10    5896
# 1    G      1777483        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  6860000.0
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  6860000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 1  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIBRETA N° 00287104321 FPS-U$-MIAGUA V - CAF  ...
# caso 1
# dentro  1777483
# Comprobante  25
# 1777620
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777620        D     10    5896
# 1    G      1777620        H    404    6215
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  5229980.58
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  5229980.58
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...           NaN
# caso 1
# dentro  1777620
# Comprobante  26
# 1777623
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777623        D     10    5896
# 1    G      1777623        H    404    6215
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  8912366.64
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  8912366.64
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...           NaN
# caso 1
# dentro  1777623
# Comprobante  27
# 1777626
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777626        D     10    5896
# 1    G      1777626        H    404    6215
#
#                                           Movimiento           MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10623426.53
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  10623426.53
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...           NaN
# caso 1
# dentro  1777626
# Comprobante  28
# 1777629
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777629        D     10    5896
# 1    G      1777629        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  2144436.0
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  2144436.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
#
#                                 GlosaDetalle
# 0                                        NaN
# 1  LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# caso 1
# dentro  1777629
# Comprobante  29
# 1777631
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777631        D     10    5896
# 1    G      1777631        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  434630.94
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  434630.94
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...           NaN
# caso 1
# dentro  1777631
# Comprobante  30
# 1777633
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777633        D     10    5896
# 1    G      1777633        H    412    5970
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  150597.58
# 1  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  150597.58
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# caso 1
# dentro  1777633
# Comprobante  31
# 1777765
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777765        D     10    5896
# 1    G      1777765        H    403    3907
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  43719.26
# 1  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  43719.26
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
#
#                      GlosaDetalle
# 0                             NaN
# 1  4010612801 EMBAJADA DE ECUADOR
# caso 1
# dentro  1777765
# Comprobante  32
# 1777767
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777767        D     17    6296
# 1    G      1777767        H    606    6538
#
#                                           Movimiento       MN  \
# 0  INTERESES DEVENGADOS                          ...  41552.5
# 1  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...  41552.5
#
#                                                Glosa  GlosaDetalle
# 0  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...           NaN
# 1  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...           NaN
# caso 1
# dentro  1777767
# Comprobante  33
# 1777769
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1777769        D    499    7355
# 1    G      1777769        H     16    6758
#
#                                           Movimiento          MN  \
# 0  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  4838139.01
# 1  TITULOS - PORTAFOLIO GLOBAL                   ...  4838139.01
#
#                                                Glosa  GlosaDetalle
# 0  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...           NaN
# 1  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...           NaN
# caso 4
# dentro  1777769
# Comprobante  34
# 1996851
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996851        D    403    7191
# 1    O      1996851        H      7    3491
#
#                                           Movimiento        MN  \
# 0  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...  686000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  686000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1996851
# Comprobante  35
# 1996852
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996852        D    403    3907
# 1    O      1996852        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1996852
# Comprobante  36
# 1996865
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996865        D    403    3906
# 1    O      1996865        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  48020000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  48020000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1996865
# Comprobante  37
# 1996906
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1996906        D    403    6893
# 1    O      1996906        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...           NaN
# caso 4
# dentro  1996906
# Comprobante  38
# 1996980
# Hay duplicado:  True
# aux4
# [1, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    H      1996980        H    828    3559
# 1    H      1996980        H      7    8085
#
#                                           Movimiento        MN  \
# 0  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...  137200.0
# 1  DOLARES ESTADOUNIDENSES - MANDATO BUSA        ...  137200.0
#
#                                                Glosa  GlosaDetalle
# 0  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# 1  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# caso 4
# dentro  1996980
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     S         2178   Egreso      10     485    5782
# 1     S         5545   Egreso      10     485    5782
# 2     D        21859  Ingreso      22     498    1470
# 3     V        28482  Ingreso     306      17    6296
# 4     S      1025269  Ingreso      11     606    1535
# 5     S      1025272  Ingreso      10     412    8467
# 6     S      1025273  Ingreso      10     404    7954
# 7     S      1025275  Ingreso      10     404    7954
# 8     S      1025283  Ingreso      10     498    8304
# 9     S      1025289   Egreso      10     412    3987
# 10    S      1025295  Ingreso      16     499    7355
# 11    S      1025301  Ingreso      10     404    7954
# 12    S      1025312  Ingreso      10     414    7866
# 13    S      1025314  Ingreso      10     498    8304
# 14    S      1025315   Egreso      10     405    7329
# 15    S      1025316   Egreso      10     412     818
# 16    S      1025332  Ingreso      10      10    5896
# 17    S      1025334  Ingreso      10      10    5896
# 18    G      1777343  Ingreso      10     404    7164
# 19    G      1777345  Ingreso      10     404    7164
# 20    G      1777347  Ingreso      10     404    7164
# 21    G      1777480   Egreso      10     498    6818
# 22    G      1777481   Egreso      10     412    3987
# 23    G      1777482   Egreso      10     412    3987
# 24    G      1777483  Ingreso      10     412    5970
# 25    G      1777620  Ingreso      10     404    6215
# 26    G      1777623  Ingreso      10     404    6215
# 27    G      1777626  Ingreso      10     404    6215
# 28    G      1777629  Ingreso      10     412    5970
# 29    G      1777631  Ingreso      10     404    7164
# 30    G      1777633  Ingreso      10     412    5970
# 31    G      1777765  Ingreso      10     403    3907
# 32    G      1777767  Ingreso      17     606    6538
# 33    G      1777769   Egreso      16     499    7355
# 34    O      1996851   Egreso       7     403    7191
# 35    O      1996852   Egreso       7     403    3907
# 36    O      1996865   Egreso       7     403    3906
# 37    O      1996906   Egreso       7     403    6893
# 38    H      1996980   Egreso       7     828    3559
#
#                                            Movimiento    MontoUSD  \
# 0   PROVISIONES PARA COMISIONES AL CUSTODIO       ...       94.24
# 1   PROVISIONES PARA COMISIONES AL CUSTODIO       ...      582.20
# 2   ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...        0.01
# 3   INTERESES DEVENGADOS                          ...  7749695.03
# 4   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     2242.85
# 5   DIREC.GRAL.AERONAUTICA CIVIL-RECURSOS ESPECIFI...    25833.67
# 6   YPFB - EXPORTACION DE UREA Y OTROS            ...  2967000.00
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...  3027000.00
# 8   ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 9   CUENTA UNICA DEL TESORO                       ...      105.11
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  YPFB - EXPORTACION DE UREA Y OTROS            ...   517860.00
# 12  EFECTIVO GARANTIA FONDO CPVIS                 ...  8000000.00
# 13  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      250.00
# 14  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...    56248.00
# 15  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...       28.59
# 16  NEW YORK - CTA. 3544020682001                 ...       11.78
# 17  NEW YORK - CTA. 3544020682001                 ...       72.78
# 18  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   263829.18
# 19  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    56906.70
# 20  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   125772.16
# 21  DEPOSITOS SECTOR PUBLICO - OP. CAMBIARIAS     ...      480.00
# 22  CUENTA UNICA DEL TESORO                       ...   152675.37
# 23  CUENTA UNICA DEL TESORO                       ...     2000.00
# 24  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  1000000.00
# 25  EMPRESA METALURGICA VINTO (EMV)               ...   762387.84
# 26  EMPRESA METALURGICA VINTO (EMV)               ...  1299178.81
# 27  EMPRESA METALURGICA VINTO (EMV)               ...  1548604.45
# 28  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   312600.00
# 29  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    63357.28
# 30  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    21953.00
# 31  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...     6373.07
# 32  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...     6057.22
# 33  VALORACION TITULOS DE LAS RESERVAS INTERNACION...   705268.08
# 34  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...   100000.00
# 35  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  5000000.00
# 36  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  7000000.00
# 37  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 38  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
#
#                                               Detalle  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Saldo ME = 93567.36 ;Bs/Mo: 6.86000000000 ;Sal...
# 3   Saldo Ant.= -66098.00 ;Bs: 9.59837480000 = $us...
# 4                                                 NaN
# 5                  P. CTA. DE IATA INTERNATIONAL AIR.
# 6   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 7   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 8                                (CC:H-0046550-2022)
# 9   TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 10                                                NaN
# 11              POR CUENTA DE HINOVE AGROCIENCIA S.A.
# 12                                                NaN
# 13                               (CC:H-0046552-2022)
# 14  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 15                         SWIFT N° 1731 DE LA FECHA.
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 23  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 24  LIBRETA N° 00287104321 FPS-U$-MIAGUA V - CAF  ...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28          LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# 29                                                NaN
# 30  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 31                     4010612801 EMBAJADA DE ECUADOR
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                                 Glosa
# 0   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 1   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 2   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 3   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 4   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 9   ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 12  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...
# 13  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 14  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 15  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 16  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...
# 17  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...
# 20  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...
# 21  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 23  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 24  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...
# 27  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...
# 28  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 29  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...
# 30  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 31  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 32  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...
# 33  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...
# 34  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...
# 35  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...
# 36  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...
# 37  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...
# 38  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...

# %%
movimientosAux= movimientos.drop(columns=['nomMovimiento'])
conCodigos = pd.merge(consolidado,movimientosAux, on=['Concepto', 'Mayor2','codMov'], how='left')
conCodigos

######## el 01feb tiene buenos moviemientos para ver glosas
# Out:
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     S         2178   Egreso      10     485    5782
# 1     S         5545   Egreso      10     485    5782
# 2     D        21859  Ingreso      22     498    1470
# 3     V        28482  Ingreso     306      17    6296
# 4     S      1025269  Ingreso      11     606    1535
# 5     S      1025272  Ingreso      10     412    8467
# 6     S      1025273  Ingreso      10     404    7954
# 7     S      1025275  Ingreso      10     404    7954
# 8     S      1025283  Ingreso      10     498    8304
# 9     S      1025289   Egreso      10     412    3987
# 10    S      1025295  Ingreso      16     499    7355
# 11    S      1025301  Ingreso      10     404    7954
# 12    S      1025312  Ingreso      10     414    7866
# 13    S      1025314  Ingreso      10     498    8304
# 14    S      1025315   Egreso      10     405    7329
# 15    S      1025316   Egreso      10     412     818
# 16    S      1025332  Ingreso      10      10    5896
# 17    S      1025334  Ingreso      10      10    5896
# 18    G      1777343  Ingreso      10     404    7164
# 19    G      1777345  Ingreso      10     404    7164
# 20    G      1777347  Ingreso      10     404    7164
# 21    G      1777480   Egreso      10     498    6818
# 22    G      1777481   Egreso      10     412    3987
# 23    G      1777482   Egreso      10     412    3987
# 24    G      1777483  Ingreso      10     412    5970
# 25    G      1777620  Ingreso      10     404    6215
# 26    G      1777623  Ingreso      10     404    6215
# 27    G      1777626  Ingreso      10     404    6215
# 28    G      1777629  Ingreso      10     412    5970
# 29    G      1777631  Ingreso      10     404    7164
# 30    G      1777633  Ingreso      10     412    5970
# 31    G      1777765  Ingreso      10     403    3907
# 32    G      1777767  Ingreso      17     606    6538
# 33    G      1777769   Egreso      16     499    7355
# 34    O      1996851   Egreso       7     403    7191
# 35    O      1996852   Egreso       7     403    3907
# 36    O      1996865   Egreso       7     403    3906
# 37    O      1996906   Egreso       7     403    6893
# 38    H      1996980   Egreso       7     828    3559
#
#                                            Movimiento    MontoUSD  \
# 0   PROVISIONES PARA COMISIONES AL CUSTODIO       ...       94.24
# 1   PROVISIONES PARA COMISIONES AL CUSTODIO       ...      582.20
# 2   ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...        0.01
# 3   INTERESES DEVENGADOS                          ...  7749695.03
# 4   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     2242.85
# 5   DIREC.GRAL.AERONAUTICA CIVIL-RECURSOS ESPECIFI...    25833.67
# 6   YPFB - EXPORTACION DE UREA Y OTROS            ...  2967000.00
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...  3027000.00
# 8   ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 9   CUENTA UNICA DEL TESORO                       ...      105.11
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  YPFB - EXPORTACION DE UREA Y OTROS            ...   517860.00
# 12  EFECTIVO GARANTIA FONDO CPVIS                 ...  8000000.00
# 13  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      250.00
# 14  GARANTIAS POR ACREDITIVOS - EMPRESAS PUBLICAS ...    56248.00
# 15  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...       28.59
# 16  NEW YORK - CTA. 3544020682001                 ...       11.78
# 17  NEW YORK - CTA. 3544020682001                 ...       72.78
# 18  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   263829.18
# 19  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    56906.70
# 20  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...   125772.16
# 21  DEPOSITOS SECTOR PUBLICO - OP. CAMBIARIAS     ...      480.00
# 22  CUENTA UNICA DEL TESORO                       ...   152675.37
# 23  CUENTA UNICA DEL TESORO                       ...     2000.00
# 24  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...  1000000.00
# 25  EMPRESA METALURGICA VINTO (EMV)               ...   762387.84
# 26  EMPRESA METALURGICA VINTO (EMV)               ...  1299178.81
# 27  EMPRESA METALURGICA VINTO (EMV)               ...  1548604.45
# 28  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   312600.00
# 29  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    63357.28
# 30  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    21953.00
# 31  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...     6373.07
# 32  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...     6057.22
# 33  VALORACION TITULOS DE LAS RESERVAS INTERNACION...   705268.08
# 34  BCO.PYME DE LA COMUNIDAD S.A. CTA.CTE. Y DE EN...   100000.00
# 35  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  5000000.00
# 36  BCO.NL.DE BOLIVIA-CUENTA CORRIENTE Y DE ENCAJE...  7000000.00
# 37  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 38  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
#
#                                               Detalle  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Saldo ME = 93567.36 ;Bs/Mo: 6.86000000000 ;Sal...
# 3   Saldo Ant.= -66098.00 ;Bs: 9.59837480000 = $us...
# 4                                                 NaN
# 5                  P. CTA. DE IATA INTERNATIONAL AIR.
# 6   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 7   POR CUENTA DE SWISS SINGAPORE OVERSEAS ENTERPR...
# 8                                (CC:H-0046550-2022)
# 9   TRANSFERENCIA DE FONDOS AL JPMORGAN CHASE BANK...
# 10                                                NaN
# 11              POR CUENTA DE HINOVE AGROCIENCIA S.A.
# 12                                                NaN
# 13                               (CC:H-0046552-2022)
# 14  (CC:H-0046772-2021) I-2021-28 VTA. DIVISAS S/G...
# 15                         SWIFT N° 1731 DE LA FECHA.
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 23  WITTY, CTA. 2003003350476 BANCO INTERNACIONAL ...
# 24  LIBRETA N° 00287104321 FPS-U$-MIAGUA V - CAF  ...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28          LIB. 00597012001 RECURSOS ESPECIFICOS YLB
# 29                                                NaN
# 30  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 31                     4010612801 EMBAJADA DE ECUADOR
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                                 Glosa  \
# 0   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 1   ||REGISTRO DEL PAGO DE COMISION AL CUSTODIO DE...
# 2   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 3   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 4   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 9   ||TRANSFERENCIA DE FOBDOS SEGÚN NOTA MEFP/VTCP...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 12  ||TRANSFERENCIA DEL EXTERIOR, SEGÚN SWIFT N° 1...
# 13  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 14  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 15  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 16  ||RETENCION IUE - BE DEL PORTAFOLIO FPA POR EL...
# 17  ||RETENCION IUE - BE DEL PORTAFOLIO FPAH POR E...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1697...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1693...
# 20  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1720...
# 21  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 22  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 23  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 24  TRANSFERENCIA RECIBIDA DEL EXTERIOR SEGÚN MENS...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1732...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1737...
# 27  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1739...
# 28  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1741...
# 29  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1743...
# 30  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1719...
# 31  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 1748...
# 32  INTERÉS DEVENGADO DE TÍTULOS AL 04-02-2022, PO...
# 33  REVALORACIÓN DE TÍTULOS AL 04-02-2022, PORTAFO...
# 34  PAGO CHEQUE: D-19-98365     , BENEFICIARIO: EM...
# 35  PAGO CHEQUE: D-20-98723     , BENEFICIARIO: EM...
# 36  PAGO CHEQUE: D-19-97881     , BENEFICIARIO: EM...
# 37  PAGO CHEQUE: D-21-99784     , BENEFICIARIO: BR...
# 38  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
#
#                              codigoBC                  codigoPropio
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                       RENTA (BCI14)           Intereses Overnight
# 5                  CORRIENTES (BCI12)  Dir. Gral. Aeronáutica Civil
# 6               Y.P.F.B. Otros (BCI5)                     YPFB UREA
# 7               Y.P.F.B. Otros (BCI5)                     YPFB UREA
# 8                                 NaN                           NaN
# 9                           Ver Glosa                     Ver Glosa
# 10                      RENTA (BCI14)     Valoración de Titulos RIN
# 11              Y.P.F.B. Otros (BCI5)                     YPFB UREA
# 12    TRANSFERENCIAS del EXT. (BCI22)                     Ver Glosa
# 13                                NaN                           NaN
# 14              OTRAS EMPRESAS (BCE4)                           NaN
# 15                          Ver Glosa                     Ver Glosa
# 16                                NaN                           NaN
# 17                                NaN                           NaN
# 18              Y.P.F.B. Otros (BCI5)                      YPFB GLP
# 19              Y.P.F.B. Otros (BCI5)                      YPFB GLP
# 20              Y.P.F.B. Otros (BCI5)                      YPFB GLP
# 21                          Ver Glosa                     Ver Glosa
# 22                          Ver Glosa                     Ver Glosa
# 23                          Ver Glosa                     Ver Glosa
# 24                          Ver Glosa                     Ver Glosa
# 25                       VINTO (BCI6)     Empresa Metalúrgica Vinto
# 26                       VINTO (BCI6)     Empresa Metalúrgica Vinto
# 27                       VINTO (BCI6)     Empresa Metalúrgica Vinto
# 28                          Ver Glosa                     Ver Glosa
# 29              Y.P.F.B. Otros (BCI5)                      YPFB GLP
# 30                          Ver Glosa                     Ver Glosa
# 31    TRANSFERENCIAS del EXT. (BCI22)               Banco Mercantil
# 32                      RENTA (BCI14)     Intereses Portafolio Euro
# 33                      OTROS (BCE12)     Valoración de Titulos RIN
# 34  OPERACIONES BANCARIAS (3) (BCE19)         Banco de la Comunidad
# 35  OPERACIONES BANCARIAS (3) (BCE19)               Banco Mercantil
# 36  OPERACIONES BANCARIAS (3) (BCE19)                Banco Nacional
# 37  OPERACIONES BANCARIAS (3) (BCE19)               Banco Fortaleza
# 38                      OTROS (BCE12)                     Ver Glosa
