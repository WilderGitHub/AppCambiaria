# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
gtes = "gtes.xls"
goi = "goi.xls"
gom = "gom.xls"
gef = "gef.xls"
cuentas=[7,10,11,16,17]
bdgtes = pd.read_excel('../data/'+gtes)
bdgoi = pd.read_excel('../data/'+goi)
bdgom = pd.read_excel('../data/'+gom)
bdgef = pd.read_excel('../data/'+gef)

bdBruto= pd.concat([bdgtes,bdgoi,bdgom,bdgef],ignore_index=True)
#bd.describe()
# Out:
# WARNING *** file size (620327) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3984880) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (4900804) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
#bdBruto.columns

# %%
bdReducida=bdBruto.loc[:,('cve_tipo_comprob','glosa_reng','cve_debe_haber','monto_mo',
           'cod_moneda', 'cod_movimiento', 'nom_movimiento',
           'monto_mn','glosa_comprob','nro_comprob','cod_mayor')]
#bdReducida

# %%
dict = {'cve_tipo_comprob':'tipo','glosa_reng':'glosaRenglon','cve_debe_haber':'dh','monto_mo':'mo',
           'cod_moneda':'moneda', 'cod_movimiento':'codMov', 'nom_movimiento':'nomMov',
           'monto_mn':'mn','glosa_comprob':'glosa','nro_comprob':'comprobante','cod_mayor':'mayor'}
bdReducida.rename(columns=dict,
          inplace=True)
bdReducida.shape
# Out:
# (6814, 11)

# %%
#bd['mayor'].unique()

#bdFiltro1=bdReducida[bdReducida['mayor'].isin([7,10,11,16,17])]
bdFiltro1=bdReducida[bdReducida['mayor'].isin(cuentas)]

# %%
#bdFiltro1.loc[:,("comprobante","mayor")]
bdFiltro1["comprobante"].unique()
#bdFiltro1.sort_values(by="comprobante", ascending=True)
# Out:
# array([1989943, 1989965, 1990012, 1990005, 1023245,   28368, 1023252,
#        1023273,   21775, 1750703, 1751094, 1751095, 1023248, 1751442,
#          28372, 1750953, 1750955, 1750957, 1750959, 1750961, 1023253,
#        1023251, 1751436, 1751437, 1751439, 1751441, 1023272, 1023271,
#        1751546, 1751547, 1023283, 1023280, 1023277, 1023274, 1023268,
#        1023269], dtype=int64)

# %%
#bd[bd['comprobante'].isin(bdFiltro1["comprobante"])].sort_values(by="comprobante", ascending=True).tail(60)
bd=bdReducida[bdReducida["comprobante"].isin(bdFiltro1["comprobante"])].sort_values(by=["comprobante","dh"], ascending=True)
bd = bd.reset_index(drop=True)
######bd.head()

# %%
#list(bd.loc[55,["glosa"]])

# %%
#bd.to_excel("ux.xlsx")

# %%
bd=bd.drop_duplicates()
bd = bd.reset_index(drop=True)
#####bd

# %%
#bd["comprobante"].unique()

# %%
aux1=bd["comprobante"].unique()
#len(aux1)
#print(bd["comprobante"]==aux1[5])
#print(aux1[5])

consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    ###print("---", q, "-----")
    ###print(aux2.loc[:,["comprobante","mayor"]])
    ###print("-----")
    suma=0
    for i in aux2.index:
    
        if aux2["mayor"][i] in cuentas and (aux2["tipo"][i]=='V' or aux2["tipo"][i]=='D'):
            #print (i)
            suma=suma+aux2["mn"][i]/6.86
            
        else:
            #print ("else")
            for j in aux2.index:
                if i!=j:
                    if aux2["mn"][i]==aux2["mn"][j]:  ####### AQUI VER LA FORMA DE COMPARAR CON UN MARGEN

                        data1.append({
                            "Tipo":aux2["tipo"][i],"Comprobante":aux2["comprobante"][i],"Concepto":aux2["dh"][i],
                            "Mayor":aux2["mayor"][i],"codMov":aux2["codMov"][i],"Movimiento":aux2["nomMov"][i],
                            "MN":aux2["mn"][i],"Glosa":aux2["glosa"][i],"GlosaDetalle":aux2["glosaRenglon"][i],
                                    })
                        #print(q)
                        pares=pd.DataFrame(data1,columns=columnas)
                        #print(type(pares))      
    print ("la suma es ",suma, " c ", aux2["comprobante"][i])
        #suma=0

    ########################

    # reduce a una sola linea
    
    data2=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    def llenarData(concepto,a,b):
        if concepto !="Neteo":    
            data2.append({
                     "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                    "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                    "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                    "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                    })
        else:
            data2.append({
                    "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                    "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                    "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                    "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                    })
            
    #if len(pares)>2:
    #    print("Revisar oe")

    #for i in salida.index:
    ##print("que pasa")
    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
        #print("Posible Neteo")
        llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
        unRegistro=pd.DataFrame(data2,columns=columnas)
    else:     
        if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
            llenarData("Ingreso",0,1)        
        if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
            llenarData("Egreso",0,1)                   
        if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
            llenarData("Ingreso",1,0)                    
        if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
            llenarData("Egreso",1,0) 

        unRegistro=pd.DataFrame(data2,columns=columnas)
      
    ## print(pares)
    ##print("-------------------")
    ##print("======= consolidado ============")
    ##print(consolidado) 
    #print("===================")
    consolidado=consolidado.append(unRegistro, ignore_index=True)  
    ##print ("la suma es ",suma, " c ", aux2["comprobante"][i])   
consolidado
#consolidado.to_excel("borrar.xlsx")
# Out:
# la suma es  0.010204081632653059  c  21775
# la suma es  905897.1311953352  c  28368
# la suma es  0.010204081632653062  c  28372
# la suma es  0  c  1023245
# la suma es  0  c  1023248
# la suma es  0  c  1023251
# la suma es  0  c  1023252
# la suma es  0  c  1023253
# la suma es  0  c  1023268
# la suma es  0  c  1023269
# la suma es  0  c  1023271
# la suma es  0  c  1023272
# la suma es  0  c  1023273
# la suma es  0  c  1023274
# la suma es  0  c  1023277
# la suma es  0  c  1023280
# la suma es  0  c  1023283
# la suma es  0  c  1750703
# la suma es  0  c  1750953
# la suma es  0  c  1750955
# la suma es  0  c  1750957
# la suma es  0  c  1750959
# la suma es  0  c  1750961
# la suma es  0  c  1751094
# la suma es  0  c  1751095
# la suma es  0  c  1751436
# la suma es  0  c  1751437
# la suma es  0  c  1751439
# la suma es  0  c  1751441
# la suma es  0  c  1751442
# la suma es  0  c  1751546
# la suma es  0  c  1751547
# la suma es  0  c  1989943
# la suma es  0  c  1989965
# la suma es  0  c  1990005
# la suma es  0  c  1990012
#    Tipo Comprobante Concepto Mayor1 Mayor2 codMov  \
# 0     S     1023245  Ingreso     11    606   1535
# 1     S     1023248  Ingreso     16    499   7355
# 2     S     1023251  Ingreso     10    403   3908
# 3     S     1023252  Ingreso     17    606   6538
# 4     S     1023253  Ingreso     10    403   7187
# 5     S     1023268  Ingreso     10    412   5832
# 6     S     1023269  Ingreso     10    412   5832
# 7     S     1023271  Ingreso     10    403   3917
# 8     S     1023272  Ingreso     10    403   3914
# 9     S     1023273  Ingreso     10    412   5832
# 10    S     1023274  Ingreso     10    404   7954
# 11    S     1023277  Ingreso     10    404   7954
# 12    S     1023280  Ingreso     10    404   7954
# 13    S     1023283  Ingreso     10    164   7811
# 14    G     1750703    Neteo     10     10   5896
# 15    G     1750953  Ingreso     10    412   3987
# 16    G     1750955  Ingreso     10    412    818
# 17    G     1750957  Ingreso     10    404   7164
# 18    G     1750959  Ingreso     10    412   4249
# 19    G     1750961  Ingreso     10    412   4249
# 20    G     1751094   Egreso     10    412   5970
# 21    G     1751095   Egreso     10    412   5970
# 22    G     1751436  Ingreso     10    498   1470
# 23    G     1751437  Ingreso     10    404   7164
# 24    G     1751439  Ingreso     10    404   7164
# 25    G     1751441  Ingreso     10    498   1470
# 26    G     1751442   Egreso     16    499   7355
# 27    G     1751546  Ingreso     10    498   1470
# 28    G     1751547  Ingreso     10    498   1470
# 29    O     1989943  Ingreso      7    406    861
# 30    O     1989965   Egreso      7    403   3917
# 31    H     1990005   Egreso      7    828   3559
# 32    O     1990012   Egreso      7    403   3910
#
#                                            Movimiento     MontoUSD  \
# 0   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3727.57
# 1   VALORACION TITULOS DE LAS RESERVAS INTERNACION...        38.90
# 2   BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  15000000.00
# 3   INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...      5980.96
# 4   BANCO FASSIL S.A. CUENTA CORRIENTE Y DE ENCAJE...  10000000.00
# 5   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...       699.13
# 6   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...       687.79
# 7   BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   2500000.00
# 8   BISA-CUENTA CORRIENTE Y DE ENCAJE             ...   3000000.00
# 9   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...       342.82
# 10  YPFB - EXPORTACION DE UREA Y OTROS            ...    120185.00
# 11  YPFB - EXPORTACION DE UREA Y OTROS            ...    481200.00
# 12  YPFB - EXPORTACION DE UREA Y OTROS            ...    669870.00
# 13  COMISIONES DEVENGADAS POR COBRAR - FPA        ...       710.30
# 14  NEW YORK - CTA. 3544020682001                 ...         0.00
# 15  CUENTA UNICA DEL TESORO                       ...     12797.00
# 16  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      5000.00
# 17  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     44880.00
# 18  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...      1604.85
# 19  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...      1631.29
# 20  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   5959047.86
# 21  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   3547937.34
# 22  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...   4966343.69
# 23  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     76750.75
# 24  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     20843.54
# 25  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1055.00
# 26  VALORACION TITULOS DE LAS RESERVAS INTERNACION...     82060.20
# 27  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1082.52
# 28  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1715.05
# 29  RECAUDACIONES CONSULARES                      ...        40.00
# 30  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   3000000.00
# 31  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...     30000.00
# 32  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...   2500000.00
#
#                                               Detalle  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   POR CUENTA DE UNIVERSAL MISSION SUPPORT COMPAN...
# 6                 POR CUENTA DE UNITED AIRLINES, INC.
# 7                                                 NaN
# 8                                                 NaN
# 9               POR CUENTA DE CUBANA DE AVIACION S.A.
# 10                  P. CTA. DE HINOVE AGROCIENCIA S.A
# 11              POR CUENTA DE ACGT QUIMICA LTDA - ME.
# 12                 P. CTA. DE HINOVE AGROCIENCIA S.A.
# 13                                                NaN
# 14                                     (±, 9506985.2)
# 15  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 16  CTA. 1-13550161 COMIBOL - EMPRESA METALURGICA ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 21  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 22                                (CC:H-0000056-2022)
# 23                                                NaN
# 24                                                NaN
# 25                                (CC:H-0000057-2022)
# 26                                                NaN
# 27                                (CC:H-0000058-2022)
# 28                                (CC:H-0000059-2022)
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                                                 Glosa
# 0   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 1   ||REVALORACIÓN  DE TITULOS  A PRECIOS DE MERCA...
# 2   ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN SWIF NO....
# 3   ||INTERESES DEVENGADOS AL 07  DE ENERO  DE   2...
# 4   ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN SWIF NO....
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN SWIFT NO...
# 8   ||TRANSF.DEL EXTERIOR SEGUN SWIFT NO.246 DE LA...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 10  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 11  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 12  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 13  ||COBRO DE COMISION 0,05% POR ADMINISTRACION D...
# 14  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 15  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.220 ...
# 16  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NOS.223...
# 17  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.219 ...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.193 ...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.190 ...
# 20  PAGO A CAF PRÉSTAMO CFA008604 VCTO. 07-01-2022...
# 21  PAGO A CAF PRÉSTAMO CFA008606 VCTO. 07-01-2022...
# 22  REGISTRO TRANSITORIO SEGUN SWIFT NO.227, HASTA...
# 23  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.235 ...
# 24  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.236 ...
# 25  REGISTRO TRANSITORIO SEGUN SWIFT NO.203, HASTA...
# 26  REVALORACIÓN DE TÍTULOS AL 07-01-2022, PORTAFO...
# 27  REGISTRO TRANSITORIO SEGUN SWIFT NO.233 HASTA ...
# 28  REGISTRO TRANSITORIO SEGUN SWIFT NO.244 HASTA ...
# 29  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA EL...
# 30  PAGO CHEQUE: D-21-99956     , BENEFICIARIO: EM...
# 31  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 32  PAGO CHEQUE: D-21-99280     , BENEFICIARIO: MA...

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

def llenarData(concepto,a,b):
    if concepto !="Neteo":    
        data2.append({
                 "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                })
    else:
        data2.append({
                "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                })


for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    #print("q ",q)
    print(aux2["comprobante"][0])
    if len(aux2)>1:
        print(">1")
        if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D':
            print ("Tipo D o V")
            #print(aux2["comprobante"][i])
            #print(aux2.loc[:,["tipo","comprobante","mayor"]])
            data2=[]
            columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
            sumaDebe=0
            sumaHaber=0
            for i in aux2.index:
                
                if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                    sumaDebe=sumaDebe+aux2["mn"][i]/6.86
                elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                    sumaHaber=sumaHaber+aux2["mn"][i]/6.86
                                    
            print(sumaDebe," ",sumaHaber)
            suma=sumaDebe-sumaHaber
            if suma>0:
                print("Ingreso", suma)
                data2.append({''
                 "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":"ingre",
                "Mayor1":"--","Mayor2":"--","codMov":"--",
                "Movimiento":"--","MontoUSD":round(suma,2),
                "Detalle":"--","Glosa":aux2["glosa"][0]
                })
                unRegistro=pd.DataFrame(data2,columns=columnas)
                consolidado=consolidado.append(unRegistro, ignore_index=True)
            else:
                print("Egreso", -suma)
                data2.append({''
                 "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":"ingre",
                "Mayor1":"--","Mayor2":"--","codMov":"--",
                "Movimiento":"--","MontoUSD":round(-suma,2),
                "Detalle":"--","Glosa":aux2["glosa"][0]
                })           
                unRegistro=pd.DataFrame(data2,columns=columnas)
                consolidado=consolidado.append(unRegistro, ignore_index=True)
            #print(pares)
        else: # este el caso normal digamos
            print ("menos Tipo D o V")
            for i in aux2.index:    
                for j in aux2.index:
                    if i!=j:
                        if aux2["mn"][i]==aux2["mn"][j]:  ####### AQUI VER LA FORMA DE COMPARAR CON UN MARGEN

                            data1.append({
                                "Tipo":aux2["tipo"][i],"Comprobante":aux2["comprobante"][i],"Concepto":aux2["dh"][i],
                                "Mayor":aux2["mayor"][i],"codMov":aux2["codMov"][i],"Movimiento":aux2["nomMov"][i],
                                "MN":aux2["mn"][i],"Glosa":aux2["glosa"][i],"GlosaDetalle":aux2["glosaRenglon"][i],
                                        })
                            #print(q)
                            pares=pd.DataFrame(data1,columns=columnas)
                #print(aux2["comprobante"][i])            
            #print(pares)
            data2=[]
            columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
            #funcion
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                #print("Posible Neteo")
                llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                unRegistro=pd.DataFrame(data2,columns=columnas)
            else:     
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                    llenarData("Ingreso",0,1)        
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                    llenarData("Egreso",0,1)                   
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                    llenarData("Ingreso",1,0)                    
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                    llenarData("Egreso",1,0) 

            unRegistro=pd.DataFrame(data2,columns=columnas)
            consolidado=consolidado.append(unRegistro, ignore_index=True)  
    else:
        print("<1")
        #print(aux2.loc[:,["tipo","comprobante","mayor"]])
    
    #########
    
    ##print ("la suma es ",suma, " c ", aux2["comprobante"][i])   
consolidado
#consolidado.to_excel("borrar.xlsx")
# Out:
# 21775
# >1
# Tipo D o V
# 0.005830903790087463   0.004373177842565597
# Ingreso 0.0014577259475218656
# 28368
# >1
# Tipo D o V
# 9.209912536443149   905887.9212827986
# Egreso 905878.7113702622
# 28372
# <1
# 1023245
# >1
# menos Tipo D o V
# 1023248
# >1
# menos Tipo D o V
# 1023251
# >1
# menos Tipo D o V
# 1023252
# >1
# menos Tipo D o V
# 1023253
# >1
# menos Tipo D o V
# 1023268
# >1
# menos Tipo D o V
# 1023269
# >1
# menos Tipo D o V
# 1023271
# >1
# menos Tipo D o V
# 1023272
# >1
# menos Tipo D o V
# 1023273
# >1
# menos Tipo D o V
# 1023274
# >1
# menos Tipo D o V
# 1023277
# >1
# menos Tipo D o V
# 1023280
# >1
# menos Tipo D o V
# 1023283
# >1
# menos Tipo D o V
# 1750703
# >1
# menos Tipo D o V
# 1750953
# >1
# menos Tipo D o V
# 1750955
# >1
# menos Tipo D o V
# 1750957
# >1
# menos Tipo D o V
# 1750959
# >1
# menos Tipo D o V
# 1750961
# >1
# menos Tipo D o V
# 1751094
# >1
# menos Tipo D o V
# 1751095
# >1
# menos Tipo D o V
# 1751436
# >1
# menos Tipo D o V
# 1751437
# >1
# menos Tipo D o V
# 1751439
# >1
# menos Tipo D o V
# 1751441
# >1
# menos Tipo D o V
# 1751442
# >1
# menos Tipo D o V
# 1751546
# >1
# menos Tipo D o V
# 1751547
# >1
# menos Tipo D o V
# 1989943
# >1
# menos Tipo D o V
# 1989965
# >1
# menos Tipo D o V
# 1990005
# >1
# menos Tipo D o V
# 1990012
# >1
# menos Tipo D o V
#    Tipo  Comprobante Concepto Mayor1 Mayor2 codMov  \
# 0     D        21775    ingre     --     --     --
# 1     V        28368    ingre     --     --     --
# 2     S      1023245  Ingreso     11    606   1535
# 3     S      1023248  Ingreso     16    499   7355
# 4     S      1023251  Ingreso     10    403   3908
# 5     S      1023252  Ingreso     17    606   6538
# 6     S      1023253  Ingreso     10    403   7187
# 7     S      1023268  Ingreso     10    412   5832
# 8     S      1023269  Ingreso     10    412   5832
# 9     S      1023271  Ingreso     10    403   3917
# 10    S      1023272  Ingreso     10    403   3914
# 11    S      1023273  Ingreso     10    412   5832
# 12    S      1023274  Ingreso     10    404   7954
# 13    S      1023277  Ingreso     10    404   7954
# 14    S      1023280  Ingreso     10    404   7954
# 15    S      1023283  Ingreso     10    164   7811
# 16    G      1750703    Neteo     10     10   5896
# 17    G      1750953  Ingreso     10    412   3987
# 18    G      1750955  Ingreso     10    412    818
# 19    G      1750957  Ingreso     10    404   7164
# 20    G      1750959  Ingreso     10    412   4249
# 21    G      1750961  Ingreso     10    412   4249
# 22    G      1751094   Egreso     10    412   5970
# 23    G      1751095   Egreso     10    412   5970
# 24    G      1751436  Ingreso     10    498   1470
# 25    G      1751437  Ingreso     10    404   7164
# 26    G      1751439  Ingreso     10    404   7164
# 27    G      1751441  Ingreso     10    498   1470
# 28    G      1751442   Egreso     16    499   7355
# 29    G      1751546  Ingreso     10    498   1470
# 30    G      1751547  Ingreso     10    498   1470
# 31    O      1989943  Ingreso      7    406    861
# 32    O      1989965   Egreso      7    403   3917
# 33    H      1990005   Egreso      7    828   3559
# 34    O      1990012   Egreso      7    403   3910
#
#                                            Movimiento     MontoUSD  \
# 0                                                  --         0.00
# 1                                                  --    905878.71
# 2   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3727.57
# 3   VALORACION TITULOS DE LAS RESERVAS INTERNACION...        38.90
# 4   BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  15000000.00
# 5   INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...      5980.96
# 6   BANCO FASSIL S.A. CUENTA CORRIENTE Y DE ENCAJE...  10000000.00
# 7   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...       699.13
# 8   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...       687.79
# 9   BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   2500000.00
# 10  BISA-CUENTA CORRIENTE Y DE ENCAJE             ...   3000000.00
# 11  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...       342.82
# 12  YPFB - EXPORTACION DE UREA Y OTROS            ...    120185.00
# 13  YPFB - EXPORTACION DE UREA Y OTROS            ...    481200.00
# 14  YPFB - EXPORTACION DE UREA Y OTROS            ...    669870.00
# 15  COMISIONES DEVENGADAS POR COBRAR - FPA        ...       710.30
# 16  NEW YORK - CTA. 3544020682001                 ...         0.00
# 17  CUENTA UNICA DEL TESORO                       ...     12797.00
# 18  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      5000.00
# 19  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     44880.00
# 20  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...      1604.85
# 21  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...      1631.29
# 22  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   5959047.86
# 23  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   3547937.34
# 24  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...   4966343.69
# 25  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     76750.75
# 26  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     20843.54
# 27  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1055.00
# 28  VALORACION TITULOS DE LAS RESERVAS INTERNACION...     82060.20
# 29  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1082.52
# 30  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1715.05
# 31  RECAUDACIONES CONSULARES                      ...        40.00
# 32  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   3000000.00
# 33  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...     30000.00
# 34  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...   2500000.00
#
#                                               Detalle  \
# 0                                                  --
# 1                                                  --
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   POR CUENTA DE UNIVERSAL MISSION SUPPORT COMPAN...
# 8                 POR CUENTA DE UNITED AIRLINES, INC.
# 9                                                 NaN
# 10                                                NaN
# 11              POR CUENTA DE CUBANA DE AVIACION S.A.
# 12                  P. CTA. DE HINOVE AGROCIENCIA S.A
# 13              POR CUENTA DE ACGT QUIMICA LTDA - ME.
# 14                 P. CTA. DE HINOVE AGROCIENCIA S.A.
# 15                                                NaN
# 16                                     (±, 9506985.2)
# 17  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 18  CTA. 1-13550161 COMIBOL - EMPRESA METALURGICA ...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 23  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 24                                (CC:H-0000056-2022)
# 25                                                NaN
# 26                                                NaN
# 27                                (CC:H-0000057-2022)
# 28                                                NaN
# 29                                (CC:H-0000058-2022)
# 30                                (CC:H-0000059-2022)
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#                                                 Glosa
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 3   ||REVALORACIÓN  DE TITULOS  A PRECIOS DE MERCA...
# 4   ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN SWIF NO....
# 5   ||INTERESES DEVENGADOS AL 07  DE ENERO  DE   2...
# 6   ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN SWIF NO....
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 8   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 9   ||TRANSF.DE FONDOS DEL EXTERIOR SEGUN SWIFT NO...
# 10  ||TRANSF.DEL EXTERIOR SEGUN SWIFT NO.246 DE LA...
# 11  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 12  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 13  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 14  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 15  ||COBRO DE COMISION 0,05% POR ADMINISTRACION D...
# 16  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 17  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.220 ...
# 18  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NOS.223...
# 19  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.219 ...
# 20  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.193 ...
# 21  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.190 ...
# 22  PAGO A CAF PRÉSTAMO CFA008604 VCTO. 07-01-2022...
# 23  PAGO A CAF PRÉSTAMO CFA008606 VCTO. 07-01-2022...
# 24  REGISTRO TRANSITORIO SEGUN SWIFT NO.227, HASTA...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.235 ...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.236 ...
# 27  REGISTRO TRANSITORIO SEGUN SWIFT NO.203, HASTA...
# 28  REVALORACIÓN DE TÍTULOS AL 07-01-2022, PORTAFO...
# 29  REGISTRO TRANSITORIO SEGUN SWIFT NO.233 HASTA ...
# 30  REGISTRO TRANSITORIO SEGUN SWIFT NO.244 HASTA ...
# 31  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA EL...
# 32  PAGO CHEQUE: D-21-99956     , BENEFICIARIO: EM...
# 33  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 34  PAGO CHEQUE: D-21-99280     , BENEFICIARIO: MA...
