# %%
import numpy as np
import pandas as pd
import re
from pandas import Series, DataFrame
gtes = "gtes13ene.xls"
goi = "goi13ene.xls"
gom = "gom13ene.xls"
gef = "gef13ene.xls"
cuentas=[7,10,11,12,16,17]
bdgtes = pd.read_excel('../data/'+gtes)
bdgoi = pd.read_excel('../data/'+goi)
bdgom = pd.read_excel('../data/'+gom)
bdgef = pd.read_excel('../data/'+gef)

bdBruto= pd.concat([bdgtes,bdgoi,bdgom,bdgef],ignore_index=True)
#bd.describe()
# Out:
# WARNING *** file size (686677) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (428716) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3079630) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3972523) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
#bdBruto.columns

# %%
bdReducida=bdBruto.loc[:,('cve_tipo_comprob','glosa_reng','cve_debe_haber','monto_mo',
           'cod_moneda', 'cod_movimiento', 'nom_movimiento',
           'monto_mn','glosa_comprob','nro_comprob','cod_mayor')]
#bdReducida

# %%
dict = {'cve_tipo_comprob':'tipo','glosa_reng':'glosaRenglon','cve_debe_haber':'dh','monto_mo':'mo',
           'cod_moneda':'moneda', 'cod_movimiento':'codMov', 'nom_movimiento':'nomMov',
           'monto_mn':'mn','glosa_comprob':'glosa','nro_comprob':'comprobante','cod_mayor':'mayor'}
bdReducida.rename(columns=dict,
          inplace=True)
bdReducida.shape
# Out:
# (5936, 11)

# %%
#bd['mayor'].unique()

#bdFiltro1=bdReducida[bdReducida['mayor'].isin([7,10,11,16,17])]
bdFiltro1=bdReducida[bdReducida['mayor'].isin(cuentas)]

# %%
#bdFiltro1.loc[:,("comprobante","mayor")]
bdFiltro1["comprobante"].unique()
#bdFiltro1.sort_values(by="comprobante", ascending=True)
# Out:
# array([1991297, 1991256, 1991308, 1991311, 1991318, 1991351, 1991354,
#        1991355, 1991403, 1023509,   28393, 1023555, 1023553, 1756890,
#          21792, 1023535, 1756838, 1023518, 1023484, 1756715, 1755863,
#        1756215, 1756217, 1756219, 1756221, 1756223, 1756225, 1756227,
#        1756581, 1023506, 1756583, 1756585, 1023528, 1023525, 1023524,
#        1756716, 1756719, 1756722, 1756723, 1756724, 1756725, 1756727,
#        1023541, 1023523, 1023537, 1023522, 1023536, 1023534, 1023520,
#        1023561], dtype=int64)

# %%
#bd[bd['comprobante'].isin(bdFiltro1["comprobante"])].sort_values(by="comprobante", ascending=True).tail(60)
bd=bdReducida[bdReducida["comprobante"].isin(bdFiltro1["comprobante"])].sort_values(by=["comprobante","dh"], ascending=True)
bd = bd.reset_index(drop=True)
#bd.head(60)

# %%
#list(bd.loc[55,["glosa"]])

# %%
#bd.to_excel("ux.xlsx")

# %%
bd=bd.drop_duplicates()
bd = bd.reset_index(drop=True)
#bd.head(60)

# %%
#bd["comprobante"].unique()

# %%
def llenarData(concepto,a,b):
    if concepto !="Neteo":    
        print('dentro ',pares["Comprobante"][a])
        data2.append({
                 "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                })
    else:
        data2.append({
                "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                })

def dv(concepto,suma):
    print("largo cuando dentra al debehaber: ",len(aux2))
    if len(aux2)==1:
        data2.append({''
                     "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                    "Mayor1":aux2["mayor"][0],"Mayor2":"--","codMov":"--",
                    "Movimiento":"--","MontoUSD":round(suma,2),
                    "Detalle":aux2["glosaRenglon"][0],"Glosa":aux2["glosa"][0]
                    })
    else:
        data2.append({''
                     "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                    "Mayor1":aux2["mayor"][0],"Mayor2":aux2["mayor"][1],"codMov":aux2["codMov"][1],
                    "Movimiento":aux2["nomMov"][1],"MontoUSD":round(suma,2),
                    "Detalle":aux2["glosaRenglon"][0],"Glosa":aux2["glosa"][0]
                    })

def debemenoshaber(hasta):
    sumaDebe=0
    sumaHaber=0
    for i in hasta:
        if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
            sumaDebe=sumaDebe+aux2["mn"][i]/6.86
        elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
            sumaHaber=sumaHaber+aux2["mn"][i]/6.86
    suma=sumaDebe-sumaHaber
    if suma>0:
        dv("Ingreso",suma)
    else:
        dv("Egreso",-suma)

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        sumaDebe=0
        sumaHaber=0
        for i in aux2.index:
            if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                sumaDebe=sumaDebe+aux2["mn"][i]/6.86
            elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                sumaHaber=sumaHaber+aux2["mn"][i]/6.86
        suma=sumaDebe-sumaHaber
        if suma>0:
            dv("Ingreso",suma)
            #unRegistro=pd.DataFrame(data2,columns=columnas)
            #consolidado=consolidado.append(unRegistro, ignore_index=True)
        else:
            dv("Egreso",-suma)
            #unRegistro=pd.DataFrame(data2,columns=columnas)
            #consolidado=consolidado.append(unRegistro, ignore_index=True)
        unRegistro=pd.DataFrame(data2,columns=columnas)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        #print ("menos Tipo D o V")
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            for x in range(len(aux4)):

                data1.append({
                    "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                    "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                    "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                            })
                pares=pd.DataFrame(data1,columns=columnas)

        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas)

            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares ',pares["Comprobante"][0])
        print(pares)
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes

        if len(aux2)==2: ### los pares. Este sería el caso normal
            print("largo de aux2: ",len(aux2))
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                #print("Posible Neteo")
                llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                unRegistro=pd.DataFrame(data2,columns=columnas)
            else:     
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                    print('caso 1')
                    llenarData("Ingreso",0,1)        
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                    print('caso 2')
                    llenarData("Egreso",0,1)                   
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                    print('caso 3')
                    llenarData("Ingreso",1,0)                    
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                    print('caso 4')
                    llenarData("Egreso",1,0)
        else:
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                ###
                data2=[]
                columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                sumaDebe=0
                sumaHaber=0
                for i in range(len(aux2)):
                    if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                        sumaDebe=sumaDebe+aux2["mn"][i]/6.86
                    elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                        sumaHaber=sumaHaber+aux2["mn"][i]/6.86
                suma=sumaDebe-sumaHaber
                if suma>0:
                    dv("Ingreso",suma)
                    #unRegistro=pd.DataFrame(data2,columns=columnas)
                    #consolidado=consolidado.append(unRegistro, ignore_index=True)
                else:
                    dv("Egreso",-suma)
                    #unRegistro=pd.DataFrame(data2,columns=columnas)
                    #consolidado=consolidado.append(unRegistro, ignore_index=True)
                ####

        unRegistro=pd.DataFrame(data2,columns=columnas)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar1.xlsx")
# Out:
# Comprobante  0
# 21792
# largo cuando dentra al debehaber:  25
# Comprobante  1
# 28393
# largo cuando dentra al debehaber:  18
# Comprobante  2
# 1023484
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh         mo  moneda  codMov  \
# 0    S          NaN  D  579726.69      34    5896
# 1    S          NaN  H  506945.40      53    6535
# 2    S          NaN  D    4624.08      69     616
#
#                                               nomMov          mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3976925.09
# 1  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  3981549.17
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     4624.08
#
#                                                glosa  comprobante  mayor
# 0  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...      1023484     10
# 1  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...      1023484     10
# 2  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...      1023484    280
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023484        D     10    5896
# 1    S      1023484        H     10    6535
# 2    S      1023484        D    280     616
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3976925.09
# 1  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  3981549.17
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     4624.08
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...           NaN
# 1  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...           NaN
# 2  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  3
# 1023506
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023506        D    405    3305
# 1    S      1023506        H     10    5896
#
#                                           Movimiento          MN  \
# 0  GARANTIA POR ACREDITIVOS-INST.GOBIERNO CENTRAL...  6617616.99
# 1  NEW YORK - CTA. 3544020682001                 ...  6617616.99
#
#                                                Glosa  \
# 0  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 1  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
#
#                                         GlosaDetalle
# 0  (CC:H-0043541-2021) I-2021-07 MHYE EEC-GNV / F...
# 1  PAGO N°6 LC I-2021-07 EEC-GNV FABER INDUSTRIE SPA
# largo de aux2:  2
# caso 4
# dentro  1023506
# Comprobante  4
# 1023509
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023509        D     11    2902
# 1    S      1023509        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  27108.18
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  27108.18
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# largo de aux2:  2
# caso 1
# dentro  1023509
# Comprobante  5
# 1023518
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023518        D     16    6286
# 1    S      1023518        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# largo de aux2:  2
# caso 1
# dentro  1023518
# Comprobante  6
# 1023520
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023520        D     10    5896
# 1    S      1023520        H    412    5832
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  78042.52
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  78042.52
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
#
#                       GlosaDetalle
# 0           A LA CUENTA 03-H-307.
# 1  P/CTA. DE TAM LINHAS AEREAS S/A
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  7
# 1023522
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023522        D     10    5896
# 1    S      1023522        H    412    5832
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  16855.77
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  16855.77
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
#
#                                    GlosaDetalle
# 0                        A LA CUENTA 03-H-307.
# 1  P/CTA. DE ABSA  AEROLINHAS BRASILEIRAS S.A.
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  8
# 1023523
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023523        D     10    5896
# 1    S      1023523        H    412    4710
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  8349.44
# 1  03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...  8349.44
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
#
#                       GlosaDetalle
# 0           A LA CUENTA 03-W-302.
# 1  P. CTA DE 101DOMAIN GRS LIMITED
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  9
# 1023524
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023524        D     10    5896
# 1    S      1023524        H    403    3908
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  82320000.0
# 1  BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  82320000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CRED...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CRED...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CREDIT...
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  10
# 1023525
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023525        D     10    5896
# 1    S      1023525        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  34300000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  34300000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL ...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL S....
# largo de aux2:  2
# caso 1
# dentro  1023525
# Comprobante  11
# 1023528
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023528        D     10    5896
# 1    S      1023528        H    403    3917
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  6860000.0
# 1  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  6860000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADER...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADER...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADERO ...
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  12
# 1023534
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023534        D     10    5896
# 1    S      1023534        H    412    5832
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68664.9
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  68664.9
#
#                                                Glosa              GlosaDetalle
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...    A LA CUENTA 03-H-307.
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...  P/CTA. DE ATLAS AIR INC
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  13
# 1023535
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh         mo  moneda  codMov  \
# 0    S          NaN  D  260000.00      53    6072
# 1    S          NaN  H  295510.80      34    5896
# 2    S          NaN  H   14835.91      69    1585
#
#                                               nomMov          mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  2042040.00
# 1  NEW YORK - CTA. 3544020682001                 ...  2027204.09
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...    14835.91
#
#                                                glosa  comprobante  mayor
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...      1023535     10
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...      1023535     10
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...      1023535    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023535        D     10    6072
# 1    S      1023535        H     10    5896
# 2    S      1023535        H    680    1585
#
#                                           Movimiento          MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  2042040.00
# 1  NEW YORK - CTA. 3544020682001                 ...  2027204.09
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...    14835.91
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...           NaN
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...           NaN
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  14
# 1023536
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023536        D     10    5896
# 1    S      1023536        H    412    5832
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  26801.88
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  26801.88
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
#
#                                 GlosaDetalle
# 0                     A LA CUENTA 03-H-307.
# 1  P.CTA DE LINEA AEREA CARGUERA - DEBTOR IN
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  15
# 1023537
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023537        D     10    5896
# 1    S      1023537        H    404    7954
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  78533.28
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  78533.28
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
#
#                                         GlosaDetalle
# 0  A LA CUENTA YPFB – EXPORTACIÓN DE UREA Y OTROS...
# 1       P.CTA DE DREYMOOR FERTILIZERS OVERSEAS PTE L
# largo de aux2:  2
# caso 1
# dentro  1023537
# Comprobante  16
# 1023541
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023541        D     10    5896
# 1    S      1023541        H    404    8291
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  262870.19
# 1  UTO - POSTGRADO UTO CAMIPER                   ...  262870.19
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0           A LA CUENTA - UTO POSTGRADO UTO CAMIPER.
# 1  POR CUENTA DE CAMARA MINERA DIPLOMADOS INTERNA...
# largo de aux2:  2
# caso 1
# dentro  1023541
# Comprobante  17
# 1023553
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023553        D     10    6535
# 1    S      1023553        H     17    6296
#
#                                           Movimiento          MN  \
# 0  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  1471499.68
# 1  INTERESES DEVENGADOS                          ...  1471499.68
#
#                                                Glosa  GlosaDetalle
# 0  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,41 01/10...           NaN
# 1  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,41 01/10...           NaN
# largo de aux2:  2
# Comprobante  18
# 1023555
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023555        D     10    6535
# 1    S      1023555        H     17    6296
#
#                                           Movimiento          MN  \
# 0  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  3211236.55
# 1  INTERESES DEVENGADOS                          ...  3211236.55
#
#                                                Glosa  GlosaDetalle
# 0  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,26 01/11...           NaN
# 1  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,26 01/11...           NaN
# largo de aux2:  2
# Comprobante  19
# 1023561
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023561        D    498    8304
# 1    S      1023561        H     10    5896
#
#                                           Movimiento        MN  \
# 0  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  23852.36
# 1  NEW YORK - CTA. 3544020682001                 ...  23852.36
#
#                                                Glosa  \
# 0  'DEVOLUCION POR TRANSFERENCIA RECIBIDA DEL EXT...
# 1  'DEVOLUCION POR TRANSFERENCIA RECIBIDA DEL EXT...
#
#                  GlosaDetalle
# 0        (CC:H-0047255-2021)
# 1  SEGÚN GLOSA DE REFERENCIA.
# largo de aux2:  2
# caso 4
# dentro  1023561
# Comprobante  20
# 1755863
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1755863        D    498    6817
# 1    G      1755863        H     10    5896
#
#                                           Movimiento          MN  \
# 0  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  68600000.0
# 1  NEW YORK - CTA. 3544020682001                 ...  68600000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  BANCO DE CREDITO DE BOLIVIA S.A., CTA. 3544031...
# largo de aux2:  2
# caso 4
# dentro  1755863
# Comprobante  21
# 1756215
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756215        D     10    5896
# 1    G      1756215        H    412    4249
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  160219.0
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  160219.0
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.429 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.429 ...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756215
# Comprobante  22
# 1756217
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756217        D     10    5896
# 1    G      1756217        H    412    4249
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  39330.03
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  39330.03
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.436 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.436 ...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756217
# Comprobante  23
# 1756219
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756219        D     10    5896
# 1    G      1756219        H    412    4249
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  182099.18
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  182099.18
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.441 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.441 ...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756219
# Comprobante  24
# 1756221
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756221        D     10    5896
# 1    G      1756221        H    412     818
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  644702.8
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  644702.8
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 469,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 469,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# largo de aux2:  2
# caso 1
# dentro  1756221
# Comprobante  25
# 1756223
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756223        D     10    5896
# 1    G      1756223        H    412     818
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  458165.68
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  458165.68
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 468,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 468,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# largo de aux2:  2
# caso 1
# dentro  1756223
# Comprobante  26
# 1756225
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756225        D     10    5896
# 1    G      1756225        H    412     818
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  758688.56
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  758688.56
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 467,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 467,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# largo de aux2:  2
# caso 1
# dentro  1756225
# Comprobante  27
# 1756227
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756227        D     10    5896
# 1    G      1756227        H    412     818
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  607699.96
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  607699.96
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 470,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 470,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# largo de aux2:  2
# caso 1
# dentro  1756227
# Comprobante  28
# 1756581
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756581        D     10    5896
# 1    G      1756581        H    412    3987
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  15378.06
# 1  CUENTA UNICA DEL TESORO                       ...  15378.06
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 465 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 465 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# largo de aux2:  2
# caso 1
# dentro  1756581
# Comprobante  29
# 1756583
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756583        D     10    5896
# 1    G      1756583        H    412     818
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1167142.22
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  1167142.22
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.485 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.485 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  CTA. 1-13550161 COMIBOL - EMPRESA METALURGICA ...
# largo de aux2:  2
# caso 1
# dentro  1756583
# Comprobante  30
# 1756585
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756585        D     10    5896
# 1    G      1756585        H    404    7164
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1132349.26
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  1132349.26
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.487 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.487 ...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756585
# Comprobante  31
# 1756715
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756715        D     16    6758
# 1    G      1756715        H    499    7355
#
#                                           Movimiento          MN  \
# 0  TITULOS - PORTAFOLIO GLOBAL                   ...  8914930.49
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  8914930.49
#
#                                                Glosa  GlosaDetalle
# 0  REVALORACIÓN DE TÍTULOS AL 13-01-2022, PORTAFO...           NaN
# 1  REVALORACIÓN DE TÍTULOS AL 13-01-2022, PORTAFO...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756715
# Comprobante  32
# 1756716
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756716        D     10    5896
# 1    G      1756716        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  238430.96
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  238430.96
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 501,...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 501,...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756716
# Comprobante  33
# 1756719
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756719        D     10    5896
# 1    G      1756719        H    404    6215
#
#                                           Movimiento           MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  54982061.37
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  54982061.37
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 493 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 493 ...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756719
# Comprobante  34
# 1756722
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756722        D     10    5896
# 1    G      1756722        H    498    1470
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  62537.75
# 1  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  62537.75
#
#                                                Glosa         GlosaDetalle
# 0  REGISTRO TRANSITORIO SEGUN SWIFT N° 497, HASTA...                  NaN
# 1  REGISTRO TRANSITORIO SEGUN SWIFT N° 497, HASTA...  (CC:H-0000115-2022)
# largo de aux2:  2
# caso 1
# dentro  1756722
# Comprobante  35
# 1756723
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756723        D     10    5896
# 1    G      1756723        H    498    1470
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  23139.12
# 1  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  23139.12
#
#                                                Glosa         GlosaDetalle
# 0  REGISTRO TRANSITORIO SEGUN SWIFT N° 488, HASTA...                  NaN
# 1  REGISTRO TRANSITORIO SEGUN SWIFT N° 488, HASTA...  (CC:H-0000116-2022)
# largo de aux2:  2
# caso 1
# dentro  1756723
# Comprobante  36
# 1756724
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756724        D     10    5896
# 1    G      1756724        H    498    1470
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  7384.04
# 1  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  7384.04
#
#                                                Glosa         GlosaDetalle
# 0  REGISTRO TRANSITORIO SEGUN SWIFT N° 491, HASTA...                  NaN
# 1  REGISTRO TRANSITORIO SEGUN SWIFT N° 491, HASTA...  (CC:H-0000117-2022)
# largo de aux2:  2
# caso 1
# dentro  1756724
# Comprobante  37
# 1756725
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756725        D     10    5896
# 1    G      1756725        H    412    3987
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  450262.96
# 1  CUENTA UNICA DEL TESORO                       ...  450262.96
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 456 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 456 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# largo de aux2:  2
# caso 1
# dentro  1756725
# Comprobante  38
# 1756727
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756727        D     10    5896
# 1    G      1756727        H    412    3987
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  146285.86
# 1  CUENTA UNICA DEL TESORO                       ...  146285.86
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 457 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 457 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# largo de aux2:  2
# caso 1
# dentro  1756727
# Comprobante  39
# 1756838
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh          mo  \
# 0    G  FLOTTWEG SE, CTA. DE06700500000000030176 BAYER...  H   258142.79
# 1    G  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...  D    57008.19
# 2    G  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...  D     2297.47
# 3    G                                                NaN  D  2000000.00
# 4    G                                                NaN  H      191.40
# 5    G                                                NaN  H       43.50
# 6    G                                                NaN  H     1763.90
# 7    G                                                NaN  H    29554.71
#
#    moneda  codMov                                             nomMov  \
# 0      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 1      69     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 2      69     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 3      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 4      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 5      69    1514  UTILES DE ESCRITORIO                          ...
# 6      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 7      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#            mn                                              glosa  comprobante  \
# 0  2027453.47  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 1    57008.19  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 2     2297.47  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 3  2000000.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 4      191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 5       43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 6     1763.90  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 7    29554.71  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
#
#    mayor
# 0     10
# 1    412
# 2    412
# 3    498
# 4    600
# 5    600
# 6    650
# 7    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756838        H     10    6072
# 1    G      1756838        D    412     818
# 2    G      1756838        D    412     818
# 3    G      1756838        D    498    4088
# 4    G      1756838        H    600    1510
# 5    G      1756838        H    600    1514
# 6    G      1756838        H    650    1563
# 7    G      1756838        H    680    6890
#
#                                           Movimiento          MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  2027453.47
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    57008.19
# 2  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     2297.47
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  2000000.00
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 5  UTILES DE ESCRITORIO                          ...       43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     1763.90
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    29554.71
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  FLOTTWEG SE, CTA. DE06700500000000030176 BAYER...
# 1  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...
# 2  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  8
# Comprobante  40
# 1756890
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756890        D     17    6296
# 1    G      1756890        H    606    6538
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS                          ...  41592.43
# 1  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...  41592.43
#
#                                                Glosa  GlosaDetalle
# 0  INTERÉS DEVENGADO DE TÍTULOS AL 13-01-2022, PO...           NaN
# 1  INTERÉS DEVENGADO DE TÍTULOS AL 13-01-2022, PO...           NaN
# largo de aux2:  2
# caso 1
# dentro  1756890
# Comprobante  41
# 1991256
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991256        D    403    3907
# 1    O      1991256        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-20-98714     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-20-98714     , BENEFICIARIO: EM...           NaN
# largo de aux2:  2
# caso 4
# dentro  1991256
# Comprobante  42
# 1991297
# Hay duplicado:  True
# aux4
# [0, 1, 2]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991297        D      7    3491
# 1    O      1991297        D    828    3499
# 2    O      1991297        H      7      23
#
#                                           Movimiento           MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  680512000.0
# 1  DOLARES AMERICANOS EN TESORO AUXILIAR         ...  680512000.0
# 2  REMESAS EN TRANSITO - MONEDA EXTRANJERA       ...  680512000.0
#
#                                                Glosa  GlosaDetalle
# 0  REMESA ME - RECEPCION                         ...           NaN
# 1  REMESA ME - RECEPCION                         ...           NaN
# 2  REMESA ME - RECEPCION                         ...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  43
# 1991308
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991308        D      7    3491
# 1    O      1991308        H    414    7245
#
#                                           Movimiento       MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  1558.04
# 1  DEPOSITOS POR APORTES FPA - LEY 365           ...  1558.04
#
#                                                Glosa  GlosaDetalle
# 0  DEPOSITO DE EFECTIVO, DEPOSITANTE: MERCANTIL S...           NaN
# 1  DEPOSITO DE EFECTIVO, DEPOSITANTE: MERCANTIL S...           NaN
# largo de aux2:  2
# caso 1
# dentro  1991308
# Comprobante  44
# 1991311
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991311        D      7    3491
# 1    O      1991311        H    400     654
#
#                                           Movimiento    MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  6.04
# 1  BILLETES Y MONEDAS EN CIRCULACION             ...  6.04
#
#                                                Glosa  GlosaDetalle
# 0  POR LA COMPRA DE DOLARES AMERICANOS           ...           NaN
# 1  POR LA COMPRA DE DOLARES AMERICANOS           ...           NaN
# largo de aux2:  2
# caso 1
# dentro  1991311
# Comprobante  45
# 1991318
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991318        D    403    3917
# 1    O      1991318        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99961     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-21-99961     , BENEFICIARIO: EM...           NaN
# largo de aux2:  2
# caso 4
# dentro  1991318
# Comprobante  46
# 1991351
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991351        D    403    3910
# 1    O      1991351        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99288     , BENEFICIARIO: MA...           NaN
# 1  PAGO CHEQUE: D-21-99288     , BENEFICIARIO: MA...           NaN
# largo de aux2:  2
# caso 4
# dentro  1991351
# Comprobante  47
# 1991354
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991354        D    403    6893
# 1    O      1991354        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99767     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99767     , BENEFICIARIO: BR...           NaN
# largo de aux2:  2
# caso 4
# dentro  1991354
# Comprobante  48
# 1991355
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991355        D    403    3915
# 1    O      1991355        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.ECONOMICO-CUENTA CORRIENTE Y DE ENCAJE    ...  20580000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  20580000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-97432     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-19-97432     , BENEFICIARIO: BR...           NaN
# largo de aux2:  2
# caso 4
# dentro  1991355
# Comprobante  49
# 1991403
# Hay duplicado:  True
# aux4
# [0, 1, 2]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991403        D      7    3491
# 1    O      1991403        D    828    3500
# 2    O      1991403        H    403    3914
#
#                                           Movimiento          MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  19070800.0
# 1  DOLARES AMERICANOS EN CAJAS                   ...  19070800.0
# 2  BISA-CUENTA CORRIENTE Y DE ENCAJE             ...  19070800.0
#
#                                                Glosa  GlosaDetalle
# 0  DEPOSITO DE EFECTIVO, DEPOSITANTE: AGUILAR, CO...           NaN
# 1  DEPOSITO DE EFECTIVO, DEPOSITANTE: AGUILAR, CO...           NaN
# 2  DEPOSITO DE EFECTIVO, DEPOSITANTE: AGUILAR, CO...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21792  Ingreso      17      10    6072
# 1     V        28393  Ingreso      22      17    6296
# 2     S      1023484   Egreso      10      10    6535
# 3     S      1023506   Egreso      10     405    3305
# 4     S      1023509  Ingreso      11     606    1535
# 5     S      1023518  Ingreso      16     499    7355
# 6     S      1023520  Ingreso      10     412    3987
# 7     S      1023522  Ingreso      10     412    3987
# 8     S      1023523  Ingreso      10     412    3987
# 9     S      1023524  Ingreso      10     403    3908
# 10    S      1023525  Ingreso      10     414    7866
# 11    S      1023528  Ingreso      10     403    3917
# 12    S      1023534  Ingreso      10     412    3987
# 13    S      1023535  Ingreso      10      10    5896
# 14    S      1023536  Ingreso      10     412    3987
# 15    S      1023537  Ingreso      10     404    7954
# 16    S      1023541  Ingreso      10     404    8291
# 17    S      1023553    Neteo      10      17    6296
# 18    S      1023555    Neteo      10      17    6296
# 19    S      1023561   Egreso      10     498    8304
# 20    G      1755863   Egreso      10     498    6817
# 21    G      1756215  Ingreso      10     412    4249
# 22    G      1756217  Ingreso      10     412    4249
# 23    G      1756219  Ingreso      10     412    4249
# 24    G      1756221  Ingreso      10     412     818
# 25    G      1756223  Ingreso      10     412     818
# 26    G      1756225  Ingreso      10     412     818
# 27    G      1756227  Ingreso      10     412     818
# 28    G      1756581  Ingreso      10     412    3987
# 29    G      1756583  Ingreso      10     412     818
# 30    G      1756585  Ingreso      10     404    7164
# 31    G      1756715  Ingreso      16     499    7355
# 32    G      1756716  Ingreso      10     404    7164
# 33    G      1756719  Ingreso      10     404    6215
# 34    G      1756722  Ingreso      10     498    1470
# 35    G      1756723  Ingreso      10     498    1470
# 36    G      1756724  Ingreso      10     498    1470
# 37    G      1756725  Ingreso      10     412    3987
# 38    G      1756727  Ingreso      10     412    3987
# 39    G      1756838   Egreso      10     412     818
# 40    G      1756890  Ingreso      17     606    6538
# 41    O      1991256   Egreso       7     403    3907
# 42    O      1991297   Egreso       7     828    3499
# 43    O      1991308  Ingreso       7     414    7245
# 44    O      1991311  Ingreso       7     400     654
# 45    O      1991318   Egreso       7     403    3917
# 46    O      1991351   Egreso       7     403    3910
# 47    O      1991354   Egreso       7     403    6893
# 48    O      1991355   Egreso       7     403    3915
# 49    O      1991403  Ingreso       7     828    3500
#
#                                            Movimiento     MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...         0.01
# 1   INTERESES DEVENGADOS                          ...   5002611.41
# 2   CTA. P03394 - 57603 PORTAFOLIO EURO           ...       674.06
# 3   GARANTIA POR ACREDITIVOS-INST.GOBIERNO CENTRAL...    964667.20
# 4   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3951.63
# 5   VALORACION TITULOS DE LAS RESERVAS INTERNACION...        38.90
# 6   CUENTA UNICA DEL TESORO                       ...     11376.46
# 7   CUENTA UNICA DEL TESORO                       ...      2457.11
# 8   CUENTA UNICA DEL TESORO                       ...      1217.12
# 9   BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  12000000.00
# 10  EFECTIVO GARANTIA FONDO CPVIS                 ...   5000000.00
# 11  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   1000000.00
# 12  CUENTA UNICA DEL TESORO                       ...     10009.46
# 13  NEW YORK - CTA. 3544020682001                 ...      2162.67
# 14  CUENTA UNICA DEL TESORO                       ...      3906.98
# 15  YPFB - EXPORTACION DE UREA Y OTROS            ...     11448.00
# 16  UTO - POSTGRADO UTO CAMIPER                   ...     38319.27
# 17  INTERESES DEVENGADOS                          ...         0.00
# 18  INTERESES DEVENGADOS                          ...         0.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      3477.02
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  10000000.00
# 21  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     23355.54
# 22  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...      5733.24
# 23  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     26545.07
# 24  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     93980.00
# 25  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     66788.00
# 26  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    110596.00
# 27  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     88586.00
# 28  CUENTA UNICA DEL TESORO                       ...      2241.70
# 29  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    170137.35
# 30  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    165065.49
# 31  VALORACION TITULOS DE LAS RESERVAS INTERNACION...   1299552.55
# 32  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     34756.70
# 33  EMPRESA METALURGICA VINTO (EMV)               ...   8014877.75
# 34  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      9116.29
# 35  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      3373.05
# 36  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1076.39
# 37  CUENTA UNICA DEL TESORO                       ...     65636.00
# 38  CUENTA UNICA DEL TESORO                       ...     21324.47
# 39  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    295547.15
# 40  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...      6063.04
# 41  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...   5000000.00
# 42  DOLARES AMERICANOS EN TESORO AUXILIAR         ...        -0.00
# 43  DEPOSITOS POR APORTES FPA - LEY 365           ...       227.12
# 44  BILLETES Y MONEDAS EN CIRCULACION             ...         0.88
# 45  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   5000000.00
# 46  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...    500000.00
# 47  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...    500000.00
# 48  BCO.ECONOMICO-CUENTA CORRIENTE Y DE ENCAJE    ...   3000000.00
# 49  DOLARES AMERICANOS EN CAJAS                   ...   2780000.00
#
#                                               Detalle  \
# 0   Saldo ME = 107142.92 ;Bs/Mo: 6.86000000000 ;Sa...
# 1   Saldo Ant.= 36491.00 ;Bs: 9.61675960000 = $us ...
# 2                                                 NaN
# 3   (CC:H-0043541-2021) I-2021-07 MHYE EEC-GNV / F...
# 4                                                 NaN
# 5                                                 NaN
# 6                              A LA CUENTA 03-H-307.
# 7                              A LA CUENTA 03-H-307.
# 8                              A LA CUENTA 03-W-302.
# 9                                                 NaN
# 10  TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL S....
# 11                                                NaN
# 12                             A LA CUENTA 03-H-307.
# 13                                                NaN
# 14                             A LA CUENTA 03-H-307.
# 15       P.CTA DE DREYMOOR FERTILIZERS OVERSEAS PTE L
# 16  POR CUENTA DE CAMARA MINERA DIPLOMADOS INTERNA...
# 17                                     (±, 214504.33)
# 18                                     (±, 468110.28)
# 19                               (CC:H-0047255-2021)
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 25   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 26   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 27   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 28  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 29  CTA. 1-13550161 COMIBOL - EMPRESA METALURGICA ...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                (CC:H-0000115-2022)
# 35                                (CC:H-0000116-2022)
# 36                                (CC:H-0000117-2022)
# 37  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 38  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 39  FLOTTWEG SE, CTA. DE06700500000000030176 BAYER...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                                 Glosa
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...
# 3   'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 4   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 5   ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 6   ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 7   ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 8   ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 9   ||TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CRED...
# 10  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL ...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADER...
# 12  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 13  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...
# 14  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 15  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 16  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 17  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,41 01/10...
# 18  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,26 01/11...
# 19  'DEVOLUCION POR TRANSFERENCIA RECIBIDA DEL EXT...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.429 ...
# 22  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.436 ...
# 23  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.441 ...
# 24  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 469,...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 468,...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 467,...
# 27  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 470,...
# 28  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 465 ...
# 29  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.485 ...
# 30  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.487 ...
# 31  REVALORACIÓN DE TÍTULOS AL 13-01-2022, PORTAFO...
# 32  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 501,...
# 33  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 493 ...
# 34  REGISTRO TRANSITORIO SEGUN SWIFT N° 497, HASTA...
# 35  REGISTRO TRANSITORIO SEGUN SWIFT N° 488, HASTA...
# 36  REGISTRO TRANSITORIO SEGUN SWIFT N° 491, HASTA...
# 37  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 456 ...
# 38  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 457 ...
# 39  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 40  INTERÉS DEVENGADO DE TÍTULOS AL 13-01-2022, PO...
# 41  PAGO CHEQUE: D-20-98714     , BENEFICIARIO: EM...
# 42  REMESA ME - RECEPCION                         ...
# 43  DEPOSITO DE EFECTIVO, DEPOSITANTE: MERCANTIL S...
# 44  POR LA COMPRA DE DOLARES AMERICANOS           ...
# 45  PAGO CHEQUE: D-21-99961     , BENEFICIARIO: EM...
# 46  PAGO CHEQUE: D-21-99288     , BENEFICIARIO: MA...
# 47  PAGO CHEQUE: D-21-99767     , BENEFICIARIO: BR...
# 48  PAGO CHEQUE: D-19-97432     , BENEFICIARIO: BR...
# 49  DEPOSITO DE EFECTIVO, DEPOSITANTE: AGUILAR, CO...

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        ########## RRRRRRRRRRRR
        debemenoshaber(aux2.index)
        ########## RRRRRRRRRRRR   
        unRegistro=pd.DataFrame(data2,columns=columnas)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            if len(aux4)==2:
                for x in range(len(aux4)):

                    data1.append({
                        "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                        "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                        "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                                })
                    pares=pd.DataFrame(data1,columns=columnas)
                #################### 1
                print("largo de aux2: ",len(aux2))
                print(pares)
                data2=[]
                columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                    #print("Posible Neteo")
                    llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                    unRegistro=pd.DataFrame(data2,columns=columnas)
                else:     
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                        print('caso 1')
                        llenarData("Ingreso",0,1)        
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                        print('caso 2')
                        llenarData("Egreso",0,1)                   
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                        print('caso 3')
                        llenarData("Ingreso",1,0)                    
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                        print('caso 4')
                        llenarData("Egreso",1,0)
            else:
                
                #@#@#@#@#@#@#
                data2=[]
                columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
               
                ####BBBBBBBBBBBBBBBBBBB
                debemenoshaber(range(len(aux2)))
                ####BBBBBBBBBBBBBBBBBBB
                #@#@#@#@#@#@#
            #################### 1

        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas)
            ################### 2
            print(pares)
            data2=[]
            columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
            
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                
                
                data2=[]
                columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                ######### HHHHHHH
               # if len(aux2)==3 and aux2["mayor"][0] in cuentas and aux2["mayor"][1] in cuentas and aux2["mayor"][2]==680:
               #     llenarData("Neteo",0,1)
               # else:
                debemenoshaber(range(len(aux2)))
               
                ######### HHHHHHH 
            ################### 2
            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares ',pares["Comprobante"][0])
            
        ###$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
        ##### $$$$$$$$$$$$$$$
        unRegistro=pd.DataFrame(data2,columns=columnas)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado

#consolidado.to_excel("borrar13ene.xlsx")
# Out:
# Comprobante  0
# 21792
# largo cuando dentra al debehaber:  25
# Comprobante  1
# 28393
# largo cuando dentra al debehaber:  18
# Comprobante  2
# 1023484
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh         mo  moneda  codMov  \
# 0    S          NaN  D  579726.69      34    5896
# 1    S          NaN  H  506945.40      53    6535
# 2    S          NaN  D    4624.08      69     616
#
#                                               nomMov          mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3976925.09
# 1  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  3981549.17
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     4624.08
#
#                                                glosa  comprobante  mayor
# 0  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...      1023484     10
# 1  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...      1023484     10
# 2  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...      1023484    280
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023484        D     10    5896
# 1    S      1023484        H     10    6535
# 2    S      1023484        D    280     616
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  3976925.09
# 1  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  3981549.17
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     4624.08
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...           NaN
# 1  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...           NaN
# 2  'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  3
# 1023506
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023506        D    405    3305
# 1    S      1023506        H     10    5896
#
#                                           Movimiento          MN  \
# 0  GARANTIA POR ACREDITIVOS-INST.GOBIERNO CENTRAL...  6617616.99
# 1  NEW YORK - CTA. 3544020682001                 ...  6617616.99
#
#                                                Glosa  \
# 0  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 1  'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
#
#                                         GlosaDetalle
# 0  (CC:H-0043541-2021) I-2021-07 MHYE EEC-GNV / F...
# 1  PAGO N°6 LC I-2021-07 EEC-GNV FABER INDUSTRIE SPA
# caso 4
# dentro  1023506
# Comprobante  4
# 1023509
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023509        D     11    2902
# 1    S      1023509        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  27108.18
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  27108.18
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# caso 1
# dentro  1023509
# Comprobante  5
# 1023518
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023518        D     16    6286
# 1    S      1023518        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# caso 1
# dentro  1023518
# Comprobante  6
# 1023520
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023520        D     10    5896
# 1    S      1023520        H    412    5832
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  78042.52
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  78042.52
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
#
#                       GlosaDetalle
# 0           A LA CUENTA 03-H-307.
# 1  P/CTA. DE TAM LINHAS AEREAS S/A
# caso 1
# dentro  1023520
# Comprobante  7
# 1023522
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023522        D     10    5896
# 1    S      1023522        H    412    5832
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  16855.77
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  16855.77
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
#
#                                    GlosaDetalle
# 0                        A LA CUENTA 03-H-307.
# 1  P/CTA. DE ABSA  AEROLINHAS BRASILEIRAS S.A.
# caso 1
# dentro  1023522
# Comprobante  8
# 1023523
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023523        D     10    5896
# 1    S      1023523        H    412    4710
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  8349.44
# 1  03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...  8349.44
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
#
#                       GlosaDetalle
# 0           A LA CUENTA 03-W-302.
# 1  P. CTA DE 101DOMAIN GRS LIMITED
# caso 1
# dentro  1023523
# Comprobante  9
# 1023524
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023524        D     10    5896
# 1    S      1023524        H    403    3908
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  82320000.0
# 1  BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  82320000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CRED...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CRED...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CREDIT...
# caso 1
# dentro  1023524
# Comprobante  10
# 1023525
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023525        D     10    5896
# 1    S      1023525        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  34300000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  34300000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL ...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL S....
# caso 1
# dentro  1023525
# Comprobante  11
# 1023528
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023528        D     10    5896
# 1    S      1023528        H    403    3917
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  6860000.0
# 1  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  6860000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADER...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADER...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADERO ...
# caso 1
# dentro  1023528
# Comprobante  12
# 1023534
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023534        D     10    5896
# 1    S      1023534        H    412    5832
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68664.9
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  68664.9
#
#                                                Glosa              GlosaDetalle
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...    A LA CUENTA 03-H-307.
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...  P/CTA. DE ATLAS AIR INC
# caso 1
# dentro  1023534
# Comprobante  13
# 1023535
# Hay duplicado:  False
# aux2
#   tipo glosaRenglon dh         mo  moneda  codMov  \
# 0    S          NaN  D  260000.00      53    6072
# 1    S          NaN  H  295510.80      34    5896
# 2    S          NaN  H   14835.91      69    1585
#
#                                               nomMov          mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  2042040.00
# 1  NEW YORK - CTA. 3544020682001                 ...  2027204.09
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...    14835.91
#
#                                                glosa  comprobante  mayor
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...      1023535     10
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...      1023535     10
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...      1023535    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023535        D     10    6072
# 1    S      1023535        H     10    5896
# 2    S      1023535        H    680    1585
#
#                                           Movimiento          MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  2042040.00
# 1  NEW YORK - CTA. 3544020682001                 ...  2027204.09
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...    14835.91
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...           NaN
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...           NaN
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  14
# 1023536
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023536        D     10    5896
# 1    S      1023536        H    412    5832
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  26801.88
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  26801.88
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
#
#                                 GlosaDetalle
# 0                     A LA CUENTA 03-H-307.
# 1  P.CTA DE LINEA AEREA CARGUERA - DEBTOR IN
# caso 1
# dentro  1023536
# Comprobante  15
# 1023537
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023537        D     10    5896
# 1    S      1023537        H    404    7954
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  78533.28
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  78533.28
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 1  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
#
#                                         GlosaDetalle
# 0  A LA CUENTA YPFB – EXPORTACIÓN DE UREA Y OTROS...
# 1       P.CTA DE DREYMOOR FERTILIZERS OVERSEAS PTE L
# caso 1
# dentro  1023537
# Comprobante  16
# 1023541
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023541        D     10    5896
# 1    S      1023541        H    404    8291
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  262870.19
# 1  UTO - POSTGRADO UTO CAMIPER                   ...  262870.19
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0           A LA CUENTA - UTO POSTGRADO UTO CAMIPER.
# 1  POR CUENTA DE CAMARA MINERA DIPLOMADOS INTERNA...
# caso 1
# dentro  1023541
# Comprobante  17
# 1023553
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023553        D     10    6535
# 1    S      1023553        H     17    6296
#
#                                           Movimiento          MN  \
# 0  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  1471499.68
# 1  INTERESES DEVENGADOS                          ...  1471499.68
#
#                                                Glosa  GlosaDetalle
# 0  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,41 01/10...           NaN
# 1  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,41 01/10...           NaN
# Comprobante  18
# 1023555
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023555        D     10    6535
# 1    S      1023555        H     17    6296
#
#                                           Movimiento          MN  \
# 0  CTA. P03394 - 57603 PORTAFOLIO EURO           ...  3211236.55
# 1  INTERESES DEVENGADOS                          ...  3211236.55
#
#                                                Glosa  GlosaDetalle
# 0  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,26 01/11...           NaN
# 1  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,26 01/11...           NaN
# Comprobante  19
# 1023561
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1023561        D    498    8304
# 1    S      1023561        H     10    5896
#
#                                           Movimiento        MN  \
# 0  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  23852.36
# 1  NEW YORK - CTA. 3544020682001                 ...  23852.36
#
#                                                Glosa  \
# 0  'DEVOLUCION POR TRANSFERENCIA RECIBIDA DEL EXT...
# 1  'DEVOLUCION POR TRANSFERENCIA RECIBIDA DEL EXT...
#
#                  GlosaDetalle
# 0        (CC:H-0047255-2021)
# 1  SEGÚN GLOSA DE REFERENCIA.
# caso 4
# dentro  1023561
# Comprobante  20
# 1755863
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1755863        D    498    6817
# 1    G      1755863        H     10    5896
#
#                                           Movimiento          MN  \
# 0  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  68600000.0
# 1  NEW YORK - CTA. 3544020682001                 ...  68600000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  BANCO DE CREDITO DE BOLIVIA S.A., CTA. 3544031...
# caso 4
# dentro  1755863
# Comprobante  21
# 1756215
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756215        D     10    5896
# 1    G      1756215        H    412    4249
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  160219.0
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  160219.0
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.429 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.429 ...           NaN
# caso 1
# dentro  1756215
# Comprobante  22
# 1756217
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756217        D     10    5896
# 1    G      1756217        H    412    4249
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  39330.03
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  39330.03
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.436 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.436 ...           NaN
# caso 1
# dentro  1756217
# Comprobante  23
# 1756219
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756219        D     10    5896
# 1    G      1756219        H    412    4249
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  182099.18
# 1  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...  182099.18
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.441 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.441 ...           NaN
# caso 1
# dentro  1756219
# Comprobante  24
# 1756221
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756221        D     10    5896
# 1    G      1756221        H    412     818
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  644702.8
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  644702.8
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 469,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 469,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# caso 1
# dentro  1756221
# Comprobante  25
# 1756223
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756223        D     10    5896
# 1    G      1756223        H    412     818
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  458165.68
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  458165.68
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 468,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 468,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# caso 1
# dentro  1756223
# Comprobante  26
# 1756225
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756225        D     10    5896
# 1    G      1756225        H    412     818
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  758688.56
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  758688.56
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 467,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 467,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# caso 1
# dentro  1756225
# Comprobante  27
# 1756227
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756227        D     10    5896
# 1    G      1756227        H    412     818
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  607699.96
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  607699.96
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 470,...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 470,...
#
#                                        GlosaDetalle
# 0                                               NaN
# 1  CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# caso 1
# dentro  1756227
# Comprobante  28
# 1756581
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756581        D     10    5896
# 1    G      1756581        H    412    3987
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  15378.06
# 1  CUENTA UNICA DEL TESORO                       ...  15378.06
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 465 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 465 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# caso 1
# dentro  1756581
# Comprobante  29
# 1756583
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756583        D     10    5896
# 1    G      1756583        H    412     818
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1167142.22
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  1167142.22
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.485 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.485 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  CTA. 1-13550161 COMIBOL - EMPRESA METALURGICA ...
# caso 1
# dentro  1756583
# Comprobante  30
# 1756585
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756585        D     10    5896
# 1    G      1756585        H    404    7164
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1132349.26
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  1132349.26
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.487 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.487 ...           NaN
# caso 1
# dentro  1756585
# Comprobante  31
# 1756715
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756715        D     16    6758
# 1    G      1756715        H    499    7355
#
#                                           Movimiento          MN  \
# 0  TITULOS - PORTAFOLIO GLOBAL                   ...  8914930.49
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  8914930.49
#
#                                                Glosa  GlosaDetalle
# 0  REVALORACIÓN DE TÍTULOS AL 13-01-2022, PORTAFO...           NaN
# 1  REVALORACIÓN DE TÍTULOS AL 13-01-2022, PORTAFO...           NaN
# caso 1
# dentro  1756715
# Comprobante  32
# 1756716
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756716        D     10    5896
# 1    G      1756716        H    404    7164
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  238430.96
# 1  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...  238430.96
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 501,...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 501,...           NaN
# caso 1
# dentro  1756716
# Comprobante  33
# 1756719
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756719        D     10    5896
# 1    G      1756719        H    404    6215
#
#                                           Movimiento           MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  54982061.37
# 1  EMPRESA METALURGICA VINTO (EMV)               ...  54982061.37
#
#                                                Glosa  GlosaDetalle
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 493 ...           NaN
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 493 ...           NaN
# caso 1
# dentro  1756719
# Comprobante  34
# 1756722
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756722        D     10    5896
# 1    G      1756722        H    498    1470
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  62537.75
# 1  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  62537.75
#
#                                                Glosa         GlosaDetalle
# 0  REGISTRO TRANSITORIO SEGUN SWIFT N° 497, HASTA...                  NaN
# 1  REGISTRO TRANSITORIO SEGUN SWIFT N° 497, HASTA...  (CC:H-0000115-2022)
# caso 1
# dentro  1756722
# Comprobante  35
# 1756723
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756723        D     10    5896
# 1    G      1756723        H    498    1470
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  23139.12
# 1  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  23139.12
#
#                                                Glosa         GlosaDetalle
# 0  REGISTRO TRANSITORIO SEGUN SWIFT N° 488, HASTA...                  NaN
# 1  REGISTRO TRANSITORIO SEGUN SWIFT N° 488, HASTA...  (CC:H-0000116-2022)
# caso 1
# dentro  1756723
# Comprobante  36
# 1756724
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756724        D     10    5896
# 1    G      1756724        H    498    1470
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  7384.04
# 1  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  7384.04
#
#                                                Glosa         GlosaDetalle
# 0  REGISTRO TRANSITORIO SEGUN SWIFT N° 491, HASTA...                  NaN
# 1  REGISTRO TRANSITORIO SEGUN SWIFT N° 491, HASTA...  (CC:H-0000117-2022)
# caso 1
# dentro  1756724
# Comprobante  37
# 1756725
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756725        D     10    5896
# 1    G      1756725        H    412    3987
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  450262.96
# 1  CUENTA UNICA DEL TESORO                       ...  450262.96
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 456 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 456 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# caso 1
# dentro  1756725
# Comprobante  38
# 1756727
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756727        D     10    5896
# 1    G      1756727        H    412    3987
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  146285.86
# 1  CUENTA UNICA DEL TESORO                       ...  146285.86
#
#                                                Glosa  \
# 0  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 457 ...
# 1  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 457 ...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# caso 1
# dentro  1756727
# Comprobante  39
# 1756838
# Hay duplicado:  False
# aux2
#   tipo                                       glosaRenglon dh          mo  \
# 0    G  FLOTTWEG SE, CTA. DE06700500000000030176 BAYER...  H   258142.79
# 1    G  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...  D    57008.19
# 2    G  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...  D     2297.47
# 3    G                                                NaN  D  2000000.00
# 4    G                                                NaN  H      191.40
# 5    G                                                NaN  H       43.50
# 6    G                                                NaN  H     1763.90
# 7    G                                                NaN  H    29554.71
#
#    moneda  codMov                                             nomMov  \
# 0      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 1      69     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 2      69     818  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...
# 3      69    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 4      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 5      69    1514  UTILES DE ESCRITORIO                          ...
# 6      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
# 7      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#            mn                                              glosa  comprobante  \
# 0  2027453.47  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 1    57008.19  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 2     2297.47  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 3  2000000.00  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 4      191.40  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 5       43.50  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 6     1763.90  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
# 7    29554.71  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1756838
#
#    mayor
# 0     10
# 1    412
# 2    412
# 3    498
# 4    600
# 5    600
# 6    650
# 7    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756838        H     10    6072
# 1    G      1756838        D    412     818
# 2    G      1756838        D    412     818
# 3    G      1756838        D    498    4088
# 4    G      1756838        H    600    1510
# 5    G      1756838        H    600    1514
# 6    G      1756838        H    650    1563
# 7    G      1756838        H    680    6890
#
#                                           Movimiento          MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  2027453.47
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    57008.19
# 2  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     2297.47
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  2000000.00
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 5  UTILES DE ESCRITORIO                          ...       43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     1763.90
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    29554.71
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  FLOTTWEG SE, CTA. DE06700500000000030176 BAYER...
# 1  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...
# 2  CTA. 10000004713413 COMIBOL -  EMPRESA MINERA ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  8
# Comprobante  40
# 1756890
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1756890        D     17    6296
# 1    G      1756890        H    606    6538
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS                          ...  41592.43
# 1  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...  41592.43
#
#                                                Glosa  GlosaDetalle
# 0  INTERÉS DEVENGADO DE TÍTULOS AL 13-01-2022, PO...           NaN
# 1  INTERÉS DEVENGADO DE TÍTULOS AL 13-01-2022, PO...           NaN
# caso 1
# dentro  1756890
# Comprobante  41
# 1991256
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991256        D    403    3907
# 1    O      1991256        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-20-98714     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-20-98714     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1991256
# Comprobante  42
# 1991297
# Hay duplicado:  True
# aux4
# [0, 1, 2]
# largo cuando dentra al debehaber:  3
# Comprobante  43
# 1991308
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991308        D      7    3491
# 1    O      1991308        H    414    7245
#
#                                           Movimiento       MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  1558.04
# 1  DEPOSITOS POR APORTES FPA - LEY 365           ...  1558.04
#
#                                                Glosa  GlosaDetalle
# 0  DEPOSITO DE EFECTIVO, DEPOSITANTE: MERCANTIL S...           NaN
# 1  DEPOSITO DE EFECTIVO, DEPOSITANTE: MERCANTIL S...           NaN
# caso 1
# dentro  1991308
# Comprobante  44
# 1991311
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991311        D      7    3491
# 1    O      1991311        H    400     654
#
#                                           Movimiento    MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  6.04
# 1  BILLETES Y MONEDAS EN CIRCULACION             ...  6.04
#
#                                                Glosa  GlosaDetalle
# 0  POR LA COMPRA DE DOLARES AMERICANOS           ...           NaN
# 1  POR LA COMPRA DE DOLARES AMERICANOS           ...           NaN
# caso 1
# dentro  1991311
# Comprobante  45
# 1991318
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991318        D    403    3917
# 1    O      1991318        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  34300000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  34300000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99961     , BENEFICIARIO: EM...           NaN
# 1  PAGO CHEQUE: D-21-99961     , BENEFICIARIO: EM...           NaN
# caso 4
# dentro  1991318
# Comprobante  46
# 1991351
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991351        D    403    3910
# 1    O      1991351        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99288     , BENEFICIARIO: MA...           NaN
# 1  PAGO CHEQUE: D-21-99288     , BENEFICIARIO: MA...           NaN
# caso 4
# dentro  1991351
# Comprobante  47
# 1991354
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991354        D    403    6893
# 1    O      1991354        H      7    3491
#
#                                           Movimiento         MN  \
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99767     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99767     , BENEFICIARIO: BR...           NaN
# caso 4
# dentro  1991354
# Comprobante  48
# 1991355
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1991355        D    403    3915
# 1    O      1991355        H      7    3491
#
#                                           Movimiento          MN  \
# 0  BCO.ECONOMICO-CUENTA CORRIENTE Y DE ENCAJE    ...  20580000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  20580000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-19-97432     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-19-97432     , BENEFICIARIO: BR...           NaN
# caso 4
# dentro  1991355
# Comprobante  49
# 1991403
# Hay duplicado:  True
# aux4
# [0, 1, 2]
# largo cuando dentra al debehaber:  3
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21792  Ingreso      17      10    6072
# 1     V        28393  Ingreso      22      17    6296
# 2     S      1023484   Egreso      10      10    6535
# 3     S      1023506   Egreso      10     405    3305
# 4     S      1023509  Ingreso      11     606    1535
# 5     S      1023518  Ingreso      16     499    7355
# 6     S      1023520  Ingreso      10     412    5832
# 7     S      1023522  Ingreso      10     412    5832
# 8     S      1023523  Ingreso      10     412    4710
# 9     S      1023524  Ingreso      10     403    3908
# 10    S      1023525  Ingreso      10     414    7866
# 11    S      1023528  Ingreso      10     403    3917
# 12    S      1023534  Ingreso      10     412    5832
# 13    S      1023535  Ingreso      10      10    5896
# 14    S      1023536  Ingreso      10     412    5832
# 15    S      1023537  Ingreso      10     404    7954
# 16    S      1023541  Ingreso      10     404    8291
# 17    S      1023553    Neteo      10      17    6296
# 18    S      1023555    Neteo      10      17    6296
# 19    S      1023561   Egreso      10     498    8304
# 20    G      1755863   Egreso      10     498    6817
# 21    G      1756215  Ingreso      10     412    4249
# 22    G      1756217  Ingreso      10     412    4249
# 23    G      1756219  Ingreso      10     412    4249
# 24    G      1756221  Ingreso      10     412     818
# 25    G      1756223  Ingreso      10     412     818
# 26    G      1756225  Ingreso      10     412     818
# 27    G      1756227  Ingreso      10     412     818
# 28    G      1756581  Ingreso      10     412    3987
# 29    G      1756583  Ingreso      10     412     818
# 30    G      1756585  Ingreso      10     404    7164
# 31    G      1756715  Ingreso      16     499    7355
# 32    G      1756716  Ingreso      10     404    7164
# 33    G      1756719  Ingreso      10     404    6215
# 34    G      1756722  Ingreso      10     498    1470
# 35    G      1756723  Ingreso      10     498    1470
# 36    G      1756724  Ingreso      10     498    1470
# 37    G      1756725  Ingreso      10     412    3987
# 38    G      1756727  Ingreso      10     412    3987
# 39    G      1756838   Egreso      10     412     818
# 40    G      1756890  Ingreso      17     606    6538
# 41    O      1991256   Egreso       7     403    3907
# 42    O      1991297   Egreso       7     828    3499
# 43    O      1991308  Ingreso       7     414    7245
# 44    O      1991311  Ingreso       7     400     654
# 45    O      1991318   Egreso       7     403    3917
# 46    O      1991351   Egreso       7     403    3910
# 47    O      1991354   Egreso       7     403    6893
# 48    O      1991355   Egreso       7     403    3915
# 49    O      1991403  Ingreso       7     828    3500
#
#                                            Movimiento     MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...         0.01
# 1   INTERESES DEVENGADOS                          ...   5002611.41
# 2   CTA. P03394 - 57603 PORTAFOLIO EURO           ...       674.06
# 3   GARANTIA POR ACREDITIVOS-INST.GOBIERNO CENTRAL...    964667.20
# 4   INTERESES OVERNIGHT CAPITAL TRABAJO           ...      3951.63
# 5   VALORACION TITULOS DE LAS RESERVAS INTERNACION...        38.90
# 6   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     11376.46
# 7   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...      2457.11
# 8   03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...      1217.12
# 9   BCO.DE CREDITO-CUENTA CORRIENTE Y DE ENCAJE   ...  12000000.00
# 10  EFECTIVO GARANTIA FONDO CPVIS                 ...   5000000.00
# 11  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   1000000.00
# 12  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     10009.46
# 13  NEW YORK - CTA. 3544020682001                 ...      2162.67
# 14  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...      3906.98
# 15  YPFB - EXPORTACION DE UREA Y OTROS            ...     11448.00
# 16  UTO - POSTGRADO UTO CAMIPER                   ...     38319.27
# 17  INTERESES DEVENGADOS                          ...         0.00
# 18  INTERESES DEVENGADOS                          ...         0.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      3477.02
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  10000000.00
# 21  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     23355.54
# 22  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...      5733.24
# 23  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     26545.07
# 24  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     93980.00
# 25  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     66788.00
# 26  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    110596.00
# 27  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...     88586.00
# 28  CUENTA UNICA DEL TESORO                       ...      2241.70
# 29  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    170137.35
# 30  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...    165065.49
# 31  VALORACION TITULOS DE LAS RESERVAS INTERNACION...   1299552.55
# 32  YPFB - CTA. EXPORTACION DE GLP Y OTROS        ...     34756.70
# 33  EMPRESA METALURGICA VINTO (EMV)               ...   8014877.75
# 34  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      9116.29
# 35  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      3373.05
# 36  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...      1076.39
# 37  CUENTA UNICA DEL TESORO                       ...     65636.00
# 38  CUENTA UNICA DEL TESORO                       ...     21324.47
# 39  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...    295547.15
# 40  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...      6063.04
# 41  BCO.MERCANTIL SANTA CRUZ SA - CTA.CTE. Y DE EN...   5000000.00
# 42  DOLARES AMERICANOS EN TESORO AUXILIAR         ...        -0.00
# 43  DEPOSITOS POR APORTES FPA - LEY 365           ...       227.12
# 44  BILLETES Y MONEDAS EN CIRCULACION             ...         0.88
# 45  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...   5000000.00
# 46  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...    500000.00
# 47  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...    500000.00
# 48  BCO.ECONOMICO-CUENTA CORRIENTE Y DE ENCAJE    ...   3000000.00
# 49  DOLARES AMERICANOS EN CAJAS                   ...   2780000.00
#
#                                               Detalle  \
# 0   Saldo ME = 107142.92 ;Bs/Mo: 6.86000000000 ;Sa...
# 1   Saldo Ant.= 36491.00 ;Bs: 9.61675960000 = $us ...
# 2                                                 NaN
# 3   (CC:H-0043541-2021) I-2021-07 MHYE EEC-GNV / F...
# 4                                                 NaN
# 5                                                 NaN
# 6                     P/CTA. DE TAM LINHAS AEREAS S/A
# 7        P/CTA. DE ABSA  AEROLINHAS BRASILEIRAS S.A.
# 8                     P. CTA DE 101DOMAIN GRS LIMITED
# 9   TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CREDIT...
# 10  TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL S....
# 11  TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADERO ...
# 12                           P/CTA. DE ATLAS AIR INC
# 13                                                NaN
# 14          P.CTA DE LINEA AEREA CARGUERA - DEBTOR IN
# 15       P.CTA DE DREYMOOR FERTILIZERS OVERSEAS PTE L
# 16  POR CUENTA DE CAMARA MINERA DIPLOMADOS INTERNA...
# 17                                     (±, 214504.33)
# 18                                     (±, 468110.28)
# 19                               (CC:H-0047255-2021)
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 25   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 26   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 27   CTA. 1-28536651 EBA - ALMENDRA VENTA EXPORTACION
# 28  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 29  CTA. 1-13550161 COMIBOL - EMPRESA METALURGICA ...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                (CC:H-0000115-2022)
# 35                                (CC:H-0000116-2022)
# 36                                (CC:H-0000117-2022)
# 37  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 38  LIB. 00010011102 MIN.RELACIONES EXTERIORES - G...
# 39  FLOTTWEG SE, CTA. DE06700500000000030176 BAYER...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                                 Glosa
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACIONES FOREX POR'||DE VENTA DE EUR 506.9...
# 3   'RESPUESTA AL BANQUERO POR CANCELACION DE CART...
# 4   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 5   ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 6   ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 7   ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 8   ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 9   ||TRANSFERENCIA DEL EXTERIOR DEL BANCO DE CRED...
# 10  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO FASSIL ...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO GANADER...
# 12  ||TRANSFERENCIA DE FONDOS S/G MENSAJES SWIFT N...
# 13  'OPERACION FOREX'||DE COMPRA DE EUR 260.000,00...
# 14  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 15  ||TRANSFERENCIA DE FONDOS S/G MENSAJE SWIFT NR...
# 16  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 17  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,41 01/10...
# 18  ||PAGO DE CUPON DE UN TITULO EFGBNK 0,26 01/11...
# 19  'DEVOLUCION POR TRANSFERENCIA RECIBIDA DEL EXT...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.429 ...
# 22  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.436 ...
# 23  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.441 ...
# 24  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 469,...
# 25  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 468,...
# 26  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 467,...
# 27  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 470,...
# 28  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 465 ...
# 29  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.485 ...
# 30  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.487 ...
# 31  REVALORACIÓN DE TÍTULOS AL 13-01-2022, PORTAFO...
# 32  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 501,...
# 33  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 493 ...
# 34  REGISTRO TRANSITORIO SEGUN SWIFT N° 497, HASTA...
# 35  REGISTRO TRANSITORIO SEGUN SWIFT N° 488, HASTA...
# 36  REGISTRO TRANSITORIO SEGUN SWIFT N° 491, HASTA...
# 37  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 456 ...
# 38  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO 457 ...
# 39  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 40  INTERÉS DEVENGADO DE TÍTULOS AL 13-01-2022, PO...
# 41  PAGO CHEQUE: D-20-98714     , BENEFICIARIO: EM...
# 42  REMESA ME - RECEPCION                         ...
# 43  DEPOSITO DE EFECTIVO, DEPOSITANTE: MERCANTIL S...
# 44  POR LA COMPRA DE DOLARES AMERICANOS           ...
# 45  PAGO CHEQUE: D-21-99961     , BENEFICIARIO: EM...
# 46  PAGO CHEQUE: D-21-99288     , BENEFICIARIO: MA...
# 47  PAGO CHEQUE: D-21-99767     , BENEFICIARIO: BR...
# 48  PAGO CHEQUE: D-19-97432     , BENEFICIARIO: BR...
# 49  DEPOSITO DE EFECTIVO, DEPOSITANTE: AGUILAR, CO...

# %%
texto1 = "PAGO A EXIMBANK CHINA POPUL PRÉSTAMO PBC 2015 (08) 350 VCTO. 21-01-2022 POR CUENTA DE TGN , NTI. 015626 VALOR 21-01-2022 CAPITAL USD 27.355.555,56 COMISIONES USD 260.358,75"
texto2= "PAGO A AFD PRÉSTAMO CBO-1009-01-J VCTO. 21-01-2022 POR CUENTA DE ENDE , VALOR 21-01-2022  INTERESES EUR 168.666,67"

#capital = re.findall(" CAPITAL (.*)(?= [IC])" , texto1)
capital = re.findall(" CAPITAL (.*)(?= [INTERESES][COMISIONES])" , texto1)
intereses = re.findall(" INTERESES (.*)(?=[C\s])" , texto1)
comisiones = re.findall(" COMISIONES (.*)" , texto1)

#t= pd.DataFrame(search)
#t
print(capital, intereses, comisiones)
# Out:
# [] [] ['USD 260.358,75']
