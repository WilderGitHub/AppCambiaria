# %%
import numpy as np
import pandas as pd
import re
import itertools
from pandas import Series, DataFrame
gtes = "gtes07feb.xls"
goi = "goi07feb.xls"
gom = "gom07feb.xls"
gef = "gef07feb.xls"
parametros = "parametros.xlsx"
cuentas=[7,10,11,12,16,17]
valorDefecto = "Ver glosita"
bdgtes = pd.read_excel('../data/'+gtes)
bdgoi = pd.read_excel('../data/'+goi)
bdgom = pd.read_excel('../data/'+gom)
bdgef = pd.read_excel('../data/'+gef)
movimientos =pd.read_excel('../data/'+parametros, sheet_name="movimientos")
bdBruto= pd.concat([bdgtes,bdgoi,bdgom,bdgef],ignore_index=True)
#bd.describe()
#movimientos
palabrasClave =pd.read_excel('../data/'+parametros, sheet_name="palabras")
listaPalabrasClave = palabrasClave['PalabrasClave'].values.tolist()
#listaPalabrasClave = ["sedem","ENVIBOL","COMIBOL"]
apachurrado=''
for palabrita in listaPalabrasClave:
   # apachurrado +='|'+'"'+ palabrita+'"'
    apachurrado +='|'+ palabrita
apachurrado=apachurrado[1:]

#listaPalabrasClave
#apachurrado
# Out:
# WARNING *** file size (676398) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (512947) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (3589224) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (4821795) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
bdBruto.shape
# Out:
# (7043, 30)

# %%
bdReducida=bdBruto.loc[:,('nro_centro','cve_tipo_comprob','glosa_reng','cve_debe_haber','monto_mo',
           'cod_moneda', 'cod_movimiento', 'nom_movimiento',
           'monto_mn','glosa_comprob','nro_comprob','cod_mayor')]
#bdReducida

# %%
type(bdReducida)
# Out:
# pandas.core.frame.DataFrame

# %%
index_names = bdReducida[ bdReducida['nro_centro'] != 1 ].index
bdReducida.drop(index_names, inplace = True)
bdReducida
# Out:
#       nro_centro cve_tipo_comprob                          glosa_reng  \
# 0              1                O                                 NaN
# 1              1                O                                 NaN
# 2              1                O                                 NaN
# 3              1                O                                 NaN
# 4              1                O                                 NaN
# ...          ...              ...                                 ...
# 7038           1                S                                 NaN
# 7039           1                S                                 NaN
# 7040           1                S       ANOTACION EN CUENTA FACT. 384
# 7041           1                S  INTERMEDIACION DE VALORES FACT 386
# 7042           1                S                                 NaN
#
#      cve_debe_haber  monto_mo  cod_moneda  cod_movimiento  \
# 0                 H      9.58          69             459
# 1                 D      9.65          69             459
# 2                 H  51086.44          69            1483
# 3                 H   1267.92          69            1483
# 4                 H   1040.00          69            1483
# ...             ...       ...         ...             ...
# 7038              H   4818.54          69            7425
# 7039              H     11.35          69            7425
# 7040              H  19116.48          69            7425
# 7041              H  22937.91          69            7425
# 7042              D   1084.00          69            7425
#
#                                          nom_movimiento  monto_mn  \
# 0     DEUDORES DIVERSOS TESORERIA                   ...      9.58
# 1     DEUDORES DIVERSOS TESORERIA                   ...      9.65
# 2     ACREEDORES POR DOCUMENTOS DE COBRO INMEDIATO  ...  51086.44
# 3     ACREEDORES POR DOCUMENTOS DE COBRO INMEDIATO  ...   1267.92
# 4     ACREEDORES POR DOCUMENTOS DE COBRO INMEDIATO  ...   1040.00
# ...                                                 ...       ...
# 7038  VUN AGENCIA DE BOLSA - CUENTA DE LIQUIDACION  ...   4818.54
# 7039  VUN AGENCIA DE BOLSA - CUENTA DE LIQUIDACION  ...     11.35
# 7040  VUN AGENCIA DE BOLSA - CUENTA DE LIQUIDACION  ...  19116.48
# 7041  VUN AGENCIA DE BOLSA - CUENTA DE LIQUIDACION  ...  22937.91
# 7042  VUN AGENCIA DE BOLSA - CUENTA DE LIQUIDACION  ...   1084.00
#
#                                           glosa_comprob  nro_comprob  \
# 0     DEPOSITO DE EFECTIVO, DEPOSITANTE: JHESENIA VA...      1997384
# 1     FALTANTE                                      ...      1997398
# 2      DEPOSITO DE CHEQUES AJENOS, CONCEPTO: REEMBOL...      1997172
# 3      DEPOSITO DE CHEQUES AJENOS, CONCEPTO: DEVOLUC...      1997177
# 4      DEPOSITO DE CHEQUES AJENOS, CONCEPTO: DESCUEN...      1997179
# ...                                                 ...          ...
# 7038  ||REGISTRO DEL PAGO DE COMISIONES A VALORES UN...      1025415
# 7039  ||REGISTRO DE LA DISMINUCION DE LA GARANTIA RE...      1025425
# 7040  ||REGISTRO DEL PAGO DE COMISIONES AL VALORES U...      1025427
# 7041  ||REGISTRO DEL PAGO DE COMISIONES AL VALORES U...      1025427
# 7042  ||REGISTRO DE LA RETENCION DE LA GARANTIA RETE...      1025428
#
#       cod_mayor
# 0           198
# 1           198
# 2           498
# 3           498
# 4           498
# ...         ...
# 7038        414
# 7039        414
# 7040        414
# 7041        414
# 7042        414
#
# [6957 rows x 12 columns]

# %%
bdReducida.shape
# Out:
# (6957, 12)

# %%
dict = {'cve_tipo_comprob':'tipo','glosa_reng':'glosaRenglon','cve_debe_haber':'dh','monto_mo':'mo',
           'cod_moneda':'moneda', 'cod_movimiento':'codMov', 'nom_movimiento':'nomMov',
           'monto_mn':'mn','glosa_comprob':'glosa','nro_comprob':'comprobante','cod_mayor':'mayor'}
bdReducida.rename(columns=dict,
          inplace=True)
#bdReducida.shape

# %%
#bd['mayor'].unique()

#bdFiltro1=bdReducida[bdReducida['mayor'].isin([7,10,11,16,17])]
bdFiltro1=bdReducida[bdReducida['mayor'].isin(cuentas)]

# %%
#bdFiltro1.loc[:,("comprobante","mayor")]
bdFiltro1["comprobante"].unique()
#bdFiltro1.sort_values(by="comprobante", ascending=True)
# Out:
# array([1997192, 1997212, 1997224, 1997225, 1997255, 1997265, 1997267,
#        1997352, 1997277, 1025347,   28487, 1779148, 1025337, 1778876,
#        1025355, 1025388,   21863, 1779021, 1779022, 1779023, 1779024,
#        1779147, 1025377, 1779146, 1778875, 1778877, 1778878, 1778879,
#        1778880, 1778881, 1778882, 1778883, 1778884, 1778885, 1778886,
#        1778887, 1778888, 1778889, 1778891, 1778893, 1779150, 1025383,
#        1025374, 1025378, 1025371, 1025368, 1025366, 1025365, 1779152,
#        1779153, 1779295, 1779296, 1025393, 1779298, 1025404, 1025405,
#        1025406, 1025390, 1025391], dtype=int64)

# %%
#bd[bd['comprobante'].isin(bdFiltro1["comprobante"])].sort_values(by="comprobante", ascending=True).tail(60)
bd=bdReducida[bdReducida["comprobante"].isin(bdFiltro1["comprobante"])].sort_values(by=["comprobante","dh"], ascending=True)
bd = bd.reset_index(drop=True)
#bd.head(60)

# %%
#list(bd.loc[55,["glosa"]])

# %%
#bd.to_excel("ux.xlsx")

# %%
bd=bd.drop_duplicates()
bd = bd.reset_index(drop=True)
#bd.head(60)

# %%
#bd["comprobante"].unique()

# %%
def llenarData(concepto,a,b):
    if concepto !="Neteo":    
        print('dentro ',pares["Comprobante"][a])
        data2.append({
                 "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":round(pares["MN"][a]/6.86,2),
                "Detalle":pares["GlosaDetalle"][b],"Glosa":pares["Glosa"][a]
                })
    else:
        data2.append({
                "Tipo":pares["Tipo"][a],"Comprobante":pares["Comprobante"][a],"Concepto":concepto,
                "Mayor1":pares["Mayor"][a],"Mayor2":pares["Mayor"][b],"codMov":pares["codMov"][b],
                "Movimiento":pares["Movimiento"][b],"MontoUSD":0, 
                "Detalle":("±", round(pares["MN"][a]/6.86,2)),"Glosa":pares["Glosa"][a]
                })

def dv(concepto,suma):
    print("largo cuando dentra al debehaber: ",len(aux2))
    if len(aux2)==1:
        data2.append({''
                     "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                    "Mayor1":aux2["mayor"][0],"Mayor2":"--","codMov":"--",
                    "Movimiento":"--","MontoUSD":round(suma,2),
                    "Detalle":aux2["glosaRenglon"][0],"Glosa":aux2["glosa"][0]
                    })
    else:
        data2.append({''
                     "Tipo":aux2["tipo"][0],"Comprobante":aux2["comprobante"][0],"Concepto":concepto,
                    "Mayor1":aux2["mayor"][0],"Mayor2":aux2["mayor"][1],"codMov":aux2["codMov"][1],
                    "Movimiento":aux2["nomMov"][1],"MontoUSD":round(suma,2),
                    "Detalle":aux2["glosaRenglon"][0],"Glosa":aux2["glosa"][0]
                    })

def debemenoshaber(hasta):
    sumaDebe=0
    sumaHaber=0
    for i in hasta:
        if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
            sumaDebe=sumaDebe+aux2["mn"][i]/6.86
        elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
            sumaHaber=sumaHaber+aux2["mn"][i]/6.86
    suma=sumaDebe-sumaHaber
    if suma>0:
        dv("Ingreso",suma)
    else:
        dv("Egreso",-suma)

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas1=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    data2=[]
    columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        data2=[]
        columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        sumaDebe=0
        sumaHaber=0
        for i in aux2.index:
            if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                sumaDebe=sumaDebe+aux2["mn"][i]/6.86
            elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                sumaHaber=sumaHaber+aux2["mn"][i]/6.86
        suma=sumaDebe-sumaHaber
        if suma>0:
            dv("Ingreso",suma)
            #unRegistro=pd.DataFrame(data2,columns=columnas)
            #consolidado=consolidado.append(unRegistro, ignore_index=True)
        else:
            dv("Egreso",-suma)
            #unRegistro=pd.DataFrame(data2,columns=columnas)
            #consolidado=consolidado.append(unRegistro, ignore_index=True)
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        #print ("menos Tipo D o V")
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            for x in range(len(aux4)):

                data1.append({
                    "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                    "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                    "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)

        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)

            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares ',pares["Comprobante"][0])
        print(pares)
        data2=[]
        columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes

        if len(aux2)==2: ### los pares. Este sería el caso normal
            print("largo de aux2: ",len(aux2))
            if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                #print("Posible Neteo")
                llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                unRegistro=pd.DataFrame(data2,columns=columnas2)
            else:     
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                    print('caso 1')
                    llenarData("Ingreso",0,1)        
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                    print('caso 2')
                    llenarData("Egreso",0,1)                   
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                    print('caso 3')
                    llenarData("Ingreso",1,0)                    
                if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                    print('caso 4')
                    llenarData("Egreso",1,0)
        else:
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                ###
                data2=[]
                columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                sumaDebe=0
                sumaHaber=0
                for i in range(len(aux2)):
                    if aux2["mayor"][i] in cuentas and aux2["dh"][i]=='D':
                        sumaDebe=sumaDebe+aux2["mn"][i]/6.86
                    elif aux2["mayor"][i] in cuentas and aux2["dh"][i]=='H':
                        sumaHaber=sumaHaber+aux2["mn"][i]/6.86
                suma=sumaDebe-sumaHaber
                if suma>0:
                    dv("Ingreso",suma)
                    #unRegistro=pd.DataFrame(data2,columns=columnas)
                    #consolidado=consolidado.append(unRegistro, ignore_index=True)
                else:
                    dv("Egreso",-suma)
                    #unRegistro=pd.DataFrame(data2,columns=columnas)
                    #consolidado=consolidado.append(unRegistro, ignore_index=True)
                ####

        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar1.xlsx")
# Out:
# Comprobante  0
# 21863
# largo cuando dentra al debehaber:  20
# Comprobante  1
# 28487
# largo cuando dentra al debehaber:  18
# Comprobante  2
# 1025337
# Hay duplicado:  False
# aux2
#    nro_centro tipo glosaRenglon dh         mo  moneda  codMov  \
# 0           1    S          NaN  D  100000.00      53    6072
# 1           1    S          NaN  H  114408.00      34    5896
# 2           1    S          NaN  H     975.12      69    1585
#
#                                               nomMov         mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  785814.00
# 1  NEW YORK - CTA. 3544020682001                 ...  784838.88
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     975.12
#
#                                                glosa  comprobante  mayor
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337     10
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337     10
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025337        D     10    6072
# 1    S      1025337        H     10    5896
# 2    S      1025337        H    680    1585
#
#                                           Movimiento         MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  785814.00
# 1  NEW YORK - CTA. 3544020682001                 ...  784838.88
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     975.12
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  3
# 1025347
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025347        D     11    2902
# 1    S      1025347        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  49023.55
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  49023.55
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# largo de aux2:  2
# caso 1
# dentro  1025347
# Comprobante  4
# 1025355
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    S                         SWIFT N° 1805 DE LA FECHA.  H
# 1           1    S  CTA. 00132032001 ECEBOL - GESTION OPERATIVA CO...  D
# 2           1    S  CTA. 00132032001 ECEBOL - GESTION OPERATIVA, C...  D
# 3           1    S                                                NaN  H
# 4           1    S                                                NaN  H
#
#        mo  moneda  codMov                                             nomMov  \
# 0   17.50      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 1  139.52      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2   50.00      69    3987  CUENTA UNICA DEL TESORO                       ...
# 3   43.50      69    1514  UTILES DE ESCRITORIO                          ...
# 4    2.00      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#        mn                                              glosa  comprobante  \
# 0  137.52  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 1  139.52  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 2   50.00  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 3   43.50  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 4    2.00  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
#
#    mayor
# 0     10
# 1    412
# 2    412
# 3    600
# 4    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025355        H     10    6072
# 1    S      1025355        D    412    3987
# 2    S      1025355        D    412    3987
# 3    S      1025355        H    600    1514
# 4    S      1025355        H    680    6890
#
#                                           Movimiento      MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  137.52
# 1  CUENTA UNICA DEL TESORO                       ...  139.52
# 2  CUENTA UNICA DEL TESORO                       ...   50.00
# 3  UTILES DE ESCRITORIO                          ...   43.50
# 4  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.00
#
#                                                Glosa  \
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
#
#                                         GlosaDetalle
# 0                         SWIFT N° 1805 DE LA FECHA.
# 1  CTA. 00132032001 ECEBOL - GESTION OPERATIVA CO...
# 2  CTA. 00132032001 ECEBOL - GESTION OPERATIVA, C...
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  5
# 1025365
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025365        D     10    5896
# 1    S      1025365        H    412    4710
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  11849.76
# 1  03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...  11849.76
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                            GlosaDetalle
# 0                 A LA CUENTA 03-W-302.
# 1  POR CUENTA DE 101DOMAIN GRS LIMITED.
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  6
# 1025366
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025366        D     10    5896
# 1    S      1025366        H    412    5832
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  13276.5
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  13276.5
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0                              A LA CUENTA 03-H-307.
# 1  POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  7
# 1025368
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025368        D     10    5896
# 1    S      1025368        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1730435.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  1730435.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1       POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# largo de aux2:  2
# caso 1
# dentro  1025368
# Comprobante  8
# 1025371
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025371        D     10    5896
# 1    S      1025371        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  2076522.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  2076522.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1       POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# largo de aux2:  2
# caso 1
# dentro  1025371
# Comprobante  9
# 1025374
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025374        D     10    5896
# 1    S      1025374        H    404    7954
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  536211.9
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  536211.9
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# largo de aux2:  2
# caso 1
# dentro  1025374
# Comprobante  10
# 1025377
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025377        D     16    6286
# 1    S      1025377        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# largo de aux2:  2
# caso 1
# dentro  1025377
# Comprobante  11
# 1025378
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025378        D     10    5896
# 1    S      1025378        H    403    3910
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  24696000.0
# 1  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  24696000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  12
# 1025383
# Hay duplicado:  True
# aux4
# [0, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025383        D     10    5896
# 1    S      1025383        H    412     818
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  4733.4
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  4733.4
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
#
#                                         GlosaDetalle
# 0  A LA CUENTA 1-2232746 UAGRM FAC.DE CIENCIAS EX...
# 1  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  13
# 1025388
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025388        D    198    3641
# 1    S      1025388        H     10    6072
#
#                                           Movimiento     MN  \
# 0  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...  78.58
# 1  MADRID EUROS CUENTA ES2990299029960000000107  ...  78.58
#
#                                                Glosa  \
# 0  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 1  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
#
#                                        GlosaDetalle
# 0  (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 1                          COMISIONES DEL BANQUERO.
# largo de aux2:  2
# caso 4
# dentro  1025388
# Comprobante  14
# 1025390
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025390        D     10    5896
# 1    S      1025390        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1509.2
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1509.2
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046564-2022)
# largo de aux2:  2
# caso 1
# dentro  1025390
# Comprobante  15
# 1025391
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025391        D     10    5896
# 1    S      1025391        H    498    8304
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10564.4
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  10564.4
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046565-2022)
# largo de aux2:  2
# caso 1
# dentro  1025391
# Comprobante  16
# 1025393
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025393        D     10    5896
# 1    S      1025393        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  48020000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  48020000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# largo de aux2:  2
# caso 1
# dentro  1025393
# Comprobante  17
# 1025404
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025404        D     10    5896
# 1    S      1025404        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1543.5
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1543.5
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046569-2022)
# largo de aux2:  2
# caso 1
# dentro  1025404
# Comprobante  18
# 1025405
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025405        D     10    5896
# 1    S      1025405        H    498    8304
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1392.58
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1392.58
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046570-2022)
# largo de aux2:  2
# caso 1
# dentro  1025405
# Comprobante  19
# 1025406
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025406        D     10    5896
# 1    S      1025406        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  4561.9
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  4561.9
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046571-2022)
# largo de aux2:  2
# caso 1
# dentro  1025406
# Comprobante  20
# 1778875
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778875        D    498    6817
# 1    G      1778875        H     10    5896
#
#                                           Movimiento          MN  \
# 0  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  34300000.0
# 1  NEW YORK - CTA. 3544020682001                 ...  34300000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  BANCO GANADERO S.A., CTA. 496553483 JPMORGAN C...
# largo de aux2:  2
# caso 4
# dentro  1778875
# Comprobante  21
# 1778876
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...  H
# 1           1    G  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...  D
# 2           1    G  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...  D
# 3           1    G                                                NaN  D
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
# 7           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   16012.00      53    6072
# 1    4075.24      69    3987
# 2     395.81      69    3987
# 3  123583.48      69    4088
# 4     191.40      69    1510
# 5      43.50      69    1514
# 6     109.45      69    1563
# 7    1834.18      69    6890
#
#                                               nomMov         mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  125824.54
# 1  CUENTA UNICA DEL TESORO                       ...    4075.24
# 2  CUENTA UNICA DEL TESORO                       ...     395.81
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  123583.48
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 5  UTILES DE ESCRITORIO                          ...      43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     109.45
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    1834.18
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    412
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    498
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    600
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    650
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778876        H     10    6072
# 1    G      1778876        D    412    3987
# 2    G      1778876        D    412    3987
# 3    G      1778876        D    498    4088
# 4    G      1778876        H    600    1510
# 5    G      1778876        H    600    1514
# 6    G      1778876        H    650    1563
# 7    G      1778876        H    680    6890
#
#                                           Movimiento         MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  125824.54
# 1  CUENTA UNICA DEL TESORO                       ...    4075.24
# 2  CUENTA UNICA DEL TESORO                       ...     395.81
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  123583.48
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 5  UTILES DE ESCRITORIO                          ...      43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     109.45
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    1834.18
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 1  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...
# 2  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  8
# Comprobante  22
# 1778877
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...  H
# 1           1    G                                                NaN  D
# 2           1    G                                                NaN  H
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
#
#         mo  moneda  codMov                                             nomMov  \
# 0  4780.16      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1  4824.30      34    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 2   191.40      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 3    43.50      69    1514  UTILES DE ESCRITORIO                          ...
# 4    28.53      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
#
#          mn                                              glosa  comprobante  \
# 0  32791.90  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 1  33094.70  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 2    191.40  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 3     43.50  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 4     28.53  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
#
#    mayor
# 0     10
# 1    498
# 2    600
# 3    600
# 4    650
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778877        H     10    5896
# 1    G      1778877        D    498    4088
# 2    G      1778877        H    600    1510
# 3    G      1778877        H    600    1514
# 4    G      1778877        H    650    1563
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  32791.90
# 1  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  33094.70
# 2  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 3  UTILES DE ESCRITORIO                          ...     43.50
# 4  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     28.53
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 2  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 3  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 4  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  23
# 1778878
# Hay duplicado:  True
# aux4
# [0, 4]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778878        D    498    4088
# 1    G      1778878        H     10    5896
#
#                                           Movimiento       MN  \
# 0  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  49901.7
# 1  NEW YORK - CTA. 3544020682001                 ...  49901.7
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  EMBAJADA DE BOLIVIA EN HOLANDA, CTA. NL31ABNA0...
# mas de 2
# largo cuando dentra al debehaber:  6
# Comprobante  24
# 1778879
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...  H
# 1           1    G  LIB. 00598012001 EEPB - RECURSOS ESPECÍFICOS P...  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0   1476.09      34    5896
# 1    280.15      69    3987
# 2  10273.59      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5      8.83      69    1563
# 6    147.61      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10125.98
# 1  CUENTA UNICA DEL TESORO                       ...    280.15
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  10273.59
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      8.83
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    147.61
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778879        H     10    5896
# 1    G      1778879        D    412    3987
# 2    G      1778879        D    498    4088
# 3    G      1778879        H    600    1510
# 4    G      1778879        H    600    1514
# 5    G      1778879        H    650    1563
# 6    G      1778879        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10125.98
# 1  CUENTA UNICA DEL TESORO                       ...    280.15
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  10273.59
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      8.83
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    147.61
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 1  LIB. 00598012001 EEPB - RECURSOS ESPECÍFICOS P...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  25
# 1778880
# Hay duplicado:  True
# aux4
# [0, 4]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778880        D    498    4088
# 1    G      1778880        H     10    5896
#
#                                           Movimiento        MN  \
# 0  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  685416.9
# 1  NEW YORK - CTA. 3544020682001                 ...  685416.9
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  AIR MAURIN INC., CTA. 3892471207 JPMORGAN CHAS...
# mas de 2
# largo cuando dentra al debehaber:  6
# Comprobante  26
# 1778881
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...  H
# 1           1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   75828.70      34    5896
# 1     790.19      69    3987
# 2  527767.75      69    4088
# 3     191.40      69    1510
# 4      43.50      69    1514
# 5     452.57      69    1563
# 6    7582.87      69    6890
#
#                                               nomMov         mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  520184.88
# 1  CUENTA UNICA DEL TESORO                       ...     790.19
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  527767.75
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     452.57
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    7582.87
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778881        H     10    5896
# 1    G      1778881        D    412    3987
# 2    G      1778881        D    498    4088
# 3    G      1778881        H    600    1510
# 4    G      1778881        H    600    1514
# 5    G      1778881        H    650    1563
# 6    G      1778881        H    680    6890
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  520184.88
# 1  CUENTA UNICA DEL TESORO                       ...     790.19
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  527767.75
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     452.57
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    7582.87
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  27
# 1778882
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0  10000.00      34    5896
# 1    338.60      69    3987
# 2  69600.00      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5     59.68      69    1563
# 6   1000.00      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68600.00
# 1  CUENTA UNICA DEL TESORO                       ...    338.60
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  69600.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     59.68
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...   1000.00
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778882        H     10    5896
# 1    G      1778882        D    412    3987
# 2    G      1778882        D    498    4088
# 3    G      1778882        H    600    1510
# 4    G      1778882        H    600    1514
# 5    G      1778882        H    650    1563
# 6    G      1778882        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68600.00
# 1  CUENTA UNICA DEL TESORO                       ...    338.60
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  69600.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     59.68
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...   1000.00
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  28
# 1778883
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#            mo  moneda  codMov  \
# 0   147581.48      34    5896
# 1     1282.40      69    3987
# 2  1027167.10      69    4088
# 3      191.40      69    1510
# 4       43.50      69    1514
# 5      880.79      69    1563
# 6    14758.15      69    6890
#
#                                               nomMov          mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1012408.95
# 1  CUENTA UNICA DEL TESORO                       ...     1282.40
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1027167.10
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      880.79
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    14758.15
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778883        H     10    5896
# 1    G      1778883        D    412    3987
# 2    G      1778883        D    498    4088
# 3    G      1778883        H    600    1510
# 4    G      1778883        H    600    1514
# 5    G      1778883        H    650    1563
# 6    G      1778883        H    680    6890
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1012408.95
# 1  CUENTA UNICA DEL TESORO                       ...     1282.40
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1027167.10
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      880.79
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    14758.15
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  29
# 1778884
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...  H
# 1           1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   21065.00      34    5896
# 1     414.54      69    3987
# 2  146612.40      69    4088
# 3     191.40      69    1510
# 4      43.50      69    1514
# 5     125.75      69    1563
# 6    2106.50      69    6890
#
#                                               nomMov         mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  144505.90
# 1  CUENTA UNICA DEL TESORO                       ...     414.54
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  146612.40
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     125.75
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2106.50
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778884        H     10    5896
# 1    G      1778884        D    412    3987
# 2    G      1778884        D    498    4088
# 3    G      1778884        H    600    1510
# 4    G      1778884        H    600    1514
# 5    G      1778884        H    650    1563
# 6    G      1778884        H    680    6890
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  144505.90
# 1  CUENTA UNICA DEL TESORO                       ...     414.54
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  146612.40
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     125.75
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2106.50
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  30
# 1778885
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0   5178.00      34    5896
# 1    305.53      69    3987
# 2  36038.88      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5     30.91      69    1563
# 6    517.80      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  35521.08
# 1  CUENTA UNICA DEL TESORO                       ...    305.53
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  36038.88
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     30.91
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    517.80
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778885        H     10    5896
# 1    G      1778885        D    412    3987
# 2    G      1778885        D    498    4088
# 3    G      1778885        H    600    1510
# 4    G      1778885        H    600    1514
# 5    G      1778885        H    650    1563
# 6    G      1778885        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  35521.08
# 1  CUENTA UNICA DEL TESORO                       ...    305.53
# ...
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...           NaN
# largo de aux2:  2
# caso 4
# dentro  1997267
# Comprobante  57
# 1997277
# Hay duplicado:  True
# aux4
# [1, 3]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    H      1997277        H    828    3559
# 1    H      1997277        H      7    8085
#
#                                           Movimiento        MN  \
# 0  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...  137200.0
# 1  DOLARES ESTADOUNIDENSES - MANDATO BUSA        ...  137200.0
#
#                                                Glosa  GlosaDetalle
# 0  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# 1  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# mas de 2
# largo cuando dentra al debehaber:  4
# Comprobante  58
# 1997352
# Hay duplicado:  True
# aux4
# [0, 1]
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1997352        D      7    3491
# 1    O      1997352        H    406     861
#
#                                           Movimiento     MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  343.0
# 1  RECAUDACIONES CONSULARES                      ...  343.0
#
#                                                Glosa  GlosaDetalle
# 0  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...           NaN
# 1  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...           NaN
# largo de aux2:  2
# caso 1
# dentro  1997352
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21863  Ingreso     410      10    6072
# 1     V        28487  Ingreso      22      17    6296
# 2     S      1025337  Ingreso      10      10    5896
# 3     S      1025347  Ingreso      11     606    1535
# 4     S      1025355   Egreso      10     412    3987
# 5     S      1025365  Ingreso      10     412    3987
# 6     S      1025366  Ingreso      10     412    3987
# 7     S      1025368  Ingreso      10     404    7954
# 8     S      1025371  Ingreso      10     404    7954
# 9     S      1025374  Ingreso      10     404    7954
# 10    S      1025377  Ingreso      16     499    7355
# 11    S      1025378  Ingreso      10     403    3910
# 12    S      1025383  Ingreso      10     412     818
# 13    S      1025388   Egreso      10     198    3641
# 14    S      1025390  Ingreso      10     498    8304
# 15    S      1025391  Ingreso      10     498    8304
# 16    S      1025393  Ingreso      10     414    7866
# 17    S      1025404  Ingreso      10     498    8304
# 18    S      1025405  Ingreso      10     498    8304
# 19    S      1025406  Ingreso      10     498    8304
# 20    G      1778875   Egreso      10     498    6817
# 21    G      1778876   Egreso      10     412    3987
# 22    G      1778877   Egreso      10     498    4088
# 23    G      1778878   Egreso     498     412    3987
# 24    G      1778879   Egreso      10     412    3987
# 25    G      1778880   Egreso     498     412    3987
# 26    G      1778881   Egreso      10     412    3987
# 27    G      1778882   Egreso      10     412    3987
# 28    G      1778883   Egreso      10     412    3987
# 29    G      1778884   Egreso      10     412    3987
# 30    G      1778885   Egreso      10     412    3987
# 31    G      1778886   Egreso      10     412    3987
# 32    G      1778887   Egreso     498     412    3987
# 33    G      1778888   Egreso     498     412    3987
# 34    G      1778889  Ingreso      10     404    5968
# 35    G      1778891  Ingreso      10     404    5968
# 36    G      1778893  Ingreso      10     404    5968
# 37    G      1779021    Neteo      10      10    5896
# 38    G      1779022   Egreso     412     412    5970
# 39    G      1779023   Egreso     412     412    5970
# 40    G      1779024   Egreso     412     412    5970
# 41    G      1779146   Egreso      16     499    7355
# 42    G      1779147   Egreso     412     412    5970
# 43    G      1779148  Ingreso      17     606    6538
# 44    G      1779150  Ingreso      10     412    5970
# 45    G      1779152   Egreso      10     498    6817
# 46    G      1779153  Ingreso      10     404    6705
# 47    G      1779295  Ingreso      10     498    1470
# 48    G      1779296  Ingreso      10     498    1470
# 49    G      1779298  Ingreso      10     412    4249
# 50    O      1997192  Ingreso       7     406     898
# 51    O      1997212   Egreso       7     403    3917
# 52    O      1997224  Ingreso       7     406     898
# 53    O      1997225  Ingreso       7     406     861
# 54    O      1997255  Ingreso       7     406     861
# 55    O      1997265   Egreso       7     403    3910
# 56    O      1997267   Egreso       7     403    6893
# 57    H      1997277   Egreso     198     828    3559
# 58    O      1997352  Ingreso       7     406     861
#
#                                            Movimiento    MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...        0.01
# 1   INTERESES DEVENGADOS                          ...  1022077.47
# 2   NEW YORK - CTA. 3544020682001                 ...      142.15
# 3   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     7146.29
# 4   CUENTA UNICA DEL TESORO                       ...       20.05
# 5   CUENTA UNICA DEL TESORO                       ...     1727.37
# 6   CUENTA UNICA DEL TESORO                       ...     1935.35
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...   252250.00
# 8   YPFB - EXPORTACION DE UREA Y OTROS            ...   302700.00
# 9   YPFB - EXPORTACION DE UREA Y OTROS            ...    78165.00
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3600000.00
# 12  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      690.00
# 13  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...       11.45
# 14  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      220.00
# 15  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...     1540.00
# 16  EFECTIVO GARANTIA FONDO CPVIS                 ...  7000000.00
# 17  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 18  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      203.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      665.00
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 21  CUENTA UNICA DEL TESORO                       ...    18341.77
# 22  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     4780.16
# 23  CUENTA UNICA DEL TESORO                       ...     7274.30
# 24  CUENTA UNICA DEL TESORO                       ...     1476.09
# 25  CUENTA UNICA DEL TESORO                       ...    99915.00
# 26  CUENTA UNICA DEL TESORO                       ...    75828.70
# 27  CUENTA UNICA DEL TESORO                       ...    10000.00
# 28  CUENTA UNICA DEL TESORO                       ...   147581.48
# 29  CUENTA UNICA DEL TESORO                       ...    21065.00
# 30  CUENTA UNICA DEL TESORO                       ...     5178.00
# 31  CUENTA UNICA DEL TESORO                       ...   129282.67
# 32  CUENTA UNICA DEL TESORO                       ...   122400.00
# 33  CUENTA UNICA DEL TESORO                       ...    37240.00
# 34  YPFB - HEROES DEL CHACO                       ...    81155.99
# 35  YPFB - HEROES DEL CHACO                       ...  1312465.83
# 36  YPFB - HEROES DEL CHACO                       ...   244090.06
# 37  NEW YORK - CTA. 3544020682001                 ...        0.00
# 38  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   629729.23
# 39  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    70973.82
# 40  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    22355.88
# 41  VALORACION TITULOS DE LAS RESERVAS INTERNACION...    80284.19
# 42  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   153911.47
# 43  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...    18198.73
# 44  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...     2074.52
# 45  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 46  YPFB OPERACIONES FINANCIERAS EXTRAORDINARIAS  ...    53876.80
# 47  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...    13992.00
# 48  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  5380396.94
# 49  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     4515.81
# 50  TGN CUENTA TRANSITORIA- M/E                   ...       20.00
# 51  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  2000000.00
# 52  TGN CUENTA TRANSITORIA- M/E                   ...       30.00
# 53  RECAUDACIONES CONSULARES                      ...       40.00
# 54  RECAUDACIONES CONSULARES                      ...       50.00
# 55  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  7500000.00
# 56  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 57  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
# 58  RECAUDACIONES CONSULARES                      ...       50.00
#
#                                               Detalle  \
# 0   Saldo ME = -687701.69 ;Bs/Mo: 6.86000000000 ;S...
# 1   Saldo Ant.= 66873.00 ;Bs: 9.64941320000 = $us ...
# 2                                                 NaN
# 3                                                 NaN
# 4                          SWIFT N° 1805 DE LA FECHA.
# 5                               A LA CUENTA 03-W-302.
# 6                               A LA CUENTA 03-H-307.
# 7          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 8          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 9   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# 10                                                NaN
# 11                                                NaN
# 12  A LA CUENTA 1-2232746 UAGRM FAC.DE CIENCIAS EX...
# 13   (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 14                               (CC:H-0046564-2022)
# 15                               (CC:H-0046565-2022)
# 16  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# 17                               (CC:H-0046569-2022)
# 18                               (CC:H-0046570-2022)
# 19                               (CC:H-0046571-2022)
# 20                                                NaN
# 21  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 22  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 23                                                NaN
# 24  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 25                                                NaN
# 26  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 27  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 28  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 29  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 30  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 31  TERMINAL INTERNACIONAL DEL SUR SA, CTA. 425105...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                      (±, 876970.4)
# 38  CTA. 3987 CUENTA UNICA DEL TESORO  LIB. 000990...
# 39  CTA. 3987 CUENTA UNICA DEL TESORO  LIB. 000990...
# 40  CTA. 3987 CUENTA UNICA DEL TESORO  LIB. 000990...
# 41                                                NaN
# 42  CTA. 3987 CUENTA UNICA DEL TESORO  LIB. 000990...
# 43                                                NaN
# 44  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 45                                                NaN
# 46                                                NaN
# 47                                (CC:H-0046566-2022)
# 48                                (CC:H-0046567-2022)
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                                 Glosa
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...
# 3   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 4   ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 12  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 13  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 14  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 15  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 16  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 17  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 18  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 19  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 22  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 23  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 24  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 25  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 26  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 27  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 28  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 29  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 30  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 31  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 32  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 33  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 34  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1770...
# 35  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1767...
# 36  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1765...
# 37  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 38  PAGO A BANCO EUROPEO DE INV PRÉSTAMO FIN 82800...
# 39  PAGO A BID PRÉSTAMO 1075-SF-BO-8 VCTO. 06-02-2...
# 40  PAGO A BID PRÉSTAMO 1118-SF-BO VCTO. 06-02-202...
# 41  REVALORACIÓN DE TÍTULOS AL 07-02-2022, PORTAFO...
# 42  PAGO A CAF PRÉSTAMO CFA010869 VCTO. 07-02-2022...
# 43  INTERÉS DEVENGADO DE TÍTULOS AL 07-02-2022, PO...
# 44  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1755...
# 45  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 46  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1754...
# 47  REGISTRO TRANSITORIO SEGUN SWIFT NO.1785 HASTA...
# 48  REGISTRO TRANSITORIO SEGUN SWIFT NO.1803 HASTA...
# 49  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1786...
# 50  DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMA...
# 51  PAGO CHEQUE: D-22-99977     , BENEFICIARIO: EM...
# 52  DEPOSITO DE EFECTIVO, DEPOSITANTE: VICTOR SAMU...
# 53  DEPOSITO DE EFECTIVO, DEPOSITANTE: BERTHA MAMA...
# 54  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA GU...
# 55  PAGO CHEQUE: D-21-99306     , BENEFICIARIO: MA...
# 56  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...
# 57  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 58  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas1=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    data2=[]
    columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        #data2=[]
        #columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
        ########## RRRRRRRRRRRR
        debemenoshaber(aux2.index)
        ########## RRRRRRRRRRRR   
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            if len(aux4)==2:
                for x in range(len(aux4)):

                    data1.append({
                        "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                        "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                        "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                                })
                    pares=pd.DataFrame(data1,columns=columnas1)
                #################### 1
                print("largo de aux2: ",len(aux2))
                print(pares)
                ###########
                #data2=[]
                #columnas=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                ##########
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                    #print("Posible Neteo")
                    llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                    unRegistro=pd.DataFrame(data2,columns=columnas2)
                else:     
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                        print('caso 1')
                        llenarData("Ingreso",0,1)        
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                        print('caso 2')
                        llenarData("Egreso",0,1)                   
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                        print('caso 3')
                        llenarData("Ingreso",1,0)                    
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                        print('caso 4')
                        llenarData("Egreso",1,0)
            else:
                
                #@#@#@#@#@#@#
                #data2=[]
                #columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
               
                ####BBBBBBBBBBBBBBBBBBB
                debemenoshaber(range(len(aux2)))
                ####BBBBBBBBBBBBBBBBBBB
                #@#@#@#@#@#@#
            #################### 1

        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            
            for x in range(len(aux2)):
                #print(aux[x],"=== ",aux2["mn"][aux4[x]])
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)
            ################### 2
            print(pares)
            #data2=[]
            #columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
            
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                
                
                #data2=[]
                #columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
                ######### HHHHHHH
               # if len(aux2)==3 and aux2["mayor"][0] in cuentas and aux2["mayor"][1] in cuentas and aux2["mayor"][2]==680:
               #     llenarData("Neteo",0,1)
               # else:
                debemenoshaber(range(len(aux2)))
               
                ######### HHHHHHH 
            ################### 2
            #print(aux2['mayor'][i],' ... ',aux2["comprobante"][i])
            #print('pares ',pares["Comprobante"][0])
            
        ###$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
        ##### $$$$$$$$$$$$$$$
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado

#consolidado.to_excel("borrar10ene.xlsx")
# Out:
# Comprobante  0
# 21863
# largo cuando dentra al debehaber:  20
# Comprobante  1
# 28487
# largo cuando dentra al debehaber:  18
# Comprobante  2
# 1025337
# Hay duplicado:  False
# aux2
#    nro_centro tipo glosaRenglon dh         mo  moneda  codMov  \
# 0           1    S          NaN  D  100000.00      53    6072
# 1           1    S          NaN  H  114408.00      34    5896
# 2           1    S          NaN  H     975.12      69    1585
#
#                                               nomMov         mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  785814.00
# 1  NEW YORK - CTA. 3544020682001                 ...  784838.88
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     975.12
#
#                                                glosa  comprobante  mayor
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337     10
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337     10
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025337        D     10    6072
# 1    S      1025337        H     10    5896
# 2    S      1025337        H    680    1585
#
#                                           Movimiento         MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  785814.00
# 1  NEW YORK - CTA. 3544020682001                 ...  784838.88
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     975.12
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  3
# 1025347
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025347        D     11    2902
# 1    S      1025347        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  49023.55
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  49023.55
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# caso 1
# dentro  1025347
# Comprobante  4
# 1025355
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    S                         SWIFT N° 1805 DE LA FECHA.  H
# 1           1    S  CTA. 00132032001 ECEBOL - GESTION OPERATIVA CO...  D
# 2           1    S  CTA. 00132032001 ECEBOL - GESTION OPERATIVA, C...  D
# 3           1    S                                                NaN  H
# 4           1    S                                                NaN  H
#
#        mo  moneda  codMov                                             nomMov  \
# 0   17.50      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 1  139.52      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2   50.00      69    3987  CUENTA UNICA DEL TESORO                       ...
# 3   43.50      69    1514  UTILES DE ESCRITORIO                          ...
# 4    2.00      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#        mn                                              glosa  comprobante  \
# 0  137.52  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 1  139.52  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 2   50.00  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 3   43.50  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 4    2.00  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
#
#    mayor
# 0     10
# 1    412
# 2    412
# 3    600
# 4    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025355        H     10    6072
# 1    S      1025355        D    412    3987
# 2    S      1025355        D    412    3987
# 3    S      1025355        H    600    1514
# 4    S      1025355        H    680    6890
#
#                                           Movimiento      MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  137.52
# 1  CUENTA UNICA DEL TESORO                       ...  139.52
# 2  CUENTA UNICA DEL TESORO                       ...   50.00
# 3  UTILES DE ESCRITORIO                          ...   43.50
# 4  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.00
#
#                                                Glosa  \
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
#
#                                         GlosaDetalle
# 0                         SWIFT N° 1805 DE LA FECHA.
# 1  CTA. 00132032001 ECEBOL - GESTION OPERATIVA CO...
# 2  CTA. 00132032001 ECEBOL - GESTION OPERATIVA, C...
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  5
# 1025365
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025365        D     10    5896
# 1    S      1025365        H    412    4710
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  11849.76
# 1  03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...  11849.76
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                            GlosaDetalle
# 0                 A LA CUENTA 03-W-302.
# 1  POR CUENTA DE 101DOMAIN GRS LIMITED.
# caso 1
# dentro  1025365
# Comprobante  6
# 1025366
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025366        D     10    5896
# 1    S      1025366        H    412    5832
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  13276.5
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  13276.5
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0                              A LA CUENTA 03-H-307.
# 1  POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# caso 1
# dentro  1025366
# Comprobante  7
# 1025368
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025368        D     10    5896
# 1    S      1025368        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1730435.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  1730435.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1       POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# caso 1
# dentro  1025368
# Comprobante  8
# 1025371
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025371        D     10    5896
# 1    S      1025371        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  2076522.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  2076522.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1       POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# caso 1
# dentro  1025371
# Comprobante  9
# 1025374
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025374        D     10    5896
# 1    S      1025374        H    404    7954
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  536211.9
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  536211.9
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# caso 1
# dentro  1025374
# Comprobante  10
# 1025377
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025377        D     16    6286
# 1    S      1025377        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# caso 1
# dentro  1025377
# Comprobante  11
# 1025378
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025378        D     10    5896
# 1    S      1025378        H    403    3910
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  24696000.0
# 1  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  24696000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# caso 1
# dentro  1025378
# Comprobante  12
# 1025383
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025383        D     10    5896
# 1    S      1025383        H    412     818
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  4733.4
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  4733.4
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
#
#                                         GlosaDetalle
# 0  A LA CUENTA 1-2232746 UAGRM FAC.DE CIENCIAS EX...
# 1  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# caso 1
# dentro  1025383
# Comprobante  13
# 1025388
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025388        D    198    3641
# 1    S      1025388        H     10    6072
#
#                                           Movimiento     MN  \
# 0  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...  78.58
# 1  MADRID EUROS CUENTA ES2990299029960000000107  ...  78.58
#
#                                                Glosa  \
# 0  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 1  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
#
#                                        GlosaDetalle
# 0  (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 1                          COMISIONES DEL BANQUERO.
# caso 4
# dentro  1025388
# Comprobante  14
# 1025390
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025390        D     10    5896
# 1    S      1025390        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1509.2
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1509.2
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046564-2022)
# caso 1
# dentro  1025390
# Comprobante  15
# 1025391
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025391        D     10    5896
# 1    S      1025391        H    498    8304
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10564.4
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  10564.4
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046565-2022)
# caso 1
# dentro  1025391
# Comprobante  16
# 1025393
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025393        D     10    5896
# 1    S      1025393        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  48020000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  48020000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# caso 1
# dentro  1025393
# Comprobante  17
# 1025404
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025404        D     10    5896
# 1    S      1025404        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1543.5
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1543.5
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046569-2022)
# caso 1
# dentro  1025404
# Comprobante  18
# 1025405
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025405        D     10    5896
# 1    S      1025405        H    498    8304
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1392.58
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1392.58
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046570-2022)
# caso 1
# dentro  1025405
# Comprobante  19
# 1025406
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025406        D     10    5896
# 1    S      1025406        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  4561.9
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  4561.9
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046571-2022)
# caso 1
# dentro  1025406
# Comprobante  20
# 1778875
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778875        D    498    6817
# 1    G      1778875        H     10    5896
#
#                                           Movimiento          MN  \
# 0  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  34300000.0
# 1  NEW YORK - CTA. 3544020682001                 ...  34300000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  BANCO GANADERO S.A., CTA. 496553483 JPMORGAN C...
# caso 4
# dentro  1778875
# Comprobante  21
# 1778876
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...  H
# 1           1    G  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...  D
# 2           1    G  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...  D
# 3           1    G                                                NaN  D
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
# 7           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   16012.00      53    6072
# 1    4075.24      69    3987
# 2     395.81      69    3987
# 3  123583.48      69    4088
# 4     191.40      69    1510
# 5      43.50      69    1514
# 6     109.45      69    1563
# 7    1834.18      69    6890
#
#                                               nomMov         mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  125824.54
# 1  CUENTA UNICA DEL TESORO                       ...    4075.24
# 2  CUENTA UNICA DEL TESORO                       ...     395.81
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  123583.48
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 5  UTILES DE ESCRITORIO                          ...      43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     109.45
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    1834.18
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    412
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    498
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    600
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    650
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778876        H     10    6072
# 1    G      1778876        D    412    3987
# 2    G      1778876        D    412    3987
# 3    G      1778876        D    498    4088
# 4    G      1778876        H    600    1510
# 5    G      1778876        H    600    1514
# 6    G      1778876        H    650    1563
# 7    G      1778876        H    680    6890
#
#                                           Movimiento         MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  125824.54
# 1  CUENTA UNICA DEL TESORO                       ...    4075.24
# 2  CUENTA UNICA DEL TESORO                       ...     395.81
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  123583.48
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 5  UTILES DE ESCRITORIO                          ...      43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     109.45
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    1834.18
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 1  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...
# 2  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  8
# Comprobante  22
# 1778877
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...  H
# 1           1    G                                                NaN  D
# 2           1    G                                                NaN  H
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
#
#         mo  moneda  codMov                                             nomMov  \
# 0  4780.16      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1  4824.30      34    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 2   191.40      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 3    43.50      69    1514  UTILES DE ESCRITORIO                          ...
# 4    28.53      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
#
#          mn                                              glosa  comprobante  \
# 0  32791.90  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 1  33094.70  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 2    191.40  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 3     43.50  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 4     28.53  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
#
#    mayor
# 0     10
# 1    498
# 2    600
# 3    600
# 4    650
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778877        H     10    5896
# 1    G      1778877        D    498    4088
# 2    G      1778877        H    600    1510
# 3    G      1778877        H    600    1514
# 4    G      1778877        H    650    1563
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  32791.90
# 1  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  33094.70
# 2  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 3  UTILES DE ESCRITORIO                          ...     43.50
# 4  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     28.53
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 2  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 3  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 4  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  23
# 1778878
# Hay duplicado:  True
# aux4
# [0, 4]
# largo de aux2:  6
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778878        D    498    4088
# 1    G      1778878        H     10    5896
#
#                                           Movimiento       MN  \
# 0  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  49901.7
# 1  NEW YORK - CTA. 3544020682001                 ...  49901.7
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  EMBAJADA DE BOLIVIA EN HOLANDA, CTA. NL31ABNA0...
# caso 4
# dentro  1778878
# Comprobante  24
# 1778879
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...  H
# 1           1    G  LIB. 00598012001 EEPB - RECURSOS ESPECÍFICOS P...  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0   1476.09      34    5896
# 1    280.15      69    3987
# 2  10273.59      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5      8.83      69    1563
# 6    147.61      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10125.98
# 1  CUENTA UNICA DEL TESORO                       ...    280.15
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  10273.59
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      8.83
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    147.61
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778879        H     10    5896
# 1    G      1778879        D    412    3987
# 2    G      1778879        D    498    4088
# 3    G      1778879        H    600    1510
# 4    G      1778879        H    600    1514
# 5    G      1778879        H    650    1563
# 6    G      1778879        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10125.98
# 1  CUENTA UNICA DEL TESORO                       ...    280.15
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  10273.59
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      8.83
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    147.61
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 1  LIB. 00598012001 EEPB - RECURSOS ESPECÍFICOS P...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  25
# 1778880
# Hay duplicado:  True
# aux4
# [0, 4]
# largo de aux2:  6
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778880        D    498    4088
# 1    G      1778880        H     10    5896
#
#                                           Movimiento        MN  \
# 0  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  685416.9
# 1  NEW YORK - CTA. 3544020682001                 ...  685416.9
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  AIR MAURIN INC., CTA. 3892471207 JPMORGAN CHAS...
# caso 4
# dentro  1778880
# Comprobante  26
# 1778881
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...  H
# 1           1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   75828.70      34    5896
# 1     790.19      69    3987
# 2  527767.75      69    4088
# 3     191.40      69    1510
# 4      43.50      69    1514
# 5     452.57      69    1563
# 6    7582.87      69    6890
#
#                                               nomMov         mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  520184.88
# 1  CUENTA UNICA DEL TESORO                       ...     790.19
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  527767.75
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     452.57
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    7582.87
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778881        H     10    5896
# 1    G      1778881        D    412    3987
# 2    G      1778881        D    498    4088
# 3    G      1778881        H    600    1510
# 4    G      1778881        H    600    1514
# 5    G      1778881        H    650    1563
# 6    G      1778881        H    680    6890
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  520184.88
# 1  CUENTA UNICA DEL TESORO                       ...     790.19
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  527767.75
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     452.57
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    7582.87
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  27
# 1778882
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0  10000.00      34    5896
# 1    338.60      69    3987
# 2  69600.00      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5     59.68      69    1563
# 6   1000.00      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68600.00
# 1  CUENTA UNICA DEL TESORO                       ...    338.60
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  69600.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     59.68
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...   1000.00
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778882        H     10    5896
# 1    G      1778882        D    412    3987
# 2    G      1778882        D    498    4088
# 3    G      1778882        H    600    1510
# 4    G      1778882        H    600    1514
# 5    G      1778882        H    650    1563
# 6    G      1778882        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68600.00
# 1  CUENTA UNICA DEL TESORO                       ...    338.60
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  69600.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     59.68
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...   1000.00
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  28
# 1778883
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#            mo  moneda  codMov  \
# 0   147581.48      34    5896
# 1     1282.40      69    3987
# 2  1027167.10      69    4088
# 3      191.40      69    1510
# 4       43.50      69    1514
# 5      880.79      69    1563
# 6    14758.15      69    6890
#
#                                               nomMov          mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1012408.95
# 1  CUENTA UNICA DEL TESORO                       ...     1282.40
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1027167.10
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      880.79
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    14758.15
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778883        H     10    5896
# 1    G      1778883        D    412    3987
# 2    G      1778883        D    498    4088
# 3    G      1778883        H    600    1510
# 4    G      1778883        H    600    1514
# 5    G      1778883        H    650    1563
# 6    G      1778883        H    680    6890
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1012408.95
# 1  CUENTA UNICA DEL TESORO                       ...     1282.40
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1027167.10
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      880.79
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    14758.15
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  29
# 1778884
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...  H
# 1           1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   21065.00      34    5896
# 1     414.54      69    3987
# 2  146612.40      69    4088
# 3     191.40      69    1510
# 4      43.50      69    1514
# 5     125.75      69    1563
# 6    2106.50      69    6890
#
#                                               nomMov         mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  144505.90
# 1  CUENTA UNICA DEL TESORO                       ...     414.54
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  146612.40
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     125.75
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2106.50
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778884        H     10    5896
# 1    G      1778884        D    412    3987
# 2    G      1778884        D    498    4088
# 3    G      1778884        H    600    1510
# 4    G      1778884        H    600    1514
# 5    G      1778884        H    650    1563
# 6    G      1778884        H    680    6890
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  144505.90
# 1  CUENTA UNICA DEL TESORO                       ...     414.54
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  146612.40
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     125.75
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2106.50
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  30
# 1778885
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0   5178.00      34    5896
# 1    305.53      69    3987
# 2  36038.88      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5     30.91      69    1563
# 6    517.80      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  35521.08
# 1  CUENTA UNICA DEL TESORO                       ...    305.53
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  36038.88
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     30.91
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    517.80
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778885        H     10    5896
# 1    G      1778885        D    412    3987
# 2    G      1778885        D    498    4088
# 3    G      1778885        H    600    1510
# 4    G      1778885        H    600    1514
# 5    G      1778885        H    650    1563
# 6    G      1778885        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  35521.08
# 1  CUENTA UNICA DEL TESORO                       ...    305.53
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  36038.88
# ...
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...           NaN
# caso 4
# dentro  1997267
# Comprobante  57
# 1997277
# Hay duplicado:  True
# aux4
# [1, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    H      1997277        H    828    3559
# 1    H      1997277        H      7    8085
#
#                                           Movimiento        MN  \
# 0  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...  137200.0
# 1  DOLARES ESTADOUNIDENSES - MANDATO BUSA        ...  137200.0
#
#                                                Glosa  GlosaDetalle
# 0  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# 1  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# caso 4
# dentro  1997277
# Comprobante  58
# 1997352
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1997352        D      7    3491
# 1    O      1997352        H    406     861
#
#                                           Movimiento     MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  343.0
# 1  RECAUDACIONES CONSULARES                      ...  343.0
#
#                                                Glosa  GlosaDetalle
# 0  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...           NaN
# 1  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...           NaN
# caso 1
# dentro  1997352
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21863  Ingreso     410      10    6072
# 1     V        28487  Ingreso      22      17    6296
# 2     S      1025337  Ingreso      10      10    5896
# 3     S      1025347  Ingreso      11     606    1535
# 4     S      1025355   Egreso      10     412    3987
# 5     S      1025365  Ingreso      10     412    4710
# 6     S      1025366  Ingreso      10     412    5832
# 7     S      1025368  Ingreso      10     404    7954
# 8     S      1025371  Ingreso      10     404    7954
# 9     S      1025374  Ingreso      10     404    7954
# 10    S      1025377  Ingreso      16     499    7355
# 11    S      1025378  Ingreso      10     403    3910
# 12    S      1025383  Ingreso      10     412     818
# 13    S      1025388   Egreso      10     198    3641
# 14    S      1025390  Ingreso      10     498    8304
# 15    S      1025391  Ingreso      10     498    8304
# 16    S      1025393  Ingreso      10     414    7866
# 17    S      1025404  Ingreso      10     498    8304
# 18    S      1025405  Ingreso      10     498    8304
# 19    S      1025406  Ingreso      10     498    8304
# 20    G      1778875   Egreso      10     498    6817
# 21    G      1778876   Egreso      10     412    3987
# 22    G      1778877   Egreso      10     498    4088
# 23    G      1778878   Egreso      10     498    4088
# 24    G      1778879   Egreso      10     412    3987
# 25    G      1778880   Egreso      10     498    4088
# 26    G      1778881   Egreso      10     412    3987
# 27    G      1778882   Egreso      10     412    3987
# 28    G      1778883   Egreso      10     412    3987
# 29    G      1778884   Egreso      10     412    3987
# 30    G      1778885   Egreso      10     412    3987
# 31    G      1778886   Egreso      10     412    3987
# 32    G      1778887   Egreso      10     498    4088
# 33    G      1778888   Egreso      10     498    4088
# 34    G      1778889  Ingreso      10     404    5968
# 35    G      1778891  Ingreso      10     404    5968
# 36    G      1778893  Ingreso      10     404    5968
# 37    G      1779021    Neteo      10      10    5896
# 38    G      1779022   Egreso      10     412    5970
# 39    G      1779023   Egreso      10     412    5970
# 40    G      1779024   Egreso      10     412    5970
# 41    G      1779146   Egreso      16     499    7355
# 42    G      1779147   Egreso      10     412    5970
# 43    G      1779148  Ingreso      17     606    6538
# 44    G      1779150  Ingreso      10     412    5970
# 45    G      1779152   Egreso      10     498    6817
# 46    G      1779153  Ingreso      10     404    6705
# 47    G      1779295  Ingreso      10     498    1470
# 48    G      1779296  Ingreso      10     498    1470
# 49    G      1779298  Ingreso      10     412    4249
# 50    O      1997192  Ingreso       7     406     898
# 51    O      1997212   Egreso       7     403    3917
# 52    O      1997224  Ingreso       7     406     898
# 53    O      1997225  Ingreso       7     406     861
# 54    O      1997255  Ingreso       7     406     861
# 55    O      1997265   Egreso       7     403    3910
# 56    O      1997267   Egreso       7     403    6893
# 57    H      1997277   Egreso       7     828    3559
# 58    O      1997352  Ingreso       7     406     861
#
#                                            Movimiento    MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...        0.01
# 1   INTERESES DEVENGADOS                          ...  1022077.47
# 2   NEW YORK - CTA. 3544020682001                 ...      142.15
# 3   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     7146.29
# 4   CUENTA UNICA DEL TESORO                       ...       20.05
# 5   03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...     1727.37
# 6   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     1935.35
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...   252250.00
# 8   YPFB - EXPORTACION DE UREA Y OTROS            ...   302700.00
# 9   YPFB - EXPORTACION DE UREA Y OTROS            ...    78165.00
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3600000.00
# 12  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      690.00
# 13  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...       11.45
# 14  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      220.00
# 15  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...     1540.00
# 16  EFECTIVO GARANTIA FONDO CPVIS                 ...  7000000.00
# 17  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 18  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      203.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      665.00
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 21  CUENTA UNICA DEL TESORO                       ...    18341.77
# 22  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     4780.16
# 23  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     7274.30
# 24  CUENTA UNICA DEL TESORO                       ...     1476.09
# 25  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    99915.00
# 26  CUENTA UNICA DEL TESORO                       ...    75828.70
# 27  CUENTA UNICA DEL TESORO                       ...    10000.00
# 28  CUENTA UNICA DEL TESORO                       ...   147581.48
# 29  CUENTA UNICA DEL TESORO                       ...    21065.00
# 30  CUENTA UNICA DEL TESORO                       ...     5178.00
# 31  CUENTA UNICA DEL TESORO                       ...   129282.67
# 32  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...   122400.00
# 33  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    37240.00
# 34  YPFB - HEROES DEL CHACO                       ...    81155.99
# 35  YPFB - HEROES DEL CHACO                       ...  1312465.83
# 36  YPFB - HEROES DEL CHACO                       ...   244090.06
# 37  NEW YORK - CTA. 3544020682001                 ...        0.00
# 38  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   629729.23
# 39  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    70973.82
# 40  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    22355.88
# 41  VALORACION TITULOS DE LAS RESERVAS INTERNACION...    80284.19
# 42  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   153911.47
# 43  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...    18198.73
# 44  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...     2074.52
# 45  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 46  YPFB OPERACIONES FINANCIERAS EXTRAORDINARIAS  ...    53876.80
# 47  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...    13992.00
# 48  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  5380396.94
# 49  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     4515.81
# 50  TGN CUENTA TRANSITORIA- M/E                   ...       20.00
# 51  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  2000000.00
# 52  TGN CUENTA TRANSITORIA- M/E                   ...       30.00
# 53  RECAUDACIONES CONSULARES                      ...       40.00
# 54  RECAUDACIONES CONSULARES                      ...       50.00
# 55  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  7500000.00
# 56  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 57  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
# 58  RECAUDACIONES CONSULARES                      ...       50.00
#
#                                               Detalle  \
# 0   Saldo ME = -687701.69 ;Bs/Mo: 6.86000000000 ;S...
# 1   Saldo Ant.= 66873.00 ;Bs: 9.64941320000 = $us ...
# 2                                                 NaN
# 3                                                 NaN
# 4                          SWIFT N° 1805 DE LA FECHA.
# 5                POR CUENTA DE 101DOMAIN GRS LIMITED.
# 6   POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# 7          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 8          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 9   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# 10                                                NaN
# 11  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# 12  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# 13   (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 14                               (CC:H-0046564-2022)
# 15                               (CC:H-0046565-2022)
# 16  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# 17                               (CC:H-0046569-2022)
# 18                               (CC:H-0046570-2022)
# 19                               (CC:H-0046571-2022)
# 20                                                NaN
# 21  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 22  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 23                                                NaN
# 24  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 25                                                NaN
# 26  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 27  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 28  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 29  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 30  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 31  TERMINAL INTERNACIONAL DEL SUR SA, CTA. 425105...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                      (±, 876970.4)
# 38  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 39  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 40  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 41                                                NaN
# 42  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 43                                                NaN
# 44  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 45                                                NaN
# 46                                                NaN
# 47                                (CC:H-0046566-2022)
# 48                                (CC:H-0046567-2022)
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                                 Glosa
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...
# 3   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 4   ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 12  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 13  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 14  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 15  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 16  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 17  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 18  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 19  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 22  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 23  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 24  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 25  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 26  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 27  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 28  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 29  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 30  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 31  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 32  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 33  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 34  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1770...
# 35  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1767...
# 36  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1765...
# 37  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 38  PAGO A BANCO EUROPEO DE INV PRÉSTAMO FIN 82800...
# 39  PAGO A BID PRÉSTAMO 1075-SF-BO-8 VCTO. 06-02-2...
# 40  PAGO A BID PRÉSTAMO 1118-SF-BO VCTO. 06-02-202...
# 41  REVALORACIÓN DE TÍTULOS AL 07-02-2022, PORTAFO...
# 42  PAGO A CAF PRÉSTAMO CFA010869 VCTO. 07-02-2022...
# 43  INTERÉS DEVENGADO DE TÍTULOS AL 07-02-2022, PO...
# 44  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1755...
# 45  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 46  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1754...
# 47  REGISTRO TRANSITORIO SEGUN SWIFT NO.1785 HASTA...
# 48  REGISTRO TRANSITORIO SEGUN SWIFT NO.1803 HASTA...
# 49  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1786...
# 50  DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMA...
# 51  PAGO CHEQUE: D-22-99977     , BENEFICIARIO: EM...
# 52  DEPOSITO DE EFECTIVO, DEPOSITANTE: VICTOR SAMU...
# 53  DEPOSITO DE EFECTIVO, DEPOSITANTE: BERTHA MAMA...
# 54  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA GU...
# 55  PAGO CHEQUE: D-21-99306     , BENEFICIARIO: MA...
# 56  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...
# 57  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 58  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...

# %%
texto1 = "PAGO A EXIMBANK CHINA POPUL PRÉSTAMO PBC 2015 (08) 350 VCTO. 21-01-2022 POR CUENTA DE TGN , NTI. 015626 VALOR 21-01-2022 CAPITAL USD 27.355.555,56 COMISIONES USD 260.358,75"
texto2= "PAGO A AFD PRÉSTAMO CBO-1009-01-J VCTO. 21-01-2022 POR CUENTA DE ENDE , VALOR 21-01-2022  INTERESES EUR 168.666,67"

#capital = re.findall(" CAPITAL (.*)(?= [IC])" , texto1)
capital = re.findall(" CAPITAL (.*)(?= [INTERESES][COMISIONES])" , texto1)
intereses = re.findall(" INTERESES (.*)(?=[C\s])" , texto1)
comisiones = re.findall(" COMISIONES (.*)" , texto1)

#t= pd.DataFrame(search)
#t
print(capital, intereses, comisiones)
# Out:
# [] [] ['USD 260.358,75']

# %%
aux1=bd["comprobante"].unique()
consolidado=pd.DataFrame()

for q in range(len(aux1)):
    aux2 = bd[bd["comprobante"]==aux1[q]]
    aux2=aux2.reset_index(drop=True)
    data1=[]
    columnas1=["Tipo","Comprobante","Concepto","Mayor","codMov","Movimiento","MN","Glosa","GlosaDetalle"]
    data2=[]
    columnas2=["Tipo","Comprobante","Concepto","Mayor1","Mayor2","codMov","Movimiento","MontoUSD","Detalle","Glosa"] #luego pones mas campos importantes
    print("Comprobante ",q)
    print(aux2["comprobante"][0])
    if aux2["tipo"][0]=='V' or aux2["tipo"][0]=='D': ####### los ajustes por arbitraje y revalorizacion ######
        debemenoshaber(aux2.index)
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)
    else: # estos son los casos normales digamos ##############################################################
        print("Hay duplicado: ",aux2.duplicated(subset=['mn']).any())
        if aux2.duplicated(subset=['mn']).any()==True:  ## aqui sacamos los repetidos en la MN
            aux3=aux2.duplicated(subset=['mn'],keep=False)
            aux4=aux3.index[aux3==True].tolist()
            print('aux4')
            print(aux4)
            if len(aux4)==2:
                for x in range(len(aux4)):
                    data1.append({
                        "Tipo":aux2["tipo"][aux4[x]],"Comprobante":aux2["comprobante"][aux4[x]],"Concepto":aux2["dh"][aux4[x]],
                        "Mayor":aux2["mayor"][aux4[x]],"codMov":aux2["codMov"][aux4[x]],"Movimiento":aux2["nomMov"][aux4[x]],
                        "MN":aux2["mn"][aux4[x]],"Glosa":aux2["glosa"][aux4[x]],"GlosaDetalle":aux2["glosaRenglon"][aux4[x]],
                                })
                    pares=pd.DataFrame(data1,columns=columnas1)
                print("largo de aux2: ",len(aux2))
                print(pares)
                if pares["Mayor"][0] in cuentas and pares["Mayor"][1] in cuentas:
                    #print("Posible Neteo")
                    llenarData("Neteo",0,1)  ######## aqui ver para que el monto sea cero y que en el detalle salga el monto
                    unRegistro=pd.DataFrame(data2,columns=columnas2)
                else:     
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="D":
                        print('caso 1')
                        llenarData("Ingreso",0,1)        
                    if pares["Mayor"][0] in cuentas and pares["Mayor"][1] not in cuentas and pares["Concepto"][0]=="H":
                        print('caso 2')
                        llenarData("Egreso",0,1)                   
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="D":
                        print('caso 3')
                        llenarData("Ingreso",1,0)                    
                    if pares["Mayor"][1] in cuentas and pares["Mayor"][0] not in cuentas and pares["Concepto"][1]=="H":            
                        print('caso 4')
                        llenarData("Egreso",1,0)
            else:
                debemenoshaber(range(len(aux2)))
        else:   # Aqui anotamos todos los que no son repetidos
            print('aux2')
            aux2= aux2.sort_values(by='mayor') #, key=cuentas)
            aux2=aux2.reset_index(drop=True)
            print(aux2)
            for x in range(len(aux2)):
                data1.append({
                    "Tipo":aux2["tipo"][x],"Comprobante":aux2["comprobante"][x],"Concepto":aux2["dh"][x],
                    "Mayor":aux2["mayor"][x],"codMov":aux2["codMov"][x],"Movimiento":aux2["nomMov"][x],
                    "MN":aux2["mn"][x],"Glosa":aux2["glosa"][x],"GlosaDetalle":aux2["glosaRenglon"][x],
                            })
                pares=pd.DataFrame(data1,columns=columnas1)
            print(pares)
            if len(aux2)==1:  ### los sueltitos (se supone que los otros movimientos estan en otras areas, ej. gadm)              
                print("entramos con 1")
                if pares["Concepto"][0]=="D":
                    print('caso 5')
                    llenarData("Ingreso",0,0)
                else:
                    print('caso 6')
                    llenarData("Egreso",0,0)
            else:             # Aqui es cuando no hay duplicados y no son pares ni sueltitos
                print("mas de 2")
                debemenoshaber(range(len(aux2)))
        unRegistro=pd.DataFrame(data2,columns=columnas2)
        consolidado=consolidado.append(unRegistro, ignore_index=True)  

consolidado
#consolidado.to_excel("borrar10ene.xlsx")
# Out:
# Comprobante  0
# 21863
# largo cuando dentra al debehaber:  20
# Comprobante  1
# 28487
# largo cuando dentra al debehaber:  18
# Comprobante  2
# 1025337
# Hay duplicado:  False
# aux2
#    nro_centro tipo glosaRenglon dh         mo  moneda  codMov  \
# 0           1    S          NaN  D  100000.00      53    6072
# 1           1    S          NaN  H  114408.00      34    5896
# 2           1    S          NaN  H     975.12      69    1585
#
#                                               nomMov         mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  785814.00
# 1  NEW YORK - CTA. 3544020682001                 ...  784838.88
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     975.12
#
#                                                glosa  comprobante  mayor
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337     10
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337     10
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...      1025337    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025337        D     10    6072
# 1    S      1025337        H     10    5896
# 2    S      1025337        H    680    1585
#
#                                           Movimiento         MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  785814.00
# 1  NEW YORK - CTA. 3544020682001                 ...  784838.88
# 2  DIFERENCIA DE CAMBIO POR ARBITRAJE            ...     975.12
#
#                                                Glosa  GlosaDetalle
# 0  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# 1  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# 2  'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...           NaN
# mas de 2
# largo cuando dentra al debehaber:  3
# Comprobante  3
# 1025347
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025347        D     11    2902
# 1    S      1025347        H    606    1535
#
#                                           Movimiento        MN  \
# 0  INTERESES DEVENGADOS OVERNIGHT CAPITAL TRABAJO...  49023.55
# 1  INTERESES OVERNIGHT CAPITAL TRABAJO           ...  49023.55
#
#                                                Glosa  GlosaDetalle
# 0  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# 1  'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...           NaN
# caso 1
# dentro  1025347
# Comprobante  4
# 1025355
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    S                         SWIFT N° 1805 DE LA FECHA.  H
# 1           1    S  CTA. 00132032001 ECEBOL - GESTION OPERATIVA CO...  D
# 2           1    S  CTA. 00132032001 ECEBOL - GESTION OPERATIVA, C...  D
# 3           1    S                                                NaN  H
# 4           1    S                                                NaN  H
#
#        mo  moneda  codMov                                             nomMov  \
# 0   17.50      53    6072  MADRID EUROS CUENTA ES2990299029960000000107  ...
# 1  139.52      69    3987  CUENTA UNICA DEL TESORO                       ...
# 2   50.00      69    3987  CUENTA UNICA DEL TESORO                       ...
# 3   43.50      69    1514  UTILES DE ESCRITORIO                          ...
# 4    2.00      69    6890  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...
#
#        mn                                              glosa  comprobante  \
# 0  137.52  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 1  139.52  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 2   50.00  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 3   43.50  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
# 4    2.00  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...      1025355
#
#    mayor
# 0     10
# 1    412
# 2    412
# 3    600
# 4    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025355        H     10    6072
# 1    S      1025355        D    412    3987
# 2    S      1025355        D    412    3987
# 3    S      1025355        H    600    1514
# 4    S      1025355        H    680    6890
#
#                                           Movimiento      MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  137.52
# 1  CUENTA UNICA DEL TESORO                       ...  139.52
# 2  CUENTA UNICA DEL TESORO                       ...   50.00
# 3  UTILES DE ESCRITORIO                          ...   43.50
# 4  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2.00
#
#                                                Glosa  \
# 0  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 1  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 2  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 3  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 4  ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
#
#                                         GlosaDetalle
# 0                         SWIFT N° 1805 DE LA FECHA.
# 1  CTA. 00132032001 ECEBOL - GESTION OPERATIVA CO...
# 2  CTA. 00132032001 ECEBOL - GESTION OPERATIVA, C...
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  5
# 1025365
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025365        D     10    5896
# 1    S      1025365        H    412    4710
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  11849.76
# 1  03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...  11849.76
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                            GlosaDetalle
# 0                 A LA CUENTA 03-W-302.
# 1  POR CUENTA DE 101DOMAIN GRS LIMITED.
# caso 1
# dentro  1025365
# Comprobante  6
# 1025366
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025366        D     10    5896
# 1    S      1025366        H    412    5832
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  13276.5
# 1  03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...  13276.5
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                         GlosaDetalle
# 0                              A LA CUENTA 03-H-307.
# 1  POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# caso 1
# dentro  1025366
# Comprobante  7
# 1025368
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025368        D     10    5896
# 1    S      1025368        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1730435.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  1730435.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1       POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# caso 1
# dentro  1025368
# Comprobante  8
# 1025371
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025371        D     10    5896
# 1    S      1025371        H    404    7954
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  2076522.0
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  2076522.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
#
#                                       GlosaDetalle
# 0  A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1       POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# caso 1
# dentro  1025371
# Comprobante  9
# 1025374
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025374        D     10    5896
# 1    S      1025374        H    404    7954
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  536211.9
# 1  YPFB - EXPORTACION DE UREA Y OTROS            ...  536211.9
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 1  ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
#
#                                         GlosaDetalle
# 0    A LA CUENTA YPFB - EXPORTACION DE UREA Y OTROS.
# 1  POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# caso 1
# dentro  1025374
# Comprobante  10
# 1025377
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025377        D     16    6286
# 1    S      1025377        H    499    7355
#
#                                           Movimiento      MN  \
# 0  TITULOS - PORTAFOLIO DE LIQUIDEZ              ...  266.85
# 1  VALORACION TITULOS DE LAS RESERVAS INTERNACION...  266.85
#
#                                                Glosa  GlosaDetalle
# 0  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# 1  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...           NaN
# caso 1
# dentro  1025377
# Comprobante  11
# 1025378
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025378        D     10    5896
# 1    S      1025378        H    403    3910
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  24696000.0
# 1  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  24696000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# caso 1
# dentro  1025378
# Comprobante  12
# 1025383
# Hay duplicado:  True
# aux4
# [0, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025383        D     10    5896
# 1    S      1025383        H    412     818
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  4733.4
# 1  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...  4733.4
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 1  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
#
#                                         GlosaDetalle
# 0  A LA CUENTA 1-2232746 UAGRM FAC.DE CIENCIAS EX...
# 1  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# caso 1
# dentro  1025383
# Comprobante  13
# 1025388
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025388        D    198    3641
# 1    S      1025388        H     10    6072
#
#                                           Movimiento     MN  \
# 0  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...  78.58
# 1  MADRID EUROS CUENTA ES2990299029960000000107  ...  78.58
#
#                                                Glosa  \
# 0  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 1  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
#
#                                        GlosaDetalle
# 0  (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 1                          COMISIONES DEL BANQUERO.
# caso 4
# dentro  1025388
# Comprobante  14
# 1025390
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025390        D     10    5896
# 1    S      1025390        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1509.2
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1509.2
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046564-2022)
# caso 1
# dentro  1025390
# Comprobante  15
# 1025391
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025391        D     10    5896
# 1    S      1025391        H    498    8304
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10564.4
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  10564.4
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046565-2022)
# caso 1
# dentro  1025391
# Comprobante  16
# 1025393
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025393        D     10    5896
# 1    S      1025393        H    414    7866
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  48020000.0
# 1  EFECTIVO GARANTIA FONDO CPVIS                 ...  48020000.0
#
#                                                Glosa  \
# 0  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 1  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# caso 1
# dentro  1025393
# Comprobante  17
# 1025404
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025404        D     10    5896
# 1    S      1025404        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1543.5
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1543.5
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046569-2022)
# caso 1
# dentro  1025404
# Comprobante  18
# 1025405
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025405        D     10    5896
# 1    S      1025405        H    498    8304
#
#                                           Movimiento       MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1392.58
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  1392.58
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046570-2022)
# caso 1
# dentro  1025405
# Comprobante  19
# 1025406
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    S      1025406        D     10    5896
# 1    S      1025406        H    498    8304
#
#                                           Movimiento      MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  4561.9
# 1  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...  4561.9
#
#                                                Glosa          GlosaDetalle
# 0  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...                   NaN
# 1  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...  (CC:H-0046571-2022)
# caso 1
# dentro  1025406
# Comprobante  20
# 1778875
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778875        D    498    6817
# 1    G      1778875        H     10    5896
#
#                                           Movimiento          MN  \
# 0  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  34300000.0
# 1  NEW YORK - CTA. 3544020682001                 ...  34300000.0
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  BANCO GANADERO S.A., CTA. 496553483 JPMORGAN C...
# caso 4
# dentro  1778875
# Comprobante  21
# 1778876
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...  H
# 1           1    G  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...  D
# 2           1    G  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...  D
# 3           1    G                                                NaN  D
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
# 7           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   16012.00      53    6072
# 1    4075.24      69    3987
# 2     395.81      69    3987
# 3  123583.48      69    4088
# 4     191.40      69    1510
# 5      43.50      69    1514
# 6     109.45      69    1563
# 7    1834.18      69    6890
#
#                                               nomMov         mn  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  125824.54
# 1  CUENTA UNICA DEL TESORO                       ...    4075.24
# 2  CUENTA UNICA DEL TESORO                       ...     395.81
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  123583.48
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 5  UTILES DE ESCRITORIO                          ...      43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     109.45
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    1834.18
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    412
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    498
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    600
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    650
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778876    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778876        H     10    6072
# 1    G      1778876        D    412    3987
# 2    G      1778876        D    412    3987
# 3    G      1778876        D    498    4088
# 4    G      1778876        H    600    1510
# 5    G      1778876        H    600    1514
# 6    G      1778876        H    650    1563
# 7    G      1778876        H    680    6890
#
#                                           Movimiento         MN  \
# 0  MADRID EUROS CUENTA ES2990299029960000000107  ...  125824.54
# 1  CUENTA UNICA DEL TESORO                       ...    4075.24
# 2  CUENTA UNICA DEL TESORO                       ...     395.81
# 3  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  123583.48
# 4  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 5  UTILES DE ESCRITORIO                          ...      43.50
# 6  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     109.45
# 7  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    1834.18
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 7  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 1  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...
# 2  LIB. 00514012002 ENDE - BS ADMINISTRACION Y OP...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  8
# Comprobante  22
# 1778877
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...  H
# 1           1    G                                                NaN  D
# 2           1    G                                                NaN  H
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
#
#         mo  moneda  codMov                                             nomMov  \
# 0  4780.16      34    5896  NEW YORK - CTA. 3544020682001                 ...
# 1  4824.30      34    4088  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...
# 2   191.40      69    1510  REEMBOLSO GASTOS DE COMUNICACIÓN              ...
# 3    43.50      69    1514  UTILES DE ESCRITORIO                          ...
# 4    28.53      69    1563  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...
#
#          mn                                              glosa  comprobante  \
# 0  32791.90  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 1  33094.70  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 2    191.40  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 3     43.50  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
# 4     28.53  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...      1778877
#
#    mayor
# 0     10
# 1    498
# 2    600
# 3    600
# 4    650
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778877        H     10    5896
# 1    G      1778877        D    498    4088
# 2    G      1778877        H    600    1510
# 3    G      1778877        H    600    1514
# 4    G      1778877        H    650    1563
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  32791.90
# 1  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  33094.70
# 2  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 3  UTILES DE ESCRITORIO                          ...     43.50
# 4  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     28.53
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 2  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 3  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 4  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  5
# Comprobante  23
# 1778878
# Hay duplicado:  True
# aux4
# [0, 4]
# largo de aux2:  6
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778878        D    498    4088
# 1    G      1778878        H     10    5896
#
#                                           Movimiento       MN  \
# 0  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  49901.7
# 1  NEW YORK - CTA. 3544020682001                 ...  49901.7
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  EMBAJADA DE BOLIVIA EN HOLANDA, CTA. NL31ABNA0...
# caso 4
# dentro  1778878
# Comprobante  24
# 1778879
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...  H
# 1           1    G  LIB. 00598012001 EEPB - RECURSOS ESPECÍFICOS P...  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0   1476.09      34    5896
# 1    280.15      69    3987
# 2  10273.59      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5      8.83      69    1563
# 6    147.61      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10125.98
# 1  CUENTA UNICA DEL TESORO                       ...    280.15
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  10273.59
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      8.83
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    147.61
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778879    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778879        H     10    5896
# 1    G      1778879        D    412    3987
# 2    G      1778879        D    498    4088
# 3    G      1778879        H    600    1510
# 4    G      1778879        H    600    1514
# 5    G      1778879        H    650    1563
# 6    G      1778879        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  10125.98
# 1  CUENTA UNICA DEL TESORO                       ...    280.15
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  10273.59
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      8.83
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    147.61
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 1  LIB. 00598012001 EEPB - RECURSOS ESPECÍFICOS P...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  25
# 1778880
# Hay duplicado:  True
# aux4
# [0, 4]
# largo de aux2:  6
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778880        D    498    4088
# 1    G      1778880        H     10    5896
#
#                                           Movimiento        MN  \
# 0  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  685416.9
# 1  NEW YORK - CTA. 3544020682001                 ...  685416.9
#
#                                                Glosa  \
# 0  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 1  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
#
#                                         GlosaDetalle
# 0                                                NaN
# 1  AIR MAURIN INC., CTA. 3892471207 JPMORGAN CHAS...
# caso 4
# dentro  1778880
# Comprobante  26
# 1778881
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...  H
# 1           1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   75828.70      34    5896
# 1     790.19      69    3987
# 2  527767.75      69    4088
# 3     191.40      69    1510
# 4      43.50      69    1514
# 5     452.57      69    1563
# 6    7582.87      69    6890
#
#                                               nomMov         mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  520184.88
# 1  CUENTA UNICA DEL TESORO                       ...     790.19
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  527767.75
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     452.57
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    7582.87
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778881    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778881        H     10    5896
# 1    G      1778881        D    412    3987
# 2    G      1778881        D    498    4088
# 3    G      1778881        H    600    1510
# 4    G      1778881        H    600    1514
# 5    G      1778881        H    650    1563
# 6    G      1778881        H    680    6890
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  520184.88
# 1  CUENTA UNICA DEL TESORO                       ...     790.19
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  527767.75
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     452.57
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    7582.87
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  27
# 1778882
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0  10000.00      34    5896
# 1    338.60      69    3987
# 2  69600.00      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5     59.68      69    1563
# 6   1000.00      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68600.00
# 1  CUENTA UNICA DEL TESORO                       ...    338.60
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  69600.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     59.68
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...   1000.00
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778882    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778882        H     10    5896
# 1    G      1778882        D    412    3987
# 2    G      1778882        D    498    4088
# 3    G      1778882        H    600    1510
# 4    G      1778882        H    600    1514
# 5    G      1778882        H    650    1563
# 6    G      1778882        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  68600.00
# 1  CUENTA UNICA DEL TESORO                       ...    338.60
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  69600.00
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     59.68
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...   1000.00
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  28
# 1778883
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#            mo  moneda  codMov  \
# 0   147581.48      34    5896
# 1     1282.40      69    3987
# 2  1027167.10      69    4088
# 3      191.40      69    1510
# 4       43.50      69    1514
# 5      880.79      69    1563
# 6    14758.15      69    6890
#
#                                               nomMov          mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1012408.95
# 1  CUENTA UNICA DEL TESORO                       ...     1282.40
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1027167.10
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      880.79
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    14758.15
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778883    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778883        H     10    5896
# 1    G      1778883        D    412    3987
# 2    G      1778883        D    498    4088
# 3    G      1778883        H    600    1510
# 4    G      1778883        H    600    1514
# 5    G      1778883        H    650    1563
# 6    G      1778883        H    680    6890
#
#                                           Movimiento          MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  1012408.95
# 1  CUENTA UNICA DEL TESORO                       ...     1282.40
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  1027167.10
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...      191.40
# 4  UTILES DE ESCRITORIO                          ...       43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...      880.79
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    14758.15
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 1        LIB. 00594012001 ASP-B FONDO DE OPERACIONES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  29
# 1778884
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...  H
# 1           1    G  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#           mo  moneda  codMov  \
# 0   21065.00      34    5896
# 1     414.54      69    3987
# 2  146612.40      69    4088
# 3     191.40      69    1510
# 4      43.50      69    1514
# 5     125.75      69    1563
# 6    2106.50      69    6890
#
#                                               nomMov         mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  144505.90
# 1  CUENTA UNICA DEL TESORO                       ...     414.54
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  146612.40
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     125.75
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2106.50
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778884    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778884        H     10    5896
# 1    G      1778884        D    412    3987
# 2    G      1778884        D    498    4088
# 3    G      1778884        H    600    1510
# 4    G      1778884        H    600    1514
# 5    G      1778884        H    650    1563
# 6    G      1778884        H    680    6890
#
#                                           Movimiento         MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  144505.90
# 1  CUENTA UNICA DEL TESORO                       ...     414.54
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  146612.40
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...     191.40
# 4  UTILES DE ESCRITORIO                          ...      43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     125.75
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    2106.50
#
#                                                Glosa  \
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
#
#                                         GlosaDetalle
# 0  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 1  LIB. 00378012002 SENATEX - ADMINISTRACION CENTRAL
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# mas de 2
# largo cuando dentra al debehaber:  7
# Comprobante  30
# 1778885
# Hay duplicado:  False
# aux2
#    nro_centro tipo                                       glosaRenglon dh  \
# 0           1    G  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...  H
# 1           1    G        LIB. 00594012001 ASP-B FONDO DE OPERACIONES  D
# 2           1    G                                                NaN  D
# 3           1    G                                                NaN  H
# 4           1    G                                                NaN  H
# 5           1    G                                                NaN  H
# 6           1    G                                                NaN  H
#
#          mo  moneda  codMov  \
# 0   5178.00      34    5896
# 1    305.53      69    3987
# 2  36038.88      69    4088
# 3    191.40      69    1510
# 4     43.50      69    1514
# 5     30.91      69    1563
# 6    517.80      69    6890
#
#                                               nomMov        mn  \
# 0  NEW YORK - CTA. 3544020682001                 ...  35521.08
# 1  CUENTA UNICA DEL TESORO                       ...    305.53
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  36038.88
# 3  REEMBOLSO GASTOS DE COMUNICACIÓN              ...    191.40
# 4  UTILES DE ESCRITORIO                          ...     43.50
# 5  COMISIONES SOBRE TRANSF. DE FONDOS AL EXTERIOR...     30.91
# 6  DIFERENCIAL CAMBIARIO P/VTA. USD - SECTOR PUBL...    517.80
#
#                                                glosa  comprobante  mayor
# 0  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885     10
# 1  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    412
# 2  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    498
# 3  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    600
# 4  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    600
# 5  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    650
# 6  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...      1778885    680
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    G      1778885        H     10    5896
# 1    G      1778885        D    412    3987
# 2    G      1778885        D    498    4088
# 3    G      1778885        H    600    1510
# 4    G      1778885        H    600    1514
# 5    G      1778885        H    650    1563
# 6    G      1778885        H    680    6890
#
#                                           Movimiento        MN  \
# 0  NEW YORK - CTA. 3544020682001                 ...  35521.08
# 1  CUENTA UNICA DEL TESORO                       ...    305.53
# 2  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...  36038.88
# ...
# 0  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...  3430000.0
# 1  DOLARES AMERICANOS EN TESORO PROPIO           ...  3430000.0
#
#                                                Glosa  GlosaDetalle
# 0  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...           NaN
# 1  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...           NaN
# caso 4
# dentro  1997267
# Comprobante  57
# 1997277
# Hay duplicado:  True
# aux4
# [1, 3]
# largo de aux2:  4
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    H      1997277        H    828    3559
# 1    H      1997277        H      7    8085
#
#                                           Movimiento        MN  \
# 0  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...  137200.0
# 1  DOLARES ESTADOUNIDENSES - MANDATO BUSA        ...  137200.0
#
#                                                Glosa  GlosaDetalle
# 0  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# 1  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...           NaN
# caso 4
# dentro  1997277
# Comprobante  58
# 1997352
# Hay duplicado:  True
# aux4
# [0, 1]
# largo de aux2:  2
#   Tipo  Comprobante Concepto  Mayor  codMov  \
# 0    O      1997352        D      7    3491
# 1    O      1997352        H    406     861
#
#                                           Movimiento     MN  \
# 0  DOLARES AMERICANOS EN TESORO PROPIO           ...  343.0
# 1  RECAUDACIONES CONSULARES                      ...  343.0
#
#                                                Glosa  GlosaDetalle
# 0  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...           NaN
# 1  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...           NaN
# caso 1
# dentro  1997352
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21863  Ingreso     410      10    6072
# 1     V        28487  Ingreso      22      17    6296
# 2     S      1025337  Ingreso      10      10    5896
# 3     S      1025347  Ingreso      11     606    1535
# 4     S      1025355   Egreso      10     412    3987
# 5     S      1025365  Ingreso      10     412    4710
# 6     S      1025366  Ingreso      10     412    5832
# 7     S      1025368  Ingreso      10     404    7954
# 8     S      1025371  Ingreso      10     404    7954
# 9     S      1025374  Ingreso      10     404    7954
# 10    S      1025377  Ingreso      16     499    7355
# 11    S      1025378  Ingreso      10     403    3910
# 12    S      1025383  Ingreso      10     412     818
# 13    S      1025388   Egreso      10     198    3641
# 14    S      1025390  Ingreso      10     498    8304
# 15    S      1025391  Ingreso      10     498    8304
# 16    S      1025393  Ingreso      10     414    7866
# 17    S      1025404  Ingreso      10     498    8304
# 18    S      1025405  Ingreso      10     498    8304
# 19    S      1025406  Ingreso      10     498    8304
# 20    G      1778875   Egreso      10     498    6817
# 21    G      1778876   Egreso      10     412    3987
# 22    G      1778877   Egreso      10     498    4088
# 23    G      1778878   Egreso      10     498    4088
# 24    G      1778879   Egreso      10     412    3987
# 25    G      1778880   Egreso      10     498    4088
# 26    G      1778881   Egreso      10     412    3987
# 27    G      1778882   Egreso      10     412    3987
# 28    G      1778883   Egreso      10     412    3987
# 29    G      1778884   Egreso      10     412    3987
# 30    G      1778885   Egreso      10     412    3987
# 31    G      1778886   Egreso      10     412    3987
# 32    G      1778887   Egreso      10     498    4088
# 33    G      1778888   Egreso      10     498    4088
# 34    G      1778889  Ingreso      10     404    5968
# 35    G      1778891  Ingreso      10     404    5968
# 36    G      1778893  Ingreso      10     404    5968
# 37    G      1779021    Neteo      10      10    5896
# 38    G      1779022   Egreso      10     412    5970
# 39    G      1779023   Egreso      10     412    5970
# 40    G      1779024   Egreso      10     412    5970
# 41    G      1779146   Egreso      16     499    7355
# 42    G      1779147   Egreso      10     412    5970
# 43    G      1779148  Ingreso      17     606    6538
# 44    G      1779150  Ingreso      10     412    5970
# 45    G      1779152   Egreso      10     498    6817
# 46    G      1779153  Ingreso      10     404    6705
# 47    G      1779295  Ingreso      10     498    1470
# 48    G      1779296  Ingreso      10     498    1470
# 49    G      1779298  Ingreso      10     412    4249
# 50    O      1997192  Ingreso       7     406     898
# 51    O      1997212   Egreso       7     403    3917
# 52    O      1997224  Ingreso       7     406     898
# 53    O      1997225  Ingreso       7     406     861
# 54    O      1997255  Ingreso       7     406     861
# 55    O      1997265   Egreso       7     403    3910
# 56    O      1997267   Egreso       7     403    6893
# 57    H      1997277   Egreso       7     828    3559
# 58    O      1997352  Ingreso       7     406     861
#
#                                            Movimiento    MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...        0.01
# 1   INTERESES DEVENGADOS                          ...  1022077.47
# 2   NEW YORK - CTA. 3544020682001                 ...      142.15
# 3   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     7146.29
# 4   CUENTA UNICA DEL TESORO                       ...       20.05
# 5   03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...     1727.37
# 6   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     1935.35
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...   252250.00
# 8   YPFB - EXPORTACION DE UREA Y OTROS            ...   302700.00
# 9   YPFB - EXPORTACION DE UREA Y OTROS            ...    78165.00
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3600000.00
# 12  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      690.00
# 13  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...       11.45
# 14  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      220.00
# 15  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...     1540.00
# 16  EFECTIVO GARANTIA FONDO CPVIS                 ...  7000000.00
# 17  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 18  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      203.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      665.00
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 21  CUENTA UNICA DEL TESORO                       ...    18341.77
# 22  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     4780.16
# 23  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     7274.30
# 24  CUENTA UNICA DEL TESORO                       ...     1476.09
# 25  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    99915.00
# 26  CUENTA UNICA DEL TESORO                       ...    75828.70
# 27  CUENTA UNICA DEL TESORO                       ...    10000.00
# 28  CUENTA UNICA DEL TESORO                       ...   147581.48
# 29  CUENTA UNICA DEL TESORO                       ...    21065.00
# 30  CUENTA UNICA DEL TESORO                       ...     5178.00
# 31  CUENTA UNICA DEL TESORO                       ...   129282.67
# 32  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...   122400.00
# 33  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    37240.00
# 34  YPFB - HEROES DEL CHACO                       ...    81155.99
# 35  YPFB - HEROES DEL CHACO                       ...  1312465.83
# 36  YPFB - HEROES DEL CHACO                       ...   244090.06
# 37  NEW YORK - CTA. 3544020682001                 ...        0.00
# 38  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   629729.23
# 39  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    70973.82
# 40  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    22355.88
# 41  VALORACION TITULOS DE LAS RESERVAS INTERNACION...    80284.19
# 42  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   153911.47
# 43  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...    18198.73
# 44  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...     2074.52
# 45  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 46  YPFB OPERACIONES FINANCIERAS EXTRAORDINARIAS  ...    53876.80
# 47  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...    13992.00
# 48  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  5380396.94
# 49  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     4515.81
# 50  TGN CUENTA TRANSITORIA- M/E                   ...       20.00
# 51  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  2000000.00
# 52  TGN CUENTA TRANSITORIA- M/E                   ...       30.00
# 53  RECAUDACIONES CONSULARES                      ...       40.00
# 54  RECAUDACIONES CONSULARES                      ...       50.00
# 55  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  7500000.00
# 56  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 57  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
# 58  RECAUDACIONES CONSULARES                      ...       50.00
#
#                                               Detalle  \
# 0   Saldo ME = -687701.69 ;Bs/Mo: 6.86000000000 ;S...
# 1   Saldo Ant.= 66873.00 ;Bs: 9.64941320000 = $us ...
# 2                                                 NaN
# 3                                                 NaN
# 4                          SWIFT N° 1805 DE LA FECHA.
# 5                POR CUENTA DE 101DOMAIN GRS LIMITED.
# 6   POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# 7          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 8          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 9   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# 10                                                NaN
# 11  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# 12  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# 13   (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 14                               (CC:H-0046564-2022)
# 15                               (CC:H-0046565-2022)
# 16  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# 17                               (CC:H-0046569-2022)
# 18                               (CC:H-0046570-2022)
# 19                               (CC:H-0046571-2022)
# 20                                                NaN
# 21  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 22  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 23                                                NaN
# 24  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 25                                                NaN
# 26  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 27  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 28  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 29  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 30  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 31  TERMINAL INTERNACIONAL DEL SUR SA, CTA. 425105...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                      (±, 876970.4)
# 38  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 39  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 40  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 41                                                NaN
# 42  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 43                                                NaN
# 44  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 45                                                NaN
# 46                                                NaN
# 47                                (CC:H-0046566-2022)
# 48                                (CC:H-0046567-2022)
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                                 Glosa
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...
# 3   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 4   ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 12  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 13  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 14  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 15  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 16  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 17  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 18  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 19  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 22  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 23  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 24  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 25  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 26  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 27  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 28  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 29  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 30  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 31  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 32  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 33  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 34  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1770...
# 35  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1767...
# 36  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1765...
# 37  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 38  PAGO A BANCO EUROPEO DE INV PRÉSTAMO FIN 82800...
# 39  PAGO A BID PRÉSTAMO 1075-SF-BO-8 VCTO. 06-02-2...
# 40  PAGO A BID PRÉSTAMO 1118-SF-BO VCTO. 06-02-202...
# 41  REVALORACIÓN DE TÍTULOS AL 07-02-2022, PORTAFO...
# 42  PAGO A CAF PRÉSTAMO CFA010869 VCTO. 07-02-2022...
# 43  INTERÉS DEVENGADO DE TÍTULOS AL 07-02-2022, PO...
# 44  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1755...
# 45  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 46  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1754...
# 47  REGISTRO TRANSITORIO SEGUN SWIFT NO.1785 HASTA...
# 48  REGISTRO TRANSITORIO SEGUN SWIFT NO.1803 HASTA...
# 49  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1786...
# 50  DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMA...
# 51  PAGO CHEQUE: D-22-99977     , BENEFICIARIO: EM...
# 52  DEPOSITO DE EFECTIVO, DEPOSITANTE: VICTOR SAMU...
# 53  DEPOSITO DE EFECTIVO, DEPOSITANTE: BERTHA MAMA...
# 54  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA GU...
# 55  PAGO CHEQUE: D-21-99306     , BENEFICIARIO: MA...
# 56  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...
# 57  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 58  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...

# %%
movimientosAux= movimientos.drop(columns=['nomMovimiento'])
conCodigos = pd.merge(consolidado,movimientosAux, on=['Concepto', 'Mayor2','codMov'], how='left').fillna(valorDefecto)
conCodigos

##### el 01feb tiene buenos moviemientos para ver glosas
# Out:
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21863  Ingreso     410      10    6072
# 1     V        28487  Ingreso      22      17    6296
# 2     S      1025337  Ingreso      10      10    5896
# 3     S      1025347  Ingreso      11     606    1535
# 4     S      1025355   Egreso      10     412    3987
# 5     S      1025365  Ingreso      10     412    4710
# 6     S      1025366  Ingreso      10     412    5832
# 7     S      1025368  Ingreso      10     404    7954
# 8     S      1025371  Ingreso      10     404    7954
# 9     S      1025374  Ingreso      10     404    7954
# 10    S      1025377  Ingreso      16     499    7355
# 11    S      1025378  Ingreso      10     403    3910
# 12    S      1025383  Ingreso      10     412     818
# 13    S      1025388   Egreso      10     198    3641
# 14    S      1025390  Ingreso      10     498    8304
# 15    S      1025391  Ingreso      10     498    8304
# 16    S      1025393  Ingreso      10     414    7866
# 17    S      1025404  Ingreso      10     498    8304
# 18    S      1025405  Ingreso      10     498    8304
# 19    S      1025406  Ingreso      10     498    8304
# 20    G      1778875   Egreso      10     498    6817
# 21    G      1778876   Egreso      10     412    3987
# 22    G      1778877   Egreso      10     498    4088
# 23    G      1778878   Egreso      10     498    4088
# 24    G      1778879   Egreso      10     412    3987
# 25    G      1778880   Egreso      10     498    4088
# 26    G      1778881   Egreso      10     412    3987
# 27    G      1778882   Egreso      10     412    3987
# 28    G      1778883   Egreso      10     412    3987
# 29    G      1778884   Egreso      10     412    3987
# 30    G      1778885   Egreso      10     412    3987
# 31    G      1778886   Egreso      10     412    3987
# 32    G      1778887   Egreso      10     498    4088
# 33    G      1778888   Egreso      10     498    4088
# 34    G      1778889  Ingreso      10     404    5968
# 35    G      1778891  Ingreso      10     404    5968
# 36    G      1778893  Ingreso      10     404    5968
# 37    G      1779021    Neteo      10      10    5896
# 38    G      1779022   Egreso      10     412    5970
# 39    G      1779023   Egreso      10     412    5970
# 40    G      1779024   Egreso      10     412    5970
# 41    G      1779146   Egreso      16     499    7355
# 42    G      1779147   Egreso      10     412    5970
# 43    G      1779148  Ingreso      17     606    6538
# 44    G      1779150  Ingreso      10     412    5970
# 45    G      1779152   Egreso      10     498    6817
# 46    G      1779153  Ingreso      10     404    6705
# 47    G      1779295  Ingreso      10     498    1470
# 48    G      1779296  Ingreso      10     498    1470
# 49    G      1779298  Ingreso      10     412    4249
# 50    O      1997192  Ingreso       7     406     898
# 51    O      1997212   Egreso       7     403    3917
# 52    O      1997224  Ingreso       7     406     898
# 53    O      1997225  Ingreso       7     406     861
# 54    O      1997255  Ingreso       7     406     861
# 55    O      1997265   Egreso       7     403    3910
# 56    O      1997267   Egreso       7     403    6893
# 57    H      1997277   Egreso       7     828    3559
# 58    O      1997352  Ingreso       7     406     861
#
#                                            Movimiento    MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...        0.01
# 1   INTERESES DEVENGADOS                          ...  1022077.47
# 2   NEW YORK - CTA. 3544020682001                 ...      142.15
# 3   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     7146.29
# 4   CUENTA UNICA DEL TESORO                       ...       20.05
# 5   03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...     1727.37
# 6   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     1935.35
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...   252250.00
# 8   YPFB - EXPORTACION DE UREA Y OTROS            ...   302700.00
# 9   YPFB - EXPORTACION DE UREA Y OTROS            ...    78165.00
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3600000.00
# 12  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      690.00
# 13  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...       11.45
# 14  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      220.00
# 15  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...     1540.00
# 16  EFECTIVO GARANTIA FONDO CPVIS                 ...  7000000.00
# 17  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 18  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      203.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      665.00
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 21  CUENTA UNICA DEL TESORO                       ...    18341.77
# 22  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     4780.16
# 23  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     7274.30
# 24  CUENTA UNICA DEL TESORO                       ...     1476.09
# 25  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    99915.00
# 26  CUENTA UNICA DEL TESORO                       ...    75828.70
# 27  CUENTA UNICA DEL TESORO                       ...    10000.00
# 28  CUENTA UNICA DEL TESORO                       ...   147581.48
# 29  CUENTA UNICA DEL TESORO                       ...    21065.00
# 30  CUENTA UNICA DEL TESORO                       ...     5178.00
# 31  CUENTA UNICA DEL TESORO                       ...   129282.67
# 32  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...   122400.00
# 33  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    37240.00
# 34  YPFB - HEROES DEL CHACO                       ...    81155.99
# 35  YPFB - HEROES DEL CHACO                       ...  1312465.83
# 36  YPFB - HEROES DEL CHACO                       ...   244090.06
# 37  NEW YORK - CTA. 3544020682001                 ...        0.00
# 38  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   629729.23
# 39  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    70973.82
# 40  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    22355.88
# 41  VALORACION TITULOS DE LAS RESERVAS INTERNACION...    80284.19
# 42  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   153911.47
# 43  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...    18198.73
# 44  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...     2074.52
# 45  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 46  YPFB OPERACIONES FINANCIERAS EXTRAORDINARIAS  ...    53876.80
# 47  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...    13992.00
# 48  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  5380396.94
# 49  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     4515.81
# 50  TGN CUENTA TRANSITORIA- M/E                   ...       20.00
# 51  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  2000000.00
# 52  TGN CUENTA TRANSITORIA- M/E                   ...       30.00
# 53  RECAUDACIONES CONSULARES                      ...       40.00
# 54  RECAUDACIONES CONSULARES                      ...       50.00
# 55  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  7500000.00
# 56  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 57  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
# 58  RECAUDACIONES CONSULARES                      ...       50.00
#
#                                               Detalle  \
# 0   Saldo ME = -687701.69 ;Bs/Mo: 6.86000000000 ;S...
# 1   Saldo Ant.= 66873.00 ;Bs: 9.64941320000 = $us ...
# 2                                         Ver glosita
# 3                                         Ver glosita
# 4                          SWIFT N° 1805 DE LA FECHA.
# 5                POR CUENTA DE 101DOMAIN GRS LIMITED.
# 6   POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# 7          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 8          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 9   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# 10                                        Ver glosita
# 11  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# 12  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# 13   (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 14                               (CC:H-0046564-2022)
# 15                               (CC:H-0046565-2022)
# 16  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# 17                               (CC:H-0046569-2022)
# 18                               (CC:H-0046570-2022)
# 19                               (CC:H-0046571-2022)
# 20                                        Ver glosita
# 21  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 22  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 23                                        Ver glosita
# 24  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 25                                        Ver glosita
# 26  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 27  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 28  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 29  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 30  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 31  TERMINAL INTERNACIONAL DEL SUR SA, CTA. 425105...
# 32                                        Ver glosita
# 33                                        Ver glosita
# 34                                        Ver glosita
# 35                                        Ver glosita
# 36                                        Ver glosita
# 37                                      (±, 876970.4)
# 38  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 39  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 40  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 41                                        Ver glosita
# 42  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 43                                        Ver glosita
# 44  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 45                                        Ver glosita
# 46                                        Ver glosita
# 47                                (CC:H-0046566-2022)
# 48                                (CC:H-0046567-2022)
# 49                                        Ver glosita
# 50                                        Ver glosita
# 51                                        Ver glosita
# 52                                        Ver glosita
# 53                                        Ver glosita
# 54                                        Ver glosita
# 55                                        Ver glosita
# 56                                        Ver glosita
# 57                                        Ver glosita
# 58                                        Ver glosita
#
#                                                 Glosa  \
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...
# 3   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 4   ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 12  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 13  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 14  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 15  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 16  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 17  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 18  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 19  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 22  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 23  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 24  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 25  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 26  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 27  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 28  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 29  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 30  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 31  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 32  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 33  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 34  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1770...
# 35  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1767...
# 36  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1765...
# 37  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 38  PAGO A BANCO EUROPEO DE INV PRÉSTAMO FIN 82800...
# 39  PAGO A BID PRÉSTAMO 1075-SF-BO-8 VCTO. 06-02-2...
# 40  PAGO A BID PRÉSTAMO 1118-SF-BO VCTO. 06-02-202...
# 41  REVALORACIÓN DE TÍTULOS AL 07-02-2022, PORTAFO...
# 42  PAGO A CAF PRÉSTAMO CFA010869 VCTO. 07-02-2022...
# 43  INTERÉS DEVENGADO DE TÍTULOS AL 07-02-2022, PO...
# 44  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1755...
# 45  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 46  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1754...
# 47  REGISTRO TRANSITORIO SEGUN SWIFT NO.1785 HASTA...
# 48  REGISTRO TRANSITORIO SEGUN SWIFT NO.1803 HASTA...
# 49  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1786...
# 50  DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMA...
# 51  PAGO CHEQUE: D-22-99977     , BENEFICIARIO: EM...
# 52  DEPOSITO DE EFECTIVO, DEPOSITANTE: VICTOR SAMU...
# 53  DEPOSITO DE EFECTIVO, DEPOSITANTE: BERTHA MAMA...
# 54  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA GU...
# 55  PAGO CHEQUE: D-21-99306     , BENEFICIARIO: MA...
# 56  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...
# 57  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 58  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...
#
#                              codigoBC                  codigoPropio
# 0                         Ver glosita                   Ver glosita
# 1                         Ver glosita                   Ver glosita
# 2                         Ver glosita                   Ver glosita
# 3                       RENTA (BCI14)           Intereses Overnight
# 4                         Ver glosita                   Ver glosita
# 5                  CORRIENTES (BCI12)                         ADSIB
# 6                  CORRIENTES (BCI12)  Dir. Gral. Aeronáutica Civil
# 7               Y.P.F.B. Otros (BCI5)                     YPFB UREA
# 8               Y.P.F.B. Otros (BCI5)                     YPFB UREA
# 9               Y.P.F.B. Otros (BCI5)                     YPFB UREA
# 10                      RENTA (BCI14)     Valoración de Titulos RIN
# 11    TRANSFERENCIAS del EXT. (BCI22)                   Banco Unión
# 12                        Ver glosita                   Ver glosita
# 13                        Ver glosita                   Ver glosita
# 14                        Ver glosita                   Ver glosita
# 15                        Ver glosita                   Ver glosita
# 16    TRANSFERENCIAS del EXT. (BCI22)                   Ver glosita
# 17                        Ver glosita                   Ver glosita
# 18                        Ver glosita                   Ver glosita
# 19                        Ver glosita                   Ver glosita
# 20     TRANSFERENCIAS al EXT. (BCE22)                   Ver glosita
# 21                        Ver glosita                   Ver glosita
# 22                        Ver glosita                   Ver glosita
# 23                        Ver glosita                   Ver glosita
# 24                        Ver glosita                   Ver glosita
# 25                        Ver glosita                   Ver glosita
# 26                        Ver glosita                   Ver glosita
# 27                        Ver glosita                   Ver glosita
# 28                        Ver glosita                   Ver glosita
# 29                        Ver glosita                   Ver glosita
# 30                        Ver glosita                   Ver glosita
# 31                        Ver glosita                   Ver glosita
# 32                        Ver glosita                   Ver glosita
# 33                        Ver glosita                   Ver glosita
# 34                        Ver glosita                   Ver glosita
# 35                        Ver glosita                   Ver glosita
# 36                        Ver glosita                   Ver glosita
# 37                        Ver glosita                   Ver glosita
# 38                        Ver glosita                   Ver glosita
# 39                        Ver glosita                   Ver glosita
# 40                        Ver glosita                   Ver glosita
# 41                      OTROS (BCE12)     Valoración de Titulos RIN
# 42                        Ver glosita                   Ver glosita
# 43                      RENTA (BCI14)     Intereses Portafolio Euro
# 44                        Ver glosita                   Ver glosita
# 45     TRANSFERENCIAS al EXT. (BCE22)                   Ver glosita
# 46          OTROS PORTAFOLIOS (BCI33)          YPFB Op. Financieras
# 47                        Ver glosita                   Ver glosita
# 48                        Ver glosita                   Ver glosita
# 49                 CORRIENTES (BCI12)                        Aasana
# 50                 CORRIENTES (BCI12)                   Ver glosita
# 51  OPERACIONES BANCARIAS (3) (BCE19)                Banco Ganadero
# 52                 CORRIENTES (BCI12)                   Ver glosita
# 53                 CORRIENTES (BCI12)                   Ver glosita
# 54                 CORRIENTES (BCI12)                   Ver glosita
# 55  OPERACIONES BANCARIAS (3) (BCE19)                   Banco Unión
# 56  OPERACIONES BANCARIAS (3) (BCE19)               Banco Fortaleza
# 57                      OTROS (BCE12)                   Ver glosita
# 58                 CORRIENTES (BCI12)                   Ver glosita

# %%
for i in range(len(conCodigos)):
    objeto =conCodigos.loc[i,"Glosa"]+str(conCodigos.loc[i,"Detalle"])
    print(i, "=",objeto)
    buscareis = re.findall(r'(%s)'%apachurrado,objeto,flags=re.IGNORECASE+re.MULTILINE)
    print ("antes ", buscareis)
    unasola = list(itertools.chain.from_iterable(buscareis))
    print("una sola ",unasola)
    unasola = list(dict.fromkeys(unasola))
    unasola = [i for i in unasola if i]
    print("sin duplicados ",unasola)
    #este =', '.join(map(str,unasola))
    
    if conCodigos.loc[i,"Tipo"] in["D","V"]:
        if conCodigos.loc[i,"Concepto"] == "Ingreso":
            conCodigos.loc[i,"codigoBC"]="AJUSTE POR ARBITRAJE DE SALDOS (BCI32)"
        else:
            conCodigos.loc[i,"codigoBC"]="AJUSTE POR ARBITRAJE DE SALDOS (BCE29)"
            
    if conCodigos.loc[i,"Mayor2"] ==498:
        if conCodigos.loc[i,"Concepto"] == "Ingreso":
            conCodigos.loc[i,"codigoBC"]="ABONOS TRANSITORIOS (BCI31)"
            
    if conCodigos.loc[i,"codigoPropio"]==valorDefecto:
        #print ("este ", este)
        print(conCodigos.loc[i,"codigoPropio"])
        conCodigos.loc[i,"codigoPropio"]=', '.join(map(str,unasola))

conCodigos
#conCodigos.to_excel("conCodigos07feb.xlsx",index=False)
#nombreSalida = "PreCargaBC_" + pd.Timestamp.now().strftime("%d%b%H%M")
#conCodigos.to_excel(nombreSalida+".xlsx", index=False)
# Out:
# 0 = AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDOS DE ACTIVOS DE RESERVA Y OBLIGACIONES MONEDA EXTRANJERA (DOLARES)                                                                                                                                                                                            Saldo ME = -687701.69 ;Bs/Mo: 6.86000000000 ;Saldo Bs: -4717633.60
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 1 = AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE RESERVA Y OBLIGACIONES EN MONEDAS DE ORIGEN AL 7/2/2022 S/G TABLA DE COTIZACIONES                                                                                                                                                                              Saldo Ant.= 66873.00 ;Bs: 9.64941320000 = $us 94064.90  Saldo ant. $us 93567.36
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 2 = 'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00 Y VENTA DE USD 114.408,00  S/G ANTC. ADJ.                                                                                                                                                                                                                    Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 3 = 'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNIGHT AUTOMATICOS EN EL  STANDARD CHARTERED BANK NY   DEL  04 AL 07 DE FEBRERO 2022 CAPITAL USD 372.850.043,15; TASA 0,23 %   S/G SWIFT  N° 1772 ADJ.                                                                                                           Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 4 = ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT N° 1805 DE LA FECHA POR COMISIONES DEL BANQUERO REF: SOLICITUD 35384-14671 DE SEDEM, PAGO FECHA VALOR 21/12/2021 POR EUR 2.367,45 A  AUBERT DIANA UND AUBERT FREDERIC ETIENNE THIERRY, SERV. SOPORTE TECNICO.                                                 SWIFT N° 1805 DE LA FECHA.
# antes  [('SEDEM', '')]
# una sola  ['SEDEM', '']
# sin duplicados  ['SEDEM']
# Ver glosita
# 5 = ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT NROS. 1758 Y 1757 DE LA FECHA, Y NOTA CITE: ADSIB - DE N° 129 DE FECHA 10/05/2016 (HRE-TGL-6924) (SECTOR PÚBLICO - SERVICIOS).                                                                                                                                POR CUENTA DE 101DOMAIN GRS LIMITED.
# antes  [('ADSIB', '')]
# una sola  ['ADSIB', '']
# sin duplicados  ['ADSIB']
# 6 = ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT NROS. 1789 Y 1788 DE LA FECHA, Y NOTA CITE: DGAC/1573/16 DE FECHA 05/05/2016 (HRE-TGL-6755).  (SECTOR PÚBLICO - SOBREVUELOS).                                                                                                                                 POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# antes  []
# una sola  []
# sin duplicados  []
# 7 = ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT NROS. 1762 Y 1761 DE LA FECHA (SECTOR PÚBLICO - EXPORTACIONES).                                                                                                                                                                                               POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# antes  []
# una sola  []
# sin duplicados  []
# 8 = ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT NROS. 1760 Y 1759 DE LA FECHA (SECTOR PÚBLICO - EXPORTACIONES).                                                                                                                                                                                               POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# antes  []
# una sola  []
# sin duplicados  []
# 9 = ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT NRO. 1763 Y CORREO ELECTRÓNICO ENVIADO POR YPFB DE LA FECHA (SECTOR PÚBLICO - EXPORTACIONES)                                                                                                                                                                   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE FERTILIZANTES LTDA.
# antes  []
# una sola  []
# sin duplicados  []
# 10 = ||REVALORACION DE TITULOS A PRECIOS DE MERCADO AL 07 DE FEBRERO DE 2022 CORRESPONDIENTE AL PORTAFOLIO DE LIQUIDEZ.                                                                                                                                                                                          Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 11 = ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A. SEGUN SWIFT NO.1810 DE LA FECHA REF.: CUENTA ENCAJE                                                                                                                                                                                                       TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A. REF.: CUENTA ENCAJE
# antes  [('BANCO UNION', ''), ('BANCO UNION', '')]
# una sola  ['BANCO UNION', '', 'BANCO UNION', '']
# sin duplicados  ['BANCO UNION']
# 12 = ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT N°1790 Y CORREO ELECTRÓNICO ENVIADO POR LA UAGRM DE LA FECHA.                                                                                                                                                                                                 A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. Y TECN. POR CTA. DE CARDENAS GALIANO JORGE ARMANDO.
# antes  [('UAGRM', ''), ('UAGRM', '')]
# una sola  ['UAGRM', '', 'UAGRM', '']
# sin duplicados  ['UAGRM']
# Ver glosita
# 13 = ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO DE COMISIONES EN EUROS SEGÚN SWIFT N° 1806 POR EUR 10.- TRANSF. EUR 100.- DE LA FECHA REF: MINISTERIO DE ECONOMIA Y FINANZAS PUBLICAS.                                                                                                                         (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 14 = 'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZACION'||SEGÚN MENSAJE SWIFT NRO. 1756 DE LA FECHA. (SIN CUENTA DE BENEFICIARIO) (SECTOR PÚBLICO - SERVICIOS)                                                                                                                                                  (CC:H-0046564-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 15 = 'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZACION'||SEGÚN MENSAJE SWIFT NRO. 1787 DE LA FECHA. (SIN CUENTA DE BENEFICIARIO) (SECTOR PÚBLICO - SERVICIOS)                                                                                                                                                  (CC:H-0046565-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 16 = ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A. SEGUN SWIFT NO.1833 DE LA FECHA REF.: CPVIS II                                                                                                                                                                                                             TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A. REF.: CPVIS II
# antes  [('BANCO BISA', ''), ('BANCO BISA', '')]
# una sola  ['BANCO BISA', '', 'BANCO BISA', '']
# sin duplicados  ['BANCO BISA']
# Ver glosita
# 17 = 'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZACION'||SEGÚN MENSAJE SWIFT NRO. 1809 DE LA FECHA. (SIN CUENTA DE BENEFICIARIO) (SECTOR PÚBLICO - SERVICIOS)                                                                                                                                                  (CC:H-0046569-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 18 = 'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZACION'||SEGÚN MENSAJE SWIFT NRO. 1811 DE LA FECHA. (SIN CUENTA DE BENEFICIARIO) (SECTOR PÚBLICO - SERVICIOS)                                                                                                                                                  (CC:H-0046570-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 19 = 'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZACION'||SEGÚN MENSAJE SWIFT NRO. 1818 DE LA FECHA. (SIN CUENTA DE BENEFICIARIO) (SECTOR PÚBLICO - SERVICIOS)                                                                                                                                                  (CC:H-0046571-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 20 = TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISIONES A SOLICITUD DE BANCO GANADERO S.A. SEGUN SOLICITUD BG-0019-2022                                                                                                                                                                                          Ver glosita
# antes  [('BANCO GANADERO', '')]
# una sola  ['BANCO GANADERO', '']
# sin duplicados  ['BANCO GANADERO']
# Ver glosita
# 21 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE EMPRESA NACIONAL DE ELECTRICIDAD SEGUN SOLICITUD 15059 REF: DIGSILENT GMBH- PAGO POR SERVICIO DE ACTUALIZACION Y MANTENIMIENTO DE SOFTWARE POWER FACTORY DIGSILENT EQUIVALENTES  18.341,77 USD                                                  DIGSILENT GMBH, CTA. DE02600501010004702483 LANDESBANK BADEN-WUERTTEMBERG STUTTGART  DE
# antes  [('EMPRESA NACIONAL DE ELECTRICIDAD', '')]
# una sola  ['EMPRESA NACIONAL DE ELECTRICIDAD', '']
# sin duplicados  ['EMPRESA NACIONAL DE ELECTRICIDAD']
# Ver glosita
# 22 = TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITUD DE MINISTERIO DE RELACIONES EXTERIORES SEGUN SOLICITUD 15073 REF: REMISION DE RECURSOS A FAVOR DE CONSULADO EN MILAN PARA GASTOS DE INSTALACION DE JIMENA GUZMAN CABELLO SEGUN LIQUIDACION 212                                                              CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT22N0306909465100000560055 INTESA SANPAOLO SPA (HEAD OFFICE) MILANO  IT
# antes  [('MINISTERIO DE RELACIONES EXTERIORES', ''), ('CONSULADO GENERAL DE BOLIVIA', '')]
# una sola  ['MINISTERIO DE RELACIONES EXTERIORES', '', 'CONSULADO GENERAL DE BOLIVIA', '']
# sin duplicados  ['MINISTERIO DE RELACIONES EXTERIORES', 'CONSULADO GENERAL DE BOLIVIA']
# Ver glosita
# 23 = TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITUD DE MINISTERIO DE RELACIONES EXTERIORES SEGUN SOLICITUD 15072 REF: REMISION DE COSTO DE VIDA  DEL PERSONAL DEL SERVICIO EXTERIOR CORRESPONDIENTE AL MES DE DICIEMBRE 2021 SEGUN PLANILLA 122110                                                              Ver glosita
# antes  [('MINISTERIO DE RELACIONES EXTERIORES', '')]
# una sola  ['MINISTERIO DE RELACIONES EXTERIORES', '']
# sin duplicados  ['MINISTERIO DE RELACIONES EXTERIORES']
# Ver glosita
# 24 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE EDITORIAL DEL ESTADO PLURINACIONAL DE BOLIVIA SEGUN SOLICITUD 15071 REF: REGISTRO PARA EL PAGO DE VENTA DE LIBROS AL FONDO DE CULTURA ECONOMICA DE CHILE S.A. EN LAS FERIAS DE LAS CIUDADES DE LA PAZ Y COCHABAMBA, STAND DE LA EDITORIAL DEL ESFONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00130001696 BANCO BICE SANTIAGO
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 25 = TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITUD DE BOLIVIANA DE AVIACION SEGUN SOLICITUD 15070 REF: INVOICE 8222 8276 8274 8277 8275 8281 82801 8280 8292 8297 8290 8289 8288 PAGO DE VARIOS ITEMS                                                                                                          Ver glosita
# antes  [('BOLIVIANA DE AVIACION', '')]
# una sola  ['BOLIVIANA DE AVIACION', '']
# sin duplicados  ['BOLIVIANA DE AVIACION']
# Ver glosita
# 26 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE SERVICIO NACIONAL TEXTIL-SENATEX SEGUN SOLICITUD 15069 REF: ADQUISICION DE TELA TEMPESTAD Y TEMPESTAD AV EVOLUTION                                                                                                                              TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE BOGOTA, MIAMI AGENCY MIAMI,FL US
# antes  [('ENATEX', '')]
# una sola  ['ENATEX', '']
# sin duplicados  ['ENATEX']
# Ver glosita
# 27 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA SEGUN SOLICITUD 15068 REF: H.R. 346  ENVIO DE RECURSOS A LA SERVIDORA PUBLICA YALILE ATAHUICHI RODRIGUEZ, PARA GASTOS-GATE OUT, Y TRANSPORTE GESTION 2022 PUERTO ARICA, SEGUN INFORME ASP-B/DOP-UADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIVIA ANTOFAGASTA, CTA. 11130695 BANCO DE CREDITO E INVERSIONES SANTIAGO CL
# antes  [('ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', ''), ('BANCO DE CREDITO', '')]
# una sola  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', '', 'BANCO DE CREDITO', '']
# sin duplicados  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', 'BANCO DE CREDITO']
# Ver glosita
# 28 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA SEGUN SOLICITUD 15067 REF: H.R. 9-10-11 PAGO DE FACTURAS EMITIDAS POR TPA. S.A. POR SERVICIOS DE REFRIGERACION DE CONTENEDORES A LA CARGA DE IMPORTACION, SERVICIOS DE DESCARGUIO, CONSOLIDADO, RTERMINAL PUERTO ARICA S.A., CTA. 005100026386 BANCO SANTANDER CHILE SANTIAGO, CHILE
# antes  [('ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', '')]
# una sola  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', '']
# sin duplicados  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA']
# Ver glosita
# 29 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE SERVICIO NACIONAL TEXTIL-SENATEX SEGUN SOLICITUD 15066 REF: PAGO DE FLETES Y SEGUROS EN COMPRA DE TELA TEMPESTAD Y TEMPESTAD EVOLUTION                                                                                                          TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE BOGOTA, MIAMI AGENCY MIAMI,FL US
# antes  [('ENATEX', '')]
# una sola  ['ENATEX', '']
# sin duplicados  ['ENATEX']
# Ver glosita
# 30 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA SEGUN SOLICITUD 15065 REF: H.R. 346 - ENVIO DE RECURSOS A LA SERVIDORA PUBLICA YALILE ATAHUICHI RODRIGUEZ, PUERTO ARICA, PARA GASTOS DE FUNCIONAMIENTO CLASE DE GASTO 5  PUERTO ARICA-SEGUN INFORADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIVIA ANTOFAGASTA, CTA. 11130695 BANCO DE CREDITO E INVERSIONES SANTIAGO CL
# antes  [('ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', ''), ('GASTOS DE FUNCIONAMIENTO', ''), ('BANCO DE CREDITO', '')]
# una sola  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', '', 'GASTOS DE FUNCIONAMIENTO', '', 'BANCO DE CREDITO', '']
# sin duplicados  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', 'GASTOS DE FUNCIONAMIENTO', 'BANCO DE CREDITO']
# Ver glosita
# 31 = VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A SOLICITUD DE ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA SEGUN SOLICITUD 15064 REF: H.R. 5094-5083 - PAGO DE FACTURAS EMITIDAS POR TISUR. S.A. POR SERVICIOS DE RECEPCION, DESCARGA, MANIPULEO Y DESPACHO DE CARGA, CORRESPONDIENTE A LA 27VA Y 28VA CONFOTERMINAL INTERNACIONAL DEL SUR SA, CTA. 4251056312156 BANCO DE CREDITO DEL PERU LIMA  PE
# antes  [('ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', ''), ('BANCO DE CREDITO', '')]
# una sola  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', '', 'BANCO DE CREDITO', '']
# sin duplicados  ['ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA', 'BANCO DE CREDITO']
# Ver glosita
# 32 = TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITUD DE BOLIVIANA DE AVIACION SEGUN SOLICITUD 15063 REF: INVOICE 105 008 2021 2 MSN 28246 CP 2926 PAGO POR MANTENIMIENTO SERVICIO MAYOR 8YR 10YR Y ADS                                                                                                           Ver glosita
# antes  [('BOLIVIANA DE AVIACION', '')]
# una sola  ['BOLIVIANA DE AVIACION', '']
# sin duplicados  ['BOLIVIANA DE AVIACION']
# Ver glosita
# 33 = TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITUD DE BOLIVIANA DE AVIACION SEGUN SOLICITUD 15062 REF: INVOICES I211510  I211511  I211509  I211512 PAGO COMPRA DE LLANTAS PARA REPOSICION                                                                                                                      Ver glosita
# antes  [('BOLIVIANA DE AVIACION', '')]
# una sola  ['BOLIVIANA DE AVIACION', '']
# sin duplicados  ['BOLIVIANA DE AVIACION']
# Ver glosita
# 34 = TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1770 Y NO.1769 DE FECHA 07/02/2022 ORDENANTE: PETROLEO BRASILEIRO SA PETROBRAS (RIO DE JANEIRO BRASIL) REF.: INV EXB-CBAJV-02/21 FECHA VALOR 4/02/2022                                                                                                            Ver glosita
# antes  [('PETROBRAS', '')]
# una sola  ['PETROBRAS', '']
# sin duplicados  ['PETROBRAS']
# Ver glosita
# 35 = TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1767 Y NO.1766 DE FECHA 07/02/2022 ORDENANTE: PETROLEO BRASILEIRO SA PETROBRAS (RIO DE JANEIRO BRAZIL) REF.: INV EXB-CBAT-037-21 FECHA VALOR 4/02/2022                                                                                                            Ver glosita
# antes  [('PETROBRAS', '')]
# una sola  ['PETROBRAS', '']
# sin duplicados  ['PETROBRAS']
# Ver glosita
# 36 = TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1765 Y NO.1764 DE FECHA 07/02/2022 ORDENANTE: PETROLEO BRASILEIRO SA PETROBRAS (RIO DE JANEIRO BRAZIL) REF.: INV EXB-CBAT1-02/21 FECHA VALOR 4/02/2022                                                                                                            Ver glosita
# antes  [('PETROBRAS', '')]
# una sola  ['PETROBRAS', '']
# sin duplicados  ['PETROBRAS']
# Ver glosita
# 37 = TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3544020682001 A LA CUENTA CTR_BOA 1901-3-28200 POR UN MONTO DE USD 876.970,40 CON FECHA VALOR 07-02-2022                                                                                                                                                       ('±', 876970.4)
# antes  [('BOA', '')]
# una sola  ['BOA', '']
# sin duplicados  ['BOA']
# Ver glosita
# 38 = PAGO A BANCO EUROPEO DE INV PRÉSTAMO FIN 82800 VCTO. 07-02-2022 POR CUENTA DE TGN , NTI. 015700 VALOR 07-02-2022 CAPITAL USD 546.875,00 INTERESES USD 82.854,23                                                                                                                                             CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMERICANOS LIB. 00099021001
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 39 = PAGO A BID PRÉSTAMO 1075-SF-BO-8 VCTO. 06-02-2022 POR CUENTA DE TGN , NTI. 015697 VALOR 07-02-2022 CAPITAL USD 49.509,68 INTERESES USD 21.464,14                                                                                                                                                            CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMERICANOS LIB. 00099021001
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 40 = PAGO A BID PRÉSTAMO 1118-SF-BO VCTO. 06-02-2022 POR CUENTA DE TGN , NTI. 015696 VALOR 07-02-2022 CAPITAL USD 15.594,94 INTERESES USD 6.760,94                                                                                                                                                               CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMERICANOS LIB. 00099021001
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 41 = REVALORACIÓN DE TÍTULOS AL 07-02-2022, PORTAFOLIO EURO, POR UN MONTO DE EUR 70.086,50                                                                                                                                                                                                                       Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 42 = PAGO A CAF PRÉSTAMO CFA010869 VCTO. 07-02-2022 POR CUENTA DE TGN , NTI. 015715 VALOR 07-02-2022  INTERESES USD 22.538,86 COMISIONES USD 131.372,61                                                                                                                                                          CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMERICANOS LIB. 00099021001
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 43 = INTERÉS DEVENGADO DE TÍTULOS AL 07-02-2022, PORTAFOLIO EURO, POR UN MONTO DE EUR 15.887,13                                                                                                                                                                                                                  Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 44 = TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1755 DE FECHA 07/02/2022 ORDENANTE: CONSULADO GENERAL DE BOLIVIA EN HOUSTON EE.UU. REF.: RECAUDACIONES GESTORÍA CONSULAR GENERAL DEL MES DE ENERO/2022                                                                                                            LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS POR GESTORÍA CONSULAR
# antes  [('CONSULADO GENERAL DE BOLIVIA', '')]
# una sola  ['CONSULADO GENERAL DE BOLIVIA', '']
# sin duplicados  ['CONSULADO GENERAL DE BOLIVIA']
# Ver glosita
# 45 = TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISIONES A SOLICITUD DE BANCO BISA S.A. SEGUN SOLICITUD BISA-0022-2022                                                                                                                                                                                            Ver glosita
# antes  [('BANCO BISA', '')]
# una sola  ['BANCO BISA', '']
# sin duplicados  ['BANCO BISA']
# Ver glosita
# 46 = TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1754 DE FECHA 07/02/2022 ORDENANTE: YPF EXPLORACION Y PRODUCCION DE HIDROCARBUROS DE BOLIVIA S.A. (SANTA CRUZ BOLIVIA) REF.: ANTICIPO PAGO PA - 20220204-00193341 FECHA VALOR 04/02/2022                                                                          Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 47 = REGISTRO TRANSITORIO SEGUN SWIFT NO.1785 HASTA IDENTIFICAR AL BENEFICIARIO - AFF                                                                                                                                                                                                                            (CC:H-0046566-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 48 = REGISTRO TRANSITORIO SEGUN SWIFT NO.1803 HASTA IDENTIFICAR AL BENEFICIARIO - AFF                                                                                                                                                                                                                            (CC:H-0046567-2022)
# antes  []
# una sola  []
# sin duplicados  []
# Ver glosita
# 49 = TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1786 DE FECHA 07/02/2022 ORDENANTE: CANDY AVIATION SERVICES CONSULTING (CALLAO PERU) REF.: YKYC 36 12 21                                                                                                                                                          Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 50 = DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMANI VDA. DE ALVAREZ, CONCEPTO: PAGO DE CUENTA DE LA SRA.REGINA MAMANI PUÑA
# DEUDA DEL FONDO COMPLEMETARIO FABRIL, CUENTA DE DEPOSITO: TGN CUENTA TRANSITORIA- M/E                                                                                             Ver glosita
# antes  [('DEPOSITO DE EFECTIVO', ''), ('DEPOSITANTE', '')]
# una sola  ['DEPOSITO DE EFECTIVO', '', 'DEPOSITANTE', '']
# sin duplicados  ['DEPOSITO DE EFECTIVO', 'DEPOSITANTE']
# Ver glosita
# 51 = PAGO CHEQUE: D-22-99977     , BENEFICIARIO: EMPRESA DE TRANSPORTE DE VALORES-ETV S.A.- CLAUDIA ISABEL ARANDA MACHICADO S/G PODER N°225/2021                                                                                                                                                                 Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 52 = DEPOSITO DE EFECTIVO, DEPOSITANTE: VICTOR SAMUEL SEMPERTEGUI PEÑARANDA, CONCEPTO: PAGO A CUENTA DE CANCELACION DE DEUDA EN MORA EX FONDO COMPLEMENTARIO DE SEGURIDAD SOCIAL FABRIL, CUENTA DE DEPOSITO: TGN CUENTA TRANSITORIA- M/E                                                                         Ver glosita
# antes  [('DEPOSITO DE EFECTIVO', ''), ('DEPOSITANTE', '')]
# una sola  ['DEPOSITO DE EFECTIVO', '', 'DEPOSITANTE', '']
# sin duplicados  ['DEPOSITO DE EFECTIVO', 'DEPOSITANTE']
# Ver glosita
# 53 = DEPOSITO DE EFECTIVO, DEPOSITANTE: BERTHA MAMANI MAGNE, CONCEPTO: PASAPORTE OFICIAL, CUENTA DE DEPOSITO: RECAUDACIONES CONSULARES                                                                                                                                                                           Ver glosita
# antes  [('DEPOSITO DE EFECTIVO', ''), ('DEPOSITANTE', ''), ('RECAUDACIONES CONSULARES', '')]
# una sola  ['DEPOSITO DE EFECTIVO', '', 'DEPOSITANTE', '', 'RECAUDACIONES CONSULARES', '']
# sin duplicados  ['DEPOSITO DE EFECTIVO', 'DEPOSITANTE', 'RECAUDACIONES CONSULARES']
# Ver glosita
# 54 = DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA GUZMAN MENESES, CONCEPTO: PASAPORTE DIPLOMATICO, CUENTA DE DEPOSITO: RECAUDACIONES CONSULARES                                                                                                                                                                   Ver glosita
# antes  [('DEPOSITO DE EFECTIVO', ''), ('DEPOSITANTE', ''), ('RECAUDACIONES CONSULARES', '')]
# una sola  ['DEPOSITO DE EFECTIVO', '', 'DEPOSITANTE', '', 'RECAUDACIONES CONSULARES', '']
# sin duplicados  ['DEPOSITO DE EFECTIVO', 'DEPOSITANTE', 'RECAUDACIONES CONSULARES']
# Ver glosita
# 55 = PAGO CHEQUE: D-21-99306     , BENEFICIARIO: MARCO ANTONIO QUISPE PATTY                                                                                                                                                                                                                                      Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 56 = PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BRINKS BOLIVIA SA  JUAN ALBERTO MOLLINEDO FLORES SEGUN PODER  266/2020                                                                                                                                                                                          Ver glosita
# antes  []
# una sola  []
# sin duplicados  []
# 57 = VENTA DE DOLARES REALIZADA EN EL BANCO UNION S.A. SEGUN CONTRATO SANO - DLBCI N° 004/2019                                                                                                                                                                                                                   Ver glosita
# antes  [('BANCO UNION', '')]
# una sola  ['BANCO UNION', '']
# sin duplicados  ['BANCO UNION']
# Ver glosita
# 58 = DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA CONDORI CALLIZAYA, CONCEPTO: PASAPORTE DIPLOMATICO, CUENTA DE DEPOSITO: RECAUDACIONES CONSULARES                                                                                                                                                             Ver glosita
# antes  [('DEPOSITO DE EFECTIVO', ''), ('DEPOSITANTE', ''), ('RECAUDACIONES CONSULARES', '')]
# una sola  ['DEPOSITO DE EFECTIVO', '', 'DEPOSITANTE', '', 'RECAUDACIONES CONSULARES', '']
# sin duplicados  ['DEPOSITO DE EFECTIVO', 'DEPOSITANTE', 'RECAUDACIONES CONSULARES']
# Ver glosita
#    Tipo  Comprobante Concepto  Mayor1  Mayor2  codMov  \
# 0     D        21863  Ingreso     410      10    6072
# 1     V        28487  Ingreso      22      17    6296
# 2     S      1025337  Ingreso      10      10    5896
# 3     S      1025347  Ingreso      11     606    1535
# 4     S      1025355   Egreso      10     412    3987
# 5     S      1025365  Ingreso      10     412    4710
# 6     S      1025366  Ingreso      10     412    5832
# 7     S      1025368  Ingreso      10     404    7954
# 8     S      1025371  Ingreso      10     404    7954
# 9     S      1025374  Ingreso      10     404    7954
# 10    S      1025377  Ingreso      16     499    7355
# 11    S      1025378  Ingreso      10     403    3910
# 12    S      1025383  Ingreso      10     412     818
# 13    S      1025388   Egreso      10     198    3641
# 14    S      1025390  Ingreso      10     498    8304
# 15    S      1025391  Ingreso      10     498    8304
# 16    S      1025393  Ingreso      10     414    7866
# 17    S      1025404  Ingreso      10     498    8304
# 18    S      1025405  Ingreso      10     498    8304
# 19    S      1025406  Ingreso      10     498    8304
# 20    G      1778875   Egreso      10     498    6817
# 21    G      1778876   Egreso      10     412    3987
# 22    G      1778877   Egreso      10     498    4088
# 23    G      1778878   Egreso      10     498    4088
# 24    G      1778879   Egreso      10     412    3987
# 25    G      1778880   Egreso      10     498    4088
# 26    G      1778881   Egreso      10     412    3987
# 27    G      1778882   Egreso      10     412    3987
# 28    G      1778883   Egreso      10     412    3987
# 29    G      1778884   Egreso      10     412    3987
# 30    G      1778885   Egreso      10     412    3987
# 31    G      1778886   Egreso      10     412    3987
# 32    G      1778887   Egreso      10     498    4088
# 33    G      1778888   Egreso      10     498    4088
# 34    G      1778889  Ingreso      10     404    5968
# 35    G      1778891  Ingreso      10     404    5968
# 36    G      1778893  Ingreso      10     404    5968
# 37    G      1779021    Neteo      10      10    5896
# 38    G      1779022   Egreso      10     412    5970
# 39    G      1779023   Egreso      10     412    5970
# 40    G      1779024   Egreso      10     412    5970
# 41    G      1779146   Egreso      16     499    7355
# 42    G      1779147   Egreso      10     412    5970
# 43    G      1779148  Ingreso      17     606    6538
# 44    G      1779150  Ingreso      10     412    5970
# 45    G      1779152   Egreso      10     498    6817
# 46    G      1779153  Ingreso      10     404    6705
# 47    G      1779295  Ingreso      10     498    1470
# 48    G      1779296  Ingreso      10     498    1470
# 49    G      1779298  Ingreso      10     412    4249
# 50    O      1997192  Ingreso       7     406     898
# 51    O      1997212   Egreso       7     403    3917
# 52    O      1997224  Ingreso       7     406     898
# 53    O      1997225  Ingreso       7     406     861
# 54    O      1997255  Ingreso       7     406     861
# 55    O      1997265   Egreso       7     403    3910
# 56    O      1997267   Egreso       7     403    6893
# 57    H      1997277   Egreso       7     828    3559
# 58    O      1997352  Ingreso       7     406     861
#
#                                            Movimiento    MontoUSD  \
# 0   MADRID EUROS CUENTA ES2990299029960000000107  ...        0.01
# 1   INTERESES DEVENGADOS                          ...  1022077.47
# 2   NEW YORK - CTA. 3544020682001                 ...      142.15
# 3   INTERESES OVERNIGHT CAPITAL TRABAJO           ...     7146.29
# 4   CUENTA UNICA DEL TESORO                       ...       20.05
# 5   03-W-302 AG.P.EL DES.DE LA SOC.DE INF.EN BOL.-...     1727.37
# 6   03-H-307 DIREC.GRAL DE AERONAUTICA CIVIL-REC.P...     1935.35
# 7   YPFB - EXPORTACION DE UREA Y OTROS            ...   252250.00
# 8   YPFB - EXPORTACION DE UREA Y OTROS            ...   302700.00
# 9   YPFB - EXPORTACION DE UREA Y OTROS            ...    78165.00
# 10  VALORACION TITULOS DE LAS RESERVAS INTERNACION...       38.90
# 11  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  3600000.00
# 12  CTAS. CTES. FISC. CORRESP. -BCO.UNION         ...      690.00
# 13  DEUDORES DIVERSOS-OPERACIONES CAMBIARIAS      ...       11.45
# 14  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      220.00
# 15  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...     1540.00
# 16  EFECTIVO GARANTIA FONDO CPVIS                 ...  7000000.00
# 17  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      225.00
# 18  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      203.00
# 19  ACREEDORES DIVERSOS OPERACIONES DEL SECTOR PUB...      665.00
# 20  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 21  CUENTA UNICA DEL TESORO                       ...    18341.77
# 22  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     4780.16
# 23  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...     7274.30
# 24  CUENTA UNICA DEL TESORO                       ...     1476.09
# 25  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    99915.00
# 26  CUENTA UNICA DEL TESORO                       ...    75828.70
# 27  CUENTA UNICA DEL TESORO                       ...    10000.00
# 28  CUENTA UNICA DEL TESORO                       ...   147581.48
# 29  CUENTA UNICA DEL TESORO                       ...    21065.00
# 30  CUENTA UNICA DEL TESORO                       ...     5178.00
# 31  CUENTA UNICA DEL TESORO                       ...   129282.67
# 32  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...   122400.00
# 33  OPERACIONES A APROPIAR TGN-GCIA.OP.INTERNACION...    37240.00
# 34  YPFB - HEROES DEL CHACO                       ...    81155.99
# 35  YPFB - HEROES DEL CHACO                       ...  1312465.83
# 36  YPFB - HEROES DEL CHACO                       ...   244090.06
# 37  NEW YORK - CTA. 3544020682001                 ...        0.00
# 38  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   629729.23
# 39  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    70973.82
# 40  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...    22355.88
# 41  VALORACION TITULOS DE LAS RESERVAS INTERNACION...    80284.19
# 42  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...   153911.47
# 43  INTERESES SOBRE CUPONES PORTAFOLIO EURO       ...    18198.73
# 44  CUENTA UNICA DEL TESORO EN DOLARES AMERICANOS ...     2074.52
# 45  DEPOSITOS SISTEMA FINANCIERO - OP. CAMBIARIAS ...  5000000.00
# 46  YPFB OPERACIONES FINANCIERAS EXTRAORDINARIAS  ...    53876.80
# 47  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...    13992.00
# 48  ACREED.DIVERSOS -OPERACIONES CAMBIARIAS       ...  5380396.94
# 49  BCB - AASANA CENTRAL 000070078200 - FDOS.COMPR...     4515.81
# 50  TGN CUENTA TRANSITORIA- M/E                   ...       20.00
# 51  BCO.GANADERO-CUENTA CORRIENTE Y DE ENCAJE     ...  2000000.00
# 52  TGN CUENTA TRANSITORIA- M/E                   ...       30.00
# 53  RECAUDACIONES CONSULARES                      ...       40.00
# 54  RECAUDACIONES CONSULARES                      ...       50.00
# 55  BCO.UNION-CUENTA CORRIENTE Y DE ENCAJE        ...  7500000.00
# 56  BANCO FORTALEZA-CUENTA CORRIENTE Y DE ENCAJE  ...   500000.00
# 57  DOLARES AMERICANOS EN CORRESPONSAL BCO.UNION  ...    20000.00
# 58  RECAUDACIONES CONSULARES                      ...       50.00
#
#                                               Detalle  \
# 0   Saldo ME = -687701.69 ;Bs/Mo: 6.86000000000 ;S...
# 1   Saldo Ant.= 66873.00 ;Bs: 9.64941320000 = $us ...
# 2                                         Ver glosita
# 3                                         Ver glosita
# 4                          SWIFT N° 1805 DE LA FECHA.
# 5                POR CUENTA DE 101DOMAIN GRS LIMITED.
# 6   POR CUENTA DE CANDY AVIATION SERVICES CONSULTING.
# 7          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 8          POR CUENTA DE PROSOLLO FERTILIZANTES LTDA.
# 9   POR CUENTA DE FERTIMAN INDUSTRIA E COMERCIO DE...
# 10                                        Ver glosita
# 11  TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S.A...
# 12  A LA CTA.1-2232746 UAGRM FAC.DE CIENCIAS EXA. ...
# 13   (CC:D-0046563-2022) SWIFT N° 1806 DEL 07/02/2022
# 14                               (CC:H-0046564-2022)
# 15                               (CC:H-0046565-2022)
# 16  TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S.A....
# 17                               (CC:H-0046569-2022)
# 18                               (CC:H-0046570-2022)
# 19                               (CC:H-0046571-2022)
# 20                                        Ver glosita
# 21  DIGSILENT GMBH, CTA. DE02600501010004702483 LA...
# 22  CONSULADO GENERAL DE BOLIVIA EN MILAN, CTA. IT...
# 23                                        Ver glosita
# 24  FONDO DE CULTURA ECONOMICA CHILE S.A., CTA. 00...
# 25                                        Ver glosita
# 26  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 27  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 28  TERMINAL PUERTO ARICA S.A., CTA. 005100026386 ...
# 29  TEXTILES LAFAYETTE S.A.S, CTA. 78311 BANCO DE ...
# 30  ADMINISTRACION DE SERVICIOS PORTUARIOS - BOLIV...
# 31  TERMINAL INTERNACIONAL DEL SUR SA, CTA. 425105...
# 32                                        Ver glosita
# 33                                        Ver glosita
# 34                                        Ver glosita
# 35                                        Ver glosita
# 36                                        Ver glosita
# 37                                      (±, 876970.4)
# 38  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 39  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 40  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 41                                        Ver glosita
# 42  CTA. 5970 CUENTA UNICA DEL TESORO DOLARES AMER...
# 43                                        Ver glosita
# 44  LIB. 00010011102 MIN.REL.EXT.- USD INGRESOS PO...
# 45                                        Ver glosita
# 46                                        Ver glosita
# 47                                (CC:H-0046566-2022)
# 48                                (CC:H-0046567-2022)
# 49                                        Ver glosita
# 50                                        Ver glosita
# 51                                        Ver glosita
# 52                                        Ver glosita
# 53                                        Ver glosita
# 54                                        Ver glosita
# 55                                        Ver glosita
# 56                                        Ver glosita
# 57                                        Ver glosita
# 58                                        Ver glosita
#
#                                                 Glosa  \
# 0   AJUSTE COMPLEMENTARIO POR REVALORIZACION SALDO...
# 1   AJUSTE POR ARBITRAJE DE SALDOS DE ACTIVOS DE R...
# 2   'OPERACION FOREX'||DE COMPRA DE EUR 100.000,00...
# 3   'INTERESES DEVENGADOS SOBRE DEPOSITOS'||OVERNI...
# 4   ||RESPUESTA A DEBITO DEL BANQUERO SEGÚN SWIFT ...
# 5   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 6   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 7   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 8   ||TRANSFERENCIA DE FONDOS S/G. MENSAJES SWIFT ...
# 9   ||TRANSFERENCIA DE FONDOS S/G. MENSAJE SWIFT N...
# 10  ||REVALORACION DE TITULOS A PRECIOS DE MERCADO...
# 11  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO UNION S...
# 12  ||TRANSFERENCIA DE FONDOS SEGÚN MENSAJE SWIFT ...
# 13  ||RESPUESTA  A DEBITO DEL BANQUERO POR COBRO D...
# 14  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 15  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 16  ||TRANSFERENCIA DEL EXTERIOR DEL BANCO BISA S....
# 17  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 18  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 19  'ABONO TRANSITORIO PARA SU POSTERIOR REGULARIZ...
# 20  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 21  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 22  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 23  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 24  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 25  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 26  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 27  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 28  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 29  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 30  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 31  VENTA DE DIVISAS CON TRANSFERENCIA DE FONDOS A...
# 32  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 33  TRANSFERENCIA DE FONDOS AL EXTERIOR A SOLICITU...
# 34  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1770...
# 35  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1767...
# 36  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1765...
# 37  TRANSFERENCIA DE FONDOS DE LA CUENTA CTR_SCB 3...
# 38  PAGO A BANCO EUROPEO DE INV PRÉSTAMO FIN 82800...
# 39  PAGO A BID PRÉSTAMO 1075-SF-BO-8 VCTO. 06-02-2...
# 40  PAGO A BID PRÉSTAMO 1118-SF-BO VCTO. 06-02-202...
# 41  REVALORACIÓN DE TÍTULOS AL 07-02-2022, PORTAFO...
# 42  PAGO A CAF PRÉSTAMO CFA010869 VCTO. 07-02-2022...
# 43  INTERÉS DEVENGADO DE TÍTULOS AL 07-02-2022, PO...
# 44  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1755...
# 45  TRANSFERENCIA DE FONDOS AL EXTERIOR SIN COMISI...
# 46  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1754...
# 47  REGISTRO TRANSITORIO SEGUN SWIFT NO.1785 HASTA...
# 48  REGISTRO TRANSITORIO SEGUN SWIFT NO.1803 HASTA...
# 49  TRANSFERENCIA DEL EXTERIOR SEGUN SWIFT NO.1786...
# 50  DEPOSITO DE EFECTIVO, DEPOSITANTE: REGINA MAMA...
# 51  PAGO CHEQUE: D-22-99977     , BENEFICIARIO: EM...
# 52  DEPOSITO DE EFECTIVO, DEPOSITANTE: VICTOR SAMU...
# 53  DEPOSITO DE EFECTIVO, DEPOSITANTE: BERTHA MAMA...
# 54  DEPOSITO DE EFECTIVO, DEPOSITANTE: PATRICIA GU...
# 55  PAGO CHEQUE: D-21-99306     , BENEFICIARIO: MA...
# 56  PAGO CHEQUE: D-21-99785     , BENEFICIARIO: BR...
# 57  VENTA DE DOLARES REALIZADA EN EL BANCO UNION S...
# 58  DEPOSITO DE EFECTIVO, DEPOSITANTE: SARA KATTYA...
#
#                                   codigoBC  \
# 0   AJUSTE POR ARBITRAJE DE SALDOS (BCI32)
# 1   AJUSTE POR ARBITRAJE DE SALDOS (BCI32)
# 2                              Ver glosita
# 3                            RENTA (BCI14)
# 4                              Ver glosita
# 5                       CORRIENTES (BCI12)
# 6                       CORRIENTES (BCI12)
# 7                    Y.P.F.B. Otros (BCI5)
# 8                    Y.P.F.B. Otros (BCI5)
# 9                    Y.P.F.B. Otros (BCI5)
# 10                           RENTA (BCI14)
# 11         TRANSFERENCIAS del EXT. (BCI22)
# 12                             Ver glosita
# 13                             Ver glosita
# 14                             Ver glosita
# 15                             Ver glosita
# 16         TRANSFERENCIAS del EXT. (BCI22)
# 17                             Ver glosita
# 18                             Ver glosita
# 19                             Ver glosita
# 20          TRANSFERENCIAS al EXT. (BCE22)
# 21                             Ver glosita
# 22                             Ver glosita
# 23                             Ver glosita
# 24                             Ver glosita
# 25                             Ver glosita
# 26                             Ver glosita
# 27                             Ver glosita
# 28                             Ver glosita
# 29                             Ver glosita
# 30                             Ver glosita
# 31                             Ver glosita
# 32                             Ver glosita
# 33                             Ver glosita
# 34                             Ver glosita
# 35                             Ver glosita
# 36                             Ver glosita
# 37                             Ver glosita
# 38                             Ver glosita
# 39                             Ver glosita
# 40                             Ver glosita
# 41                           OTROS (BCE12)
# 42                             Ver glosita
# 43                           RENTA (BCI14)
# 44                             Ver glosita
# 45          TRANSFERENCIAS al EXT. (BCE22)
# 46               OTROS PORTAFOLIOS (BCI33)
# 47                             Ver glosita
# 48                             Ver glosita
# 49                      CORRIENTES (BCI12)
# 50                      CORRIENTES (BCI12)
# 51       OPERACIONES BANCARIAS (3) (BCE19)
# 52                      CORRIENTES (BCI12)
# 53                      CORRIENTES (BCI12)
# 54                      CORRIENTES (BCI12)
# 55       OPERACIONES BANCARIAS (3) (BCE19)
# 56       OPERACIONES BANCARIAS (3) (BCE19)
# 57                           OTROS (BCE12)
# 58                      CORRIENTES (BCI12)
#
#                                          codigoPropio
# 0
# 1
# 2
# 3                                 Intereses Overnight
# 4                                               SEDEM
# 5                                               ADSIB
# 6                        Dir. Gral. Aeronáutica Civil
# 7                                           YPFB UREA
# 8                                           YPFB UREA
# 9                                           YPFB UREA
# 10                          Valoración de Titulos RIN
# 11                                        Banco Unión
# 12                                              UAGRM
# 13
# 14
# 15
# 16                                         BANCO BISA
# 17
# 18
# 19
# 20                                     BANCO GANADERO
# 21                   EMPRESA NACIONAL DE ELECTRICIDAD
# 22  MINISTERIO DE RELACIONES EXTERIORES, CONSULADO...
# 23                MINISTERIO DE RELACIONES EXTERIORES
# 24
# 25                              BOLIVIANA DE AVIACION
# 26                                             ENATEX
# 27  ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA...
# 28     ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA
# 29                                             ENATEX
# 30  ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA...
# 31  ADMINISTRACION DE SERVICIOS PORTUARIOS BOLIVIA...
# 32                              BOLIVIANA DE AVIACION
# 33                              BOLIVIANA DE AVIACION
# 34                                          PETROBRAS
# 35                                          PETROBRAS
# 36                                          PETROBRAS
# 37                                                BOA
# 38
# 39
# 40
# 41                          Valoración de Titulos RIN
# 42
# 43                          Intereses Portafolio Euro
# 44                       CONSULADO GENERAL DE BOLIVIA
# 45                                         BANCO BISA
# 46                               YPFB Op. Financieras
# 47
# 48
# 49                                             Aasana
# 50                  DEPOSITO DE EFECTIVO, DEPOSITANTE
# 51                                     Banco Ganadero
# 52                  DEPOSITO DE EFECTIVO, DEPOSITANTE
# 53  DEPOSITO DE EFECTIVO, DEPOSITANTE, RECAUDACION...
# 54  DEPOSITO DE EFECTIVO, DEPOSITANTE, RECAUDACION...
# 55                                        Banco Unión
# 56                                    Banco Fortaleza
# 57                                        BANCO UNION
# 58  DEPOSITO DE EFECTIVO, DEPOSITANTE, RECAUDACION...

# %%
#print(dt.datetime.today().strftime("%m/%d/%Y"))
print(pd.Timestamp.now().strftime("%d%b%H%M"))
# Out:
# 10Feb1811
